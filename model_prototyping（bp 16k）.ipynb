# %% [markdown]
# # Model Prototyping
#
# Building the basis for our model experimentation

# %%
import numpy as np
import pandas as pd
import torch
import os
import json

from torch.utils import data
from torch.nn import Conv2d, AvgPool2d, ReLU, Dropout, Flatten, Linear, Sequential, Module
from torch.optim import Adam
from time import time

from tqdm import tqdm

device = torch.device("cuda:0")
torch.set_default_dtype(torch.float64)

MODELS_DIR  = '/home/cxw/sonos_rirs/models/'

# %%
model_dict = {}
model_dict['name'] = "testrun2_regularization"
model_dict['notes'] = "same as test run but with regularization"
model_dict['data_path'] = '/home/cxw/sonos_rirs/features/080122_5k_phase/feature_df_bp_16k.csv'
model_dict['model_path'] = os.path.join(MODELS_DIR, model_dict['name'])

# %%
try:
    # 尝试导入IPython
    from IPython import get_ipython
    # 检查是否在IPython环境下
    if get_ipython() is not None:
        # 加载autoreload扩展
        # %load_ext autoreload
        # 设置autoreload为2
        # %autoreload 2
except ImportError:
    # 如果IPython没有被安装，则不作任何操作
    pass

# %%
# %autoreload 2
# # import volume_estimation.modeling as model_funcs
# model_funcs.train_model(model_funcs.Baseline_Model, model_dict,\
#                         overwrite=True, epochs=10,log=False) #######################################################

# %%
# feat_df = pd.read_csv(model_dict['data_path'])
# model_path = os.path.join(MODELS_DIR, model_dict['name'])

# dataset = []

    
# def create_dataloader(feature_df, batch_size=1, log=True):
#     dataset = []
#     for row in tqdm(feature_df.iterrows()):
#         feat_file = row[1]['file_feature']
#         loaded = np.load(feat_file)

#         feature = loaded['feat']
#         feature = feature.reshape((1, feature.shape[0], feature.shape[1]))
#         feature = np.real(feature)

#         vol = loaded['vol']
#         if log:
#             vol = np.log10(vol)
#         dataset.append((feature, vol))
    
#     dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
#     return dataloader

# dataloader = create_dataloader(feat_df, log=False)

feat_df = pd.read_csv(model_dict['data_path'])
model_path = os.path.join(MODELS_DIR, model_dict['name'])

dataset = []

import pandas as pd
import numpy as np
import torch
from tqdm import tqdm
import os

# 假设 csv_file_path 是你的 .csv 文件路径
csv_file_path = '/home/cxw/sonos_rirs/features/080122_5k_phase/feature_df_bp_16k.csv'

# 读取 .csv 文件
csv_df = pd.read_csv(csv_file_path)

def create_dataloader(feature_df, batch_size=1, log=False):
    dataset = []
    for row in tqdm(feature_df.iterrows()):
        feat_file = row[1]['file_feature']
        loaded = np.load(feat_file)
        
        # 获取 log_rt60
        vol = loaded['log_rt60']
        
        # 在 csv_df 中查找对应的 log_bp 值
        csv_row = csv_df[csv_df['file_feature'] == feat_file]
        if not csv_row.empty:
            log_bp_value = csv_row['log_bp'].values[0]
            vol = log_bp_value  # 用 log_bp 替换 log_rt60
        
        feature = loaded['feat']
        feature = feature.reshape((1, feature.shape[0], feature.shape[1]))
        feature = np.real(feature)
        
        if log:
            vol = np.log10(vol)
        
        dataset.append((feature, vol))
    
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
    return dataloader

# 假设 feat_df 是你的特征数据框
dataloader = create_dataloader(feat_df, log=False)
# Out:
# 32000it [00:48, 658.88it/s]

# %%
savename = './testmodeldict.json'
with open(savename, 'w') as f:
    json.dump(model_dict, f)
    
with open(savename) as f:
    load_dict = json.load(f)
    
for key in load_dict.keys():
    print(key, load_dict[key])
# Out:
# name testrun2_regularization
# notes same as test run but with regularization
# data_path /home/cxw/sonos_rirs/features/080122_5k_phase/feature_df_bp_16k.csv
# model_path /home/cxw/sonos_rirs/models/testrun2_regularization

# %%
train_df = feat_df[feat_df['split'].isin(['train','val','test'])]
val_df = feat_df[feat_df['split']=='test']
test_df = feat_df[feat_df['split']=='test']

print("Creating training dataloader")
train_dataloader = create_dataloader(train_df, batch_size=64)

print("Creating validation dataloader")
val_dataloader = create_dataloader(val_df)

print("Creating test dataloader")
test_dataloader = create_dataloader(test_df)
# Out:
# Creating training dataloader
# 32000it [00:47, 666.81it/s]
# Creating validation dataloader
# 6380it [00:09, 662.03it/s]
# Creating test dataloader
# 6380it [00:09, 667.35it/s]

# %%
features, labels = next(iter(train_dataloader))
print(f"Feature batch shape: {features.size()}")
print(f"Labels batch shape: {labels.size()}")
# Out:
# Feature batch shape: torch.Size([64, 1, 30, 1997])
# Labels batch shape: torch.Size([64])

# %%
class Baseline_Model(Module):
    def __init__(self, input_shape):
        #accepts a tuple with the height/width of the feature
        #matrix to set the FC layer dimensions
        super(Baseline_Model, self).__init__()
        
        #block1
        Conv1 = Conv2d(1, 30, kernel_size=(1,10), stride=(1,1))
        Avgpool1 = AvgPool2d((1,2), stride=(1,2))

        #block2
        Conv2 = Conv2d(30, 20, kernel_size=(1,10), stride=(1,1))
        Avgpool2 = AvgPool2d((1,2), stride=(1,2))

        #block3
        Conv3 = Conv2d(20, 10, kernel_size=(1,10), stride=(1,1))
        Avgpool3 = AvgPool2d((1,2), stride=(1,2))

        #block4
        Conv4 = Conv2d(10, 10, kernel_size=(1,10), stride=(1,1))
        Avgpool4 = AvgPool2d((1,2), stride=(1,2))

        #block5
        Conv5 = Conv2d(10, 5, kernel_size=(3,9), stride=(1,1))
        Avgpool5 = AvgPool2d((1,2), stride=(1,2))

        #block6
        Conv6 = Conv2d(5, 5, kernel_size=(3,9), stride=(1,1))
        Avgpool6 = AvgPool2d((2,2), stride=(2,2))

        #dropout
        dropout_layer = Dropout(p=0.5)
        height5 = input_shape[0] - 2
        height6 = (height5 - 2) // 2

        time1 = (input_shape[1] - 9) // 2
        time2 = (time1 - 9) // 2
        time3 = (time2 - 9) // 2
        time4 = (time3 - 9) // 2
        time5 = (time4 - 7) // 2
        time6 = (time5 - 7) // 2

        flat_dims = 5 * height6 * time6
        fc_layer = Linear(flat_dims, 1)
        
        self.net = Sequential(
                    Conv1, ReLU(), Avgpool1,
                    Conv2, ReLU(), Avgpool2,
                    Conv3, ReLU(), Avgpool3,
                    Conv4, ReLU(), Avgpool4,
                    Conv5, ReLU(), Avgpool5,
                    Conv6, ReLU(), Avgpool6,
                    dropout_layer, Flatten(),
                    fc_layer, Flatten()
                )
    def forward(self, x):
        for layer in self.net:
            x = layer(x)
        return x

# %%
input_height = features.size()[2]
input_width = features.size()[3]

model = Baseline_Model((input_height, input_width)).to(device)

# %%
def MSE(output, target):
    loss = torch.mean((output - target)**2)
    return loss

def Bias(output, target):
    loss = torch.mean(torch.abs(10**output - 10**target))
    return loss

def CovStep(output, target, output_mean, target_mean):
    loss = torch.mean(((output - output_mean) * (target - target_mean)))
    return loss

def MeanAbsLogStep(output, target, log=True):
    #convert out of log
    if log:
        vol_pred = 10**output
        vol_target = 10**target
    else:
        vol_pred = output
        vol_target = target
    loss = torch.mean(torch.abs(torch.log(vol_pred/vol_target)))
    return loss

def compute_eval_metrics(dataloader, model, log=True):
    target_sum = 0
    pred_sum = 0
    n_steps = 0
    
    for (x,y) in dataloader:        
        (x, y) = (x.to(device), y.to(device))
        pred = model(x)
        target_sum += y.sum()
        pred_sum += pred.sum()
        n_steps += 1
    
    target_mean = target_sum/n_steps
    pred_mean = pred_sum/n_steps
    
    mse = 0
    mean_error = 0
    cov = 0
    abs_log_ratio = 0
    
    var_pred = 0 #technically var * N but gets cancelled out in Pearson calculation
    var_target = 0 
    
    for (x,y) in dataloader:        
        (x, y) = (x.to(device), y.to(device))
        pred = model(x)
        mse += MSE(pred, y)
        mean_error += Bias(pred, y)
        cov += CovStep(pred, y, pred_mean, target_mean)
        abs_log_ratio += MeanAbsLogStep(pred, y, log=log)
        
        var_pred += MSE(pred, pred_mean)
        var_target += MSE(y, target_mean)
        
        pears = CovStep(pred, y, pred_mean, target_mean)/(torch.sqrt(MSE(pred, pred_mean))*torch.sqrt(MSE(y, target_mean)))
    
    out_dict = {}
    out_dict['mse'] = (mse / n_steps).item()
    out_dict['bias'] = (mean_error / n_steps).item()
    out_dict['pearson_cor'] = (cov/(torch.sqrt(var_pred) * torch.sqrt(var_target))).item()
    out_dict['mean_mult'] = (torch.exp(abs_log_ratio/n_steps)).item()
    
    return out_dict
    
# eval_dict = compute_eval_metrics(val_dataloader, model)
# print(eval_dict)

# %%
opt = Adam(model.parameters(),lr=0.0005, weight_decay=1e-2)

hist = {
	"train_loss": [],
	"val_loss": [],
    "val_bias": [],
    "val_pearson_cor": [],
    "val_mean_mult": []
}

for ep in range(800):     #########################################################################                   
    t_start = time()
    model.train()
    
    train_loss = 0
    val_loss = 0
    train_steps = 0
    val_steps = 0
    
    for (x, y) in train_dataloader:
        (x, y) = (x.to(device), y.to(device))
        pred = model(x)
        loss = MSE(pred, y.reshape((y.shape[0], 1)))
        
        opt.zero_grad()
        loss.backward()
        opt.step()
        
        train_loss += loss
        train_steps += 1
    
    with torch.no_grad():
        model.eval()
        
        val_metrics = compute_eval_metrics(val_dataloader, model)
    
    
    hist['train_loss'].append(train_loss/train_steps)
    hist['val_loss'].append(val_metrics['mse'])
    hist['val_bias'].append(val_metrics['bias'])
    hist['val_pearson_cor'].append(val_metrics['pearson_cor'])
    hist['val_mean_mult'].append(val_metrics['mean_mult'])
    
    t_end = time()
    
    t_elapsed = t_end - t_start
    print("Epoch: {}\tDuration: {:.2f}s\tTrain loss: {:.4f}\tVal loss: {:.4f}\tVal bias:{:.4f}\tVal Pearson correlation: {:.4e}\tVal MeanMult: {:.4f}"\
          .format(ep, t_elapsed, train_loss/train_steps, val_metrics['mse'],\
                  val_metrics['bias'], val_metrics['pearson_cor'],val_metrics['mean_mult']))
# Out:
# Epoch: 0	Duration: 124.51s	Train loss: 0.5341	Val loss: 0.2574	Val bias:818.0150	Val Pearson correlation: 1.2552e-01	Val MeanMult: 2.6007
# Epoch: 1	Duration: 124.05s	Train loss: 0.2701	Val loss: 0.2597	Val bias:816.0277	Val Pearson correlation: 1.3262e-01	Val MeanMult: 2.5953
# Epoch: 2	Duration: 123.76s	Train loss: 0.2685	Val loss: 0.2544	Val bias:816.1536	Val Pearson correlation: 1.4095e-01	Val MeanMult: 2.5942
# Epoch: 3	Duration: 123.96s	Train loss: 0.2672	Val loss: 0.2507	Val bias:818.4637	Val Pearson correlation: 1.4970e-01	Val MeanMult: 2.6003
# Epoch: 4	Duration: 123.81s	Train loss: 0.2637	Val loss: 0.2496	Val bias:815.1892	Val Pearson correlation: 1.7027e-01	Val MeanMult: 2.5886
# Epoch: 5	Duration: 124.09s	Train loss: 0.2611	Val loss: 0.2475	Val bias:809.3001	Val Pearson correlation: 1.9986e-01	Val MeanMult: 2.5667
# Epoch: 6	Duration: 123.80s	Train loss: 0.2568	Val loss: 0.2430	Val bias:809.1863	Val Pearson correlation: 2.3193e-01	Val MeanMult: 2.5594
# Epoch: 7	Duration: 123.83s	Train loss: 0.2462	Val loss: 0.2344	Val bias:736.8735	Val Pearson correlation: 4.5970e-01	Val MeanMult: 2.3613
# Epoch: 8	Duration: 126.37s	Train loss: 0.2038	Val loss: 0.1935	Val bias:670.0381	Val Pearson correlation: 5.6070e-01	Val MeanMult: 2.1669
# Epoch: 9	Duration: 124.51s	Train loss: 0.1877	Val loss: 0.1831	Val bias:631.2676	Val Pearson correlation: 5.9710e-01	Val MeanMult: 2.0924
# Epoch: 10	Duration: 126.46s	Train loss: 0.1775	Val loss: 0.1686	Val bias:611.2140	Val Pearson correlation: 6.2012e-01	Val MeanMult: 2.0362
# Epoch: 11	Duration: 123.99s	Train loss: 0.1714	Val loss: 0.1593	Val bias:607.7754	Val Pearson correlation: 6.3204e-01	Val MeanMult: 2.0123
# Epoch: 12	Duration: 123.95s	Train loss: 0.1673	Val loss: 0.1601	Val bias:602.7296	Val Pearson correlation: 6.3790e-01	Val MeanMult: 1.9992
# Epoch: 13	Duration: 124.64s	Train loss: 0.1629	Val loss: 0.1576	Val bias:603.5947	Val Pearson correlation: 6.4112e-01	Val MeanMult: 1.9926
# Epoch: 14	Duration: 124.03s	Train loss: 0.1612	Val loss: 0.1543	Val bias:603.9415	Val Pearson correlation: 6.4317e-01	Val MeanMult: 1.9898
# Epoch: 15	Duration: 123.91s	Train loss: 0.1595	Val loss: 0.1538	Val bias:600.0659	Val Pearson correlation: 6.4643e-01	Val MeanMult: 1.9808
# Epoch: 16	Duration: 123.86s	Train loss: 0.1586	Val loss: 0.1529	Val bias:603.0435	Val Pearson correlation: 6.4630e-01	Val MeanMult: 1.9829
# Epoch: 17	Duration: 124.28s	Train loss: 0.1581	Val loss: 0.1533	Val bias:603.9580	Val Pearson correlation: 6.4842e-01	Val MeanMult: 1.9815
# Epoch: 18	Duration: 123.97s	Train loss: 0.1569	Val loss: 0.1509	Val bias:602.3660	Val Pearson correlation: 6.5067e-01	Val MeanMult: 1.9773
# Epoch: 19	Duration: 124.15s	Train loss: 0.1560	Val loss: 0.1548	Val bias:601.8588	Val Pearson correlation: 6.5261e-01	Val MeanMult: 1.9789
# Epoch: 20	Duration: 124.10s	Train loss: 0.1554	Val loss: 0.1535	Val bias:601.9346	Val Pearson correlation: 6.5215e-01	Val MeanMult: 1.9794
# Epoch: 21	Duration: 123.93s	Train loss: 0.1541	Val loss: 0.1545	Val bias:598.4890	Val Pearson correlation: 6.5574e-01	Val MeanMult: 1.9730
# Epoch: 22	Duration: 123.82s	Train loss: 0.1531	Val loss: 0.1574	Val bias:603.2186	Val Pearson correlation: 6.5761e-01	Val MeanMult: 1.9794
# Epoch: 23	Duration: 123.83s	Train loss: 0.1535	Val loss: 0.1509	Val bias:598.8392	Val Pearson correlation: 6.5751e-01	Val MeanMult: 1.9672
# Epoch: 24	Duration: 125.57s	Train loss: 0.1524	Val loss: 0.1540	Val bias:598.3573	Val Pearson correlation: 6.5946e-01	Val MeanMult: 1.9695
# Epoch: 25	Duration: 123.93s	Train loss: 0.1508	Val loss: 0.1612	Val bias:611.2326	Val Pearson correlation: 6.6173e-01	Val MeanMult: 1.9909
# Epoch: 26	Duration: 124.01s	Train loss: 0.1495	Val loss: 0.1558	Val bias:601.2365	Val Pearson correlation: 6.6295e-01	Val MeanMult: 1.9739
# Epoch: 27	Duration: 124.40s	Train loss: 0.1506	Val loss: 0.1529	Val bias:597.9122	Val Pearson correlation: 6.6684e-01	Val MeanMult: 1.9597
# Epoch: 28	Duration: 123.86s	Train loss: 0.1479	Val loss: 0.1556	Val bias:600.7844	Val Pearson correlation: 6.7020e-01	Val MeanMult: 1.9681
# Epoch: 29	Duration: 123.89s	Train loss: 0.1474	Val loss: 0.1488	Val bias:590.2022	Val Pearson correlation: 6.7476e-01	Val MeanMult: 1.9419
# Epoch: 30	Duration: 124.81s	Train loss: 0.1466	Val loss: 0.1497	Val bias:591.5857	Val Pearson correlation: 6.7768e-01	Val MeanMult: 1.9427
# Epoch: 31	Duration: 123.93s	Train loss: 0.1459	Val loss: 0.1494	Val bias:587.8654	Val Pearson correlation: 6.8233e-01	Val MeanMult: 1.9367
# Epoch: 32	Duration: 123.96s	Train loss: 0.1456	Val loss: 0.1467	Val bias:581.4892	Val Pearson correlation: 6.8524e-01	Val MeanMult: 1.9253
# Epoch: 33	Duration: 124.10s	Train loss: 0.1456	Val loss: 0.1461	Val bias:576.4428	Val Pearson correlation: 6.8929e-01	Val MeanMult: 1.9186
# Epoch: 34	Duration: 124.22s	Train loss: 0.1438	Val loss: 0.1489	Val bias:583.3321	Val Pearson correlation: 6.8947e-01	Val MeanMult: 1.9290
# Epoch: 35	Duration: 123.97s	Train loss: 0.1441	Val loss: 0.1480	Val bias:579.6918	Val Pearson correlation: 6.9282e-01	Val MeanMult: 1.9219
# Epoch: 36	Duration: 123.95s	Train loss: 0.1429	Val loss: 0.1424	Val bias:573.2646	Val Pearson correlation: 6.9442e-01	Val MeanMult: 1.9070
# Epoch: 37	Duration: 123.95s	Train loss: 0.1431	Val loss: 0.1487	Val bias:583.7736	Val Pearson correlation: 6.9628e-01	Val MeanMult: 1.9234
# Epoch: 38	Duration: 123.86s	Train loss: 0.1433	Val loss: 0.1422	Val bias:571.1295	Val Pearson correlation: 6.9698e-01	Val MeanMult: 1.9032
# Epoch: 39	Duration: 124.31s	Train loss: 0.1419	Val loss: 0.1455	Val bias:578.7854	Val Pearson correlation: 6.9840e-01	Val MeanMult: 1.9116
# Epoch: 40	Duration: 123.92s	Train loss: 0.1419	Val loss: 0.1401	Val bias:570.2271	Val Pearson correlation: 6.9998e-01	Val MeanMult: 1.8943
# Epoch: 41	Duration: 123.98s	Train loss: 0.1412	Val loss: 0.1454	Val bias:574.4534	Val Pearson correlation: 7.0049e-01	Val MeanMult: 1.9078
# Epoch: 42	Duration: 124.82s	Train loss: 0.1413	Val loss: 0.1412	Val bias:568.3015	Val Pearson correlation: 7.0068e-01	Val MeanMult: 1.8957
# Epoch: 43	Duration: 124.05s	Train loss: 0.1416	Val loss: 0.1456	Val bias:576.5331	Val Pearson correlation: 7.0157e-01	Val MeanMult: 1.9085
# Epoch: 44	Duration: 123.88s	Train loss: 0.1417	Val loss: 0.1483	Val bias:585.1125	Val Pearson correlation: 7.0200e-01	Val MeanMult: 1.9183
# Epoch: 45	Duration: 124.32s	Train loss: 0.1416	Val loss: 0.1472	Val bias:584.2271	Val Pearson correlation: 7.0209e-01	Val MeanMult: 1.9155
# Epoch: 46	Duration: 126.37s	Train loss: 0.1404	Val loss: 0.1560	Val bias:604.0913	Val Pearson correlation: 7.0282e-01	Val MeanMult: 1.9501
# Epoch: 47	Duration: 124.02s	Train loss: 0.1411	Val loss: 0.1565	Val bias:606.2381	Val Pearson correlation: 7.0364e-01	Val MeanMult: 1.9514
# Epoch: 48	Duration: 124.06s	Train loss: 0.1402	Val loss: 0.1507	Val bias:587.3611	Val Pearson correlation: 7.0368e-01	Val MeanMult: 1.9264
# Epoch: 49	Duration: 123.91s	Train loss: 0.1396	Val loss: 0.1465	Val bias:580.1682	Val Pearson correlation: 7.0365e-01	Val MeanMult: 1.9114
# Epoch: 50	Duration: 123.83s	Train loss: 0.1399	Val loss: 0.1449	Val bias:579.6163	Val Pearson correlation: 7.0389e-01	Val MeanMult: 1.9083
# Epoch: 51	Duration: 123.98s	Train loss: 0.1400	Val loss: 0.1503	Val bias:588.4704	Val Pearson correlation: 7.0400e-01	Val MeanMult: 1.9257
# Epoch: 52	Duration: 123.89s	Train loss: 0.1392	Val loss: 0.1503	Val bias:592.0878	Val Pearson correlation: 7.0409e-01	Val MeanMult: 1.9282
# Epoch: 53	Duration: 123.88s	Train loss: 0.1394	Val loss: 0.1570	Val bias:609.3182	Val Pearson correlation: 7.0546e-01	Val MeanMult: 1.9523
# Epoch: 54	Duration: 123.92s	Train loss: 0.1386	Val loss: 0.1530	Val bias:601.3835	Val Pearson correlation: 7.0581e-01	Val MeanMult: 1.9368
# Epoch: 55	Duration: 124.58s	Train loss: 0.1393	Val loss: 0.1474	Val bias:579.0508	Val Pearson correlation: 7.0655e-01	Val MeanMult: 1.9118
# Epoch: 56	Duration: 123.84s	Train loss: 0.1381	Val loss: 0.1550	Val bias:605.9578	Val Pearson correlation: 7.0635e-01	Val MeanMult: 1.9451
# Epoch: 57	Duration: 124.00s	Train loss: 0.1386	Val loss: 0.1490	Val bias:587.7689	Val Pearson correlation: 7.0689e-01	Val MeanMult: 1.9199
# Epoch: 58	Duration: 124.87s	Train loss: 0.1378	Val loss: 0.1503	Val bias:592.3428	Val Pearson correlation: 7.0702e-01	Val MeanMult: 1.9238
# Epoch: 59	Duration: 124.25s	Train loss: 0.1383	Val loss: 0.1553	Val bias:605.7317	Val Pearson correlation: 7.0773e-01	Val MeanMult: 1.9438
# Epoch: 60	Duration: 123.87s	Train loss: 0.1383	Val loss: 0.1525	Val bias:601.3431	Val Pearson correlation: 7.0779e-01	Val MeanMult: 1.9354
# Epoch: 61	Duration: 123.92s	Train loss: 0.1387	Val loss: 0.1583	Val bias:617.5414	Val Pearson correlation: 7.0753e-01	Val MeanMult: 1.9607
# Epoch: 62	Duration: 124.95s	Train loss: 0.1375	Val loss: 0.1511	Val bias:598.8695	Val Pearson correlation: 7.0673e-01	Val MeanMult: 1.9301
# Epoch: 63	Duration: 123.98s	Train loss: 0.1376	Val loss: 0.1544	Val bias:601.8511	Val Pearson correlation: 7.0822e-01	Val MeanMult: 1.9411
# Epoch: 64	Duration: 124.50s	Train loss: 0.1378	Val loss: 0.1557	Val bias:607.7715	Val Pearson correlation: 7.0777e-01	Val MeanMult: 1.9474
# Epoch: 65	Duration: 123.95s	Train loss: 0.1385	Val loss: 0.1488	Val bias:587.4538	Val Pearson correlation: 7.0749e-01	Val MeanMult: 1.9208
# Epoch: 66	Duration: 124.08s	Train loss: 0.1365	Val loss: 0.1549	Val bias:604.6248	Val Pearson correlation: 7.0838e-01	Val MeanMult: 1.9438
# Epoch: 67	Duration: 125.58s	Train loss: 0.1379	Val loss: 0.1515	Val bias:597.7933	Val Pearson correlation: 7.0785e-01	Val MeanMult: 1.9312
# Epoch: 68	Duration: 124.02s	Train loss: 0.1377	Val loss: 0.1515	Val bias:599.7948	Val Pearson correlation: 7.0793e-01	Val MeanMult: 1.9336
# Epoch: 69	Duration: 124.70s	Train loss: 0.1375	Val loss: 0.1539	Val bias:600.0431	Val Pearson correlation: 7.0968e-01	Val MeanMult: 1.9382
# Epoch: 70	Duration: 123.98s	Train loss: 0.1370	Val loss: 0.1530	Val bias:603.7276	Val Pearson correlation: 7.0898e-01	Val MeanMult: 1.9381
# Epoch: 71	Duration: 124.03s	Train loss: 0.1368	Val loss: 0.1498	Val bias:593.6084	Val Pearson correlation: 7.0787e-01	Val MeanMult: 1.9244
# Epoch: 72	Duration: 126.61s	Train loss: 0.1368	Val loss: 0.1525	Val bias:600.2784	Val Pearson correlation: 7.0889e-01	Val MeanMult: 1.9359
# Epoch: 73	Duration: 124.45s	Train loss: 0.1377	Val loss: 0.1581	Val bias:622.6815	Val Pearson correlation: 7.0840e-01	Val MeanMult: 1.9625
# Epoch: 74	Duration: 124.06s	Train loss: 0.1367	Val loss: 0.1553	Val bias:616.6672	Val Pearson correlation: 7.0835e-01	Val MeanMult: 1.9525
# Epoch: 75	Duration: 123.93s	Train loss: 0.1369	Val loss: 0.1505	Val bias:599.3485	Val Pearson correlation: 7.0899e-01	Val MeanMult: 1.9291
# Epoch: 76	Duration: 123.89s	Train loss: 0.1371	Val loss: 0.1592	Val bias:622.0954	Val Pearson correlation: 7.0999e-01	Val MeanMult: 1.9637
# Epoch: 77	Duration: 123.94s	Train loss: 0.1361	Val loss: 0.1557	Val bias:613.9615	Val Pearson correlation: 7.0983e-01	Val MeanMult: 1.9494
# Epoch: 78	Duration: 124.33s	Train loss: 0.1366	Val loss: 0.1349	Val bias:561.1296	Val Pearson correlation: 7.0882e-01	Val MeanMult: 1.8728
# Epoch: 79	Duration: 125.03s	Train loss: 0.1366	Val loss: 0.1515	Val bias:594.7510	Val Pearson correlation: 7.0977e-01	Val MeanMult: 1.9293
# Epoch: 80	Duration: 124.05s	Train loss: 0.1356	Val loss: 0.1539	Val bias:601.6668	Val Pearson correlation: 7.1087e-01	Val MeanMult: 1.9386
# Epoch: 81	Duration: 123.95s	Train loss: 0.1370	Val loss: 0.1550	Val bias:610.4788	Val Pearson correlation: 7.0996e-01	Val MeanMult: 1.9458
# Epoch: 82	Duration: 124.20s	Train loss: 0.1358	Val loss: 0.1493	Val bias:597.5083	Val Pearson correlation: 7.1052e-01	Val MeanMult: 1.9221
# Epoch: 83	Duration: 124.48s	Train loss: 0.1362	Val loss: 0.1604	Val bias:628.2978	Val Pearson correlation: 7.1007e-01	Val MeanMult: 1.9720
# Epoch: 84	Duration: 123.92s	Train loss: 0.1367	Val loss: 0.1581	Val bias:620.1431	Val Pearson correlation: 7.1032e-01	Val MeanMult: 1.9576
# Epoch: 85	Duration: 124.01s	Train loss: 0.1363	Val loss: 0.1537	Val bias:605.5570	Val Pearson correlation: 7.1098e-01	Val MeanMult: 1.9379
# Epoch: 86	Duration: 124.00s	Train loss: 0.1361	Val loss: 0.1496	Val bias:593.0069	Val Pearson correlation: 7.1088e-01	Val MeanMult: 1.9221
# Epoch: 87	Duration: 123.96s	Train loss: 0.1359	Val loss: 0.1541	Val bias:605.4020	Val Pearson correlation: 7.1123e-01	Val MeanMult: 1.9387
# Epoch: 88	Duration: 124.07s	Train loss: 0.1360	Val loss: 0.1496	Val bias:598.8309	Val Pearson correlation: 7.1009e-01	Val MeanMult: 1.9237
# Epoch: 89	Duration: 123.93s	Train loss: 0.1348	Val loss: 0.1506	Val bias:596.4509	Val Pearson correlation: 7.1046e-01	Val MeanMult: 1.9254
# Epoch: 90	Duration: 123.82s	Train loss: 0.1359	Val loss: 0.1542	Val bias:607.9891	Val Pearson correlation: 7.1071e-01	Val MeanMult: 1.9428
# Epoch: 91	Duration: 125.38s	Train loss: 0.1360	Val loss: 0.1535	Val bias:611.0171	Val Pearson correlation: 7.1032e-01	Val MeanMult: 1.9407
# Epoch: 92	Duration: 124.20s	Train loss: 0.1353	Val loss: 0.1507	Val bias:601.1098	Val Pearson correlation: 7.1048e-01	Val MeanMult: 1.9274
# Epoch: 93	Duration: 126.50s	Train loss: 0.1352	Val loss: 0.1548	Val bias:614.7961	Val Pearson correlation: 7.1121e-01	Val MeanMult: 1.9466
# Epoch: 94	Duration: 126.38s	Train loss: 0.1359	Val loss: 0.1551	Val bias:617.0729	Val Pearson correlation: 7.1090e-01	Val MeanMult: 1.9476
# Epoch: 95	Duration: 124.44s	Train loss: 0.1360	Val loss: 0.1473	Val bias:597.0008	Val Pearson correlation: 7.1141e-01	Val MeanMult: 1.9139
# Epoch: 96	Duration: 123.95s	Train loss: 0.1350	Val loss: 0.1538	Val bias:609.9717	Val Pearson correlation: 7.1306e-01	Val MeanMult: 1.9385
# Epoch: 97	Duration: 124.03s	Train loss: 0.1348	Val loss: 0.1514	Val bias:603.6857	Val Pearson correlation: 7.1352e-01	Val MeanMult: 1.9299
# Epoch: 98	Duration: 125.35s	Train loss: 0.1355	Val loss: 0.1514	Val bias:596.4856	Val Pearson correlation: 7.1350e-01	Val MeanMult: 1.9267
# Epoch: 99	Duration: 123.92s	Train loss: 0.1340	Val loss: 0.1551	Val bias:616.1165	Val Pearson correlation: 7.1361e-01	Val MeanMult: 1.9429
# Epoch: 100	Duration: 123.90s	Train loss: 0.1338	Val loss: 0.1452	Val bias:581.1791	Val Pearson correlation: 7.1427e-01	Val MeanMult: 1.8996
# Epoch: 101	Duration: 123.90s	Train loss: 0.1331	Val loss: 0.1536	Val bias:604.5352	Val Pearson correlation: 7.1392e-01	Val MeanMult: 1.9364
# Epoch: 102	Duration: 124.53s	Train loss: 0.1346	Val loss: 0.1566	Val bias:618.9313	Val Pearson correlation: 7.1475e-01	Val MeanMult: 1.9492
# Epoch: 103	Duration: 126.47s	Train loss: 0.1341	Val loss: 0.1552	Val bias:616.5410	Val Pearson correlation: 7.1425e-01	Val MeanMult: 1.9462
# Epoch: 104	Duration: 123.94s	Train loss: 0.1342	Val loss: 0.1518	Val bias:607.3342	Val Pearson correlation: 7.1420e-01	Val MeanMult: 1.9330
# Epoch: 105	Duration: 123.92s	Train loss: 0.1337	Val loss: 0.1532	Val bias:604.2347	Val Pearson correlation: 7.1416e-01	Val MeanMult: 1.9350
# Epoch: 106	Duration: 126.62s	Train loss: 0.1337	Val loss: 0.1573	Val bias:623.8774	Val Pearson correlation: 7.1451e-01	Val MeanMult: 1.9565
# Epoch: 107	Duration: 124.19s	Train loss: 0.1339	Val loss: 0.1490	Val bias:598.2648	Val Pearson correlation: 7.1419e-01	Val MeanMult: 1.9197
# Epoch: 108	Duration: 124.13s	Train loss: 0.1338	Val loss: 0.1473	Val bias:589.5686	Val Pearson correlation: 7.1385e-01	Val MeanMult: 1.9130
# Epoch: 109	Duration: 124.52s	Train loss: 0.1334	Val loss: 0.1483	Val bias:594.0079	Val Pearson correlation: 7.1351e-01	Val MeanMult: 1.9147
# Epoch: 110	Duration: 123.95s	Train loss: 0.1334	Val loss: 0.1508	Val bias:600.0695	Val Pearson correlation: 7.1372e-01	Val MeanMult: 1.9248
# Epoch: 111	Duration: 124.38s	Train loss: 0.1336	Val loss: 0.1568	Val bias:625.1195	Val Pearson correlation: 7.1369e-01	Val MeanMult: 1.9543
# Epoch: 112	Duration: 126.38s	Train loss: 0.1340	Val loss: 0.1513	Val bias:595.4774	Val Pearson correlation: 7.1499e-01	Val MeanMult: 1.9223
# Epoch: 113	Duration: 126.60s	Train loss: 0.1335	Val loss: 0.1482	Val bias:592.5541	Val Pearson correlation: 7.1434e-01	Val MeanMult: 1.9147
# Epoch: 114	Duration: 124.38s	Train loss: 0.1335	Val loss: 0.1521	Val bias:608.0125	Val Pearson correlation: 7.1406e-01	Val MeanMult: 1.9329
# Epoch: 115	Duration: 123.99s	Train loss: 0.1337	Val loss: 0.1517	Val bias:605.1142	Val Pearson correlation: 7.1420e-01	Val MeanMult: 1.9306
# Epoch: 116	Duration: 124.64s	Train loss: 0.1338	Val loss: 0.1531	Val bias:601.3636	Val Pearson correlation: 7.1523e-01	Val MeanMult: 1.9313
# Epoch: 117	Duration: 126.45s	Train loss: 0.1338	Val loss: 0.1509	Val bias:606.2160	Val Pearson correlation: 7.1428e-01	Val MeanMult: 1.9282
# Epoch: 118	Duration: 125.55s	Train loss: 0.1333	Val loss: 0.1513	Val bias:597.0715	Val Pearson correlation: 7.1411e-01	Val MeanMult: 1.9255
# Epoch: 119	Duration: 124.21s	Train loss: 0.1332	Val loss: 0.1561	Val bias:618.2399	Val Pearson correlation: 7.1450e-01	Val MeanMult: 1.9483
# Epoch: 120	Duration: 123.93s	Train loss: 0.1338	Val loss: 0.1483	Val bias:596.5008	Val Pearson correlation: 7.1464e-01	Val MeanMult: 1.9157
# Epoch: 121	Duration: 123.93s	Train loss: 0.1343	Val loss: 0.1548	Val bias:607.2784	Val Pearson correlation: 7.1474e-01	Val MeanMult: 1.9405
# Epoch: 122	Duration: 124.06s	Train loss: 0.1326	Val loss: 0.1478	Val bias:590.9613	Val Pearson correlation: 7.1481e-01	Val MeanMult: 1.9105
# Epoch: 123	Duration: 124.14s	Train loss: 0.1335	Val loss: 0.1545	Val bias:607.3919	Val Pearson correlation: 7.1436e-01	Val MeanMult: 1.9416
# Epoch: 124	Duration: 124.29s	Train loss: 0.1341	Val loss: 0.1546	Val bias:608.9850	Val Pearson correlation: 7.1487e-01	Val MeanMult: 1.9406
# Epoch: 125	Duration: 124.20s	Train loss: 0.1340	Val loss: 0.1509	Val bias:607.4699	Val Pearson correlation: 7.1391e-01	Val MeanMult: 1.9302
# Epoch: 126	Duration: 123.96s	Train loss: 0.1341	Val loss: 0.1565	Val bias:617.3501	Val Pearson correlation: 7.1467e-01	Val MeanMult: 1.9505
# Epoch: 127	Duration: 124.12s	Train loss: 0.1332	Val loss: 0.1503	Val bias:602.1739	Val Pearson correlation: 7.1460e-01	Val MeanMult: 1.9229
# Epoch: 128	Duration: 124.23s	Train loss: 0.1326	Val loss: 0.1580	Val bias:625.1586	Val Pearson correlation: 7.1471e-01	Val MeanMult: 1.9593
# Epoch: 129	Duration: 123.96s	Train loss: 0.1337	Val loss: 0.1539	Val bias:608.5526	Val Pearson correlation: 7.1477e-01	Val MeanMult: 1.9379
# Epoch: 130	Duration: 123.89s	Train loss: 0.1326	Val loss: 0.1511	Val bias:602.1250	Val Pearson correlation: 7.1448e-01	Val MeanMult: 1.9278
# Epoch: 131	Duration: 123.90s	Train loss: 0.1323	Val loss: 0.1525	Val bias:609.0873	Val Pearson correlation: 7.1442e-01	Val MeanMult: 1.9355
# Epoch: 132	Duration: 123.99s	Train loss: 0.1345	Val loss: 0.1559	Val bias:614.9013	Val Pearson correlation: 7.1489e-01	Val MeanMult: 1.9476
# Epoch: 133	Duration: 124.01s	Train loss: 0.1333	Val loss: 0.1492	Val bias:595.7007	Val Pearson correlation: 7.1470e-01	Val MeanMult: 1.9191
# Epoch: 134	Duration: 123.95s	Train loss: 0.1323	Val loss: 0.1492	Val bias:596.3465	Val Pearson correlation: 7.1484e-01	Val MeanMult: 1.9173
# Epoch: 135	Duration: 124.66s	Train loss: 0.1332	Val loss: 0.1525	Val bias:605.4336	Val Pearson correlation: 7.1424e-01	Val MeanMult: 1.9332
# Epoch: 136	Duration: 124.02s	Train loss: 0.1328	Val loss: 0.1464	Val bias:584.6432	Val Pearson correlation: 7.1415e-01	Val MeanMult: 1.9060
# Epoch: 137	Duration: 123.93s	Train loss: 0.1333	Val loss: 0.1493	Val bias:598.4117	Val Pearson correlation: 7.1408e-01	Val MeanMult: 1.9190
# Epoch: 138	Duration: 123.94s	Train loss: 0.1342	Val loss: 0.1643	Val bias:642.8996	Val Pearson correlation: 7.1489e-01	Val MeanMult: 1.9860
# Epoch: 139	Duration: 123.92s	Train loss: 0.1337	Val loss: 0.1603	Val bias:632.5163	Val Pearson correlation: 7.1466e-01	Val MeanMult: 1.9690
# Epoch: 140	Duration: 124.03s	Train loss: 0.1337	Val loss: 0.1573	Val bias:620.9550	Val Pearson correlation: 7.1443e-01	Val MeanMult: 1.9550
# Epoch: 141	Duration: 123.99s	Train loss: 0.1335	Val loss: 0.1573	Val bias:620.4990	Val Pearson correlation: 7.1516e-01	Val MeanMult: 1.9552
# Epoch: 142	Duration: 124.00s	Train loss: 0.1330	Val loss: 0.1479	Val bias:590.3029	Val Pearson correlation: 7.1478e-01	Val MeanMult: 1.9129
# Epoch: 143	Duration: 124.11s	Train loss: 0.1323	Val loss: 0.1557	Val bias:616.4076	Val Pearson correlation: 7.1458e-01	Val MeanMult: 1.9488
# Epoch: 144	Duration: 124.02s	Train loss: 0.1336	Val loss: 0.1503	Val bias:597.0054	Val Pearson correlation: 7.1576e-01	Val MeanMult: 1.9217
# Epoch: 145	Duration: 124.07s	Train loss: 0.1330	Val loss: 0.1569	Val bias:626.6633	Val Pearson correlation: 7.1452e-01	Val MeanMult: 1.9566
# Epoch: 146	Duration: 124.52s	Train loss: 0.1325	Val loss: 0.1499	Val bias:598.0719	Val Pearson correlation: 7.1406e-01	Val MeanMult: 1.9220
# Epoch: 147	Duration: 125.11s	Train loss: 0.1332	Val loss: 0.1482	Val bias:591.9710	Val Pearson correlation: 7.1484e-01	Val MeanMult: 1.9143
# Epoch: 148	Duration: 123.94s	Train loss: 0.1325	Val loss: 0.1468	Val bias:590.7232	Val Pearson correlation: 7.1486e-01	Val MeanMult: 1.9090
# Epoch: 149	Duration: 124.02s	Train loss: 0.1336	Val loss: 0.1514	Val bias:600.9140	Val Pearson correlation: 7.1464e-01	Val MeanMult: 1.9282
# Epoch: 150	Duration: 124.02s	Train loss: 0.1332	Val loss: 0.1537	Val bias:605.7979	Val Pearson correlation: 7.1454e-01	Val MeanMult: 1.9364
# Epoch: 151	Duration: 124.10s	Train loss: 0.1325	Val loss: 0.1498	Val bias:596.3233	Val Pearson correlation: 7.1491e-01	Val MeanMult: 1.9216
# Epoch: 152	Duration: 124.11s	Train loss: 0.1334	Val loss: 0.1506	Val bias:603.2152	Val Pearson correlation: 7.1490e-01	Val MeanMult: 1.9255
# Epoch: 153	Duration: 123.96s	Train loss: 0.1337	Val loss: 0.1544	Val bias:610.9894	Val Pearson correlation: 7.1503e-01	Val MeanMult: 1.9425
# Epoch: 154	Duration: 124.27s	Train loss: 0.1331	Val loss: 0.1527	Val bias:611.9264	Val Pearson correlation: 7.1448e-01	Val MeanMult: 1.9365
# Epoch: 155	Duration: 123.96s	Train loss: 0.1329	Val loss: 0.1555	Val bias:615.2189	Val Pearson correlation: 7.1530e-01	Val MeanMult: 1.9451
# Epoch: 156	Duration: 123.91s	Train loss: 0.1331	Val loss: 0.1567	Val bias:624.6844	Val Pearson correlation: 7.1435e-01	Val MeanMult: 1.9560
# Epoch: 157	Duration: 123.89s	Train loss: 0.1321	Val loss: 0.1464	Val bias:587.5708	Val Pearson correlation: 7.1535e-01	Val MeanMult: 1.9070
# Epoch: 158	Duration: 124.30s	Train loss: 0.1327	Val loss: 0.1532	Val bias:599.4607	Val Pearson correlation: 7.1580e-01	Val MeanMult: 1.9324
# Epoch: 159	Duration: 124.01s	Train loss: 0.1328	Val loss: 0.1500	Val bias:593.2694	Val Pearson correlation: 7.1510e-01	Val MeanMult: 1.9203
# Epoch: 160	Duration: 124.02s	Train loss: 0.1333	Val loss: 0.1445	Val bias:581.0577	Val Pearson correlation: 7.1515e-01	Val MeanMult: 1.8993
# Epoch: 161	Duration: 124.03s	Train loss: 0.1331	Val loss: 0.1504	Val bias:589.1848	Val Pearson correlation: 7.1569e-01	Val MeanMult: 1.9182
# Epoch: 162	Duration: 123.97s	Train loss: 0.1329	Val loss: 0.1544	Val bias:614.0129	Val Pearson correlation: 7.1471e-01	Val MeanMult: 1.9404
# Epoch: 163	Duration: 123.82s	Train loss: 0.1331	Val loss: 0.1571	Val bias:619.9857	Val Pearson correlation: 7.1537e-01	Val MeanMult: 1.9531
# Epoch: 164	Duration: 123.96s	Train loss: 0.1330	Val loss: 0.1510	Val bias:596.2967	Val Pearson correlation: 7.1521e-01	Val MeanMult: 1.9258
# Epoch: 165	Duration: 124.16s	Train loss: 0.1323	Val loss: 0.1512	Val bias:598.3383	Val Pearson correlation: 7.1573e-01	Val MeanMult: 1.9259
# Epoch: 166	Duration: 124.70s	Train loss: 0.1328	Val loss: 0.1502	Val bias:598.1900	Val Pearson correlation: 7.1557e-01	Val MeanMult: 1.9210
# Epoch: 167	Duration: 126.51s	Train loss: 0.1333	Val loss: 0.1529	Val bias:607.5250	Val Pearson correlation: 7.1499e-01	Val MeanMult: 1.9360
# Epoch: 168	Duration: 123.95s	Train loss: 0.1334	Val loss: 0.1586	Val bias:621.1477	Val Pearson correlation: 7.1522e-01	Val MeanMult: 1.9587
# Epoch: 169	Duration: 124.14s	Train loss: 0.1330	Val loss: 0.1582	Val bias:620.2177	Val Pearson correlation: 7.1568e-01	Val MeanMult: 1.9557
# Epoch: 170	Duration: 123.95s	Train loss: 0.1326	Val loss: 0.1474	Val bias:587.4660	Val Pearson correlation: 7.1581e-01	Val MeanMult: 1.9068
# Epoch: 171	Duration: 124.63s	Train loss: 0.1322	Val loss: 0.1506	Val bias:601.6086	Val Pearson correlation: 7.1567e-01	Val MeanMult: 1.9245
# Epoch: 172	Duration: 123.94s	Train loss: 0.1326	Val loss: 0.1472	Val bias:587.0554	Val Pearson correlation: 7.1498e-01	Val MeanMult: 1.9094
# Epoch: 173	Duration: 124.03s	Train loss: 0.1325	Val loss: 0.1503	Val bias:597.9896	Val Pearson correlation: 7.1525e-01	Val MeanMult: 1.9216
# Epoch: 174	Duration: 124.08s	Train loss: 0.1327	Val loss: 0.1511	Val bias:596.9570	Val Pearson correlation: 7.1632e-01	Val MeanMult: 1.9240
# Epoch: 175	Duration: 125.62s	Train loss: 0.1324	Val loss: 0.1445	Val bias:582.4857	Val Pearson correlation: 7.1585e-01	Val MeanMult: 1.9004
# Epoch: 176	Duration: 123.95s	Train loss: 0.1331	Val loss: 0.1556	Val bias:610.3970	Val Pearson correlation: 7.1574e-01	Val MeanMult: 1.9436
# Epoch: 177	Duration: 124.08s	Train loss: 0.1331	Val loss: 0.1496	Val bias:594.4490	Val Pearson correlation: 7.1585e-01	Val MeanMult: 1.9183
# Epoch: 178	Duration: 123.84s	Train loss: 0.1327	Val loss: 0.1523	Val bias:595.2958	Val Pearson correlation: 7.1602e-01	Val MeanMult: 1.9280
# Epoch: 179	Duration: 124.04s	Train loss: 0.1340	Val loss: 0.1485	Val bias:589.1482	Val Pearson correlation: 7.1686e-01	Val MeanMult: 1.9110
# Epoch: 180	Duration: 126.25s	Train loss: 0.1322	Val loss: 0.1505	Val bias:596.2259	Val Pearson correlation: 7.1582e-01	Val MeanMult: 1.9226
# Epoch: 181	Duration: 123.96s	Train loss: 0.1319	Val loss: 0.1509	Val bias:602.4511	Val Pearson correlation: 7.1600e-01	Val MeanMult: 1.9253
# Epoch: 182	Duration: 124.07s	Train loss: 0.1332	Val loss: 0.1556	Val bias:612.7374	Val Pearson correlation: 7.1598e-01	Val MeanMult: 1.9440
# Epoch: 183	Duration: 126.44s	Train loss: 0.1329	Val loss: 0.1496	Val bias:599.4320	Val Pearson correlation: 7.1533e-01	Val MeanMult: 1.9213
# Epoch: 184	Duration: 124.08s	Train loss: 0.1319	Val loss: 0.1541	Val bias:608.9638	Val Pearson correlation: 7.1627e-01	Val MeanMult: 1.9388
# Epoch: 185	Duration: 125.04s	Train loss: 0.1321	Val loss: 0.1472	Val bias:588.0241	Val Pearson correlation: 7.1522e-01	Val MeanMult: 1.9112
# Epoch: 186	Duration: 123.91s	Train loss: 0.1325	Val loss: 0.1519	Val bias:600.5525	Val Pearson correlation: 7.1657e-01	Val MeanMult: 1.9291
# Epoch: 187	Duration: 124.29s	Train loss: 0.1315	Val loss: 0.1485	Val bias:590.9828	Val Pearson correlation: 7.1675e-01	Val MeanMult: 1.9124
# Epoch: 188	Duration: 124.19s	Train loss: 0.1325	Val loss: 0.1546	Val bias:609.8287	Val Pearson correlation: 7.1604e-01	Val MeanMult: 1.9415
# Epoch: 189	Duration: 124.73s	Train loss: 0.1322	Val loss: 0.1584	Val bias:623.1941	Val Pearson correlation: 7.1592e-01	Val MeanMult: 1.9581
# Epoch: 190	Duration: 124.06s	Train loss: 0.1324	Val loss: 0.1479	Val bias:589.5795	Val Pearson correlation: 7.1642e-01	Val MeanMult: 1.9103
# Epoch: 191	Duration: 123.89s	Train loss: 0.1326	Val loss: 0.1460	Val bias:581.9321	Val Pearson correlation: 7.1630e-01	Val MeanMult: 1.9023
# Epoch: 192	Duration: 124.08s	Train loss: 0.1335	Val loss: 0.1609	Val bias:629.8881	Val Pearson correlation: 7.1619e-01	Val MeanMult: 1.9690
# Epoch: 193	Duration: 124.72s	Train loss: 0.1327	Val loss: 0.1528	Val bias:596.0984	Val Pearson correlation: 7.1698e-01	Val MeanMult: 1.9279
# Epoch: 194	Duration: 124.15s	Train loss: 0.1330	Val loss: 0.1504	Val bias:591.1956	Val Pearson correlation: 7.1670e-01	Val MeanMult: 1.9197
# Epoch: 195	Duration: 124.14s	Train loss: 0.1328	Val loss: 0.1472	Val bias:586.6303	Val Pearson correlation: 7.1673e-01	Val MeanMult: 1.9083
# Epoch: 196	Duration: 124.31s	Train loss: 0.1322	Val loss: 0.1470	Val bias:583.6370	Val Pearson correlation: 7.1658e-01	Val MeanMult: 1.9054
# Epoch: 197	Duration: 126.42s	Train loss: 0.1325	Val loss: 0.1489	Val bias:593.0350	Val Pearson correlation: 7.1700e-01	Val MeanMult: 1.9157
# Epoch: 198	Duration: 124.01s	Train loss: 0.1323	Val loss: 0.1461	Val bias:581.1923	Val Pearson correlation: 7.1697e-01	Val MeanMult: 1.9020
# Epoch: 199	Duration: 124.03s	Train loss: 0.1329	Val loss: 0.1443	Val bias:577.4911	Val Pearson correlation: 7.1692e-01	Val MeanMult: 1.8954
# Epoch: 200	Duration: 124.44s	Train loss: 0.1326	Val loss: 0.1441	Val bias:578.3314	Val Pearson correlation: 7.1576e-01	Val MeanMult: 1.8968
# Epoch: 201	Duration: 124.06s	Train loss: 0.1324	Val loss: 0.1497	Val bias:591.7459	Val Pearson correlation: 7.1675e-01	Val MeanMult: 1.9178
# Epoch: 202	Duration: 124.99s	Train loss: 0.1329	Val loss: 0.1484	Val bias:588.9453	Val Pearson correlation: 7.1724e-01	Val MeanMult: 1.9127
# Epoch: 203	Duration: 123.85s	Train loss: 0.1323	Val loss: 0.1512	Val bias:599.9079	Val Pearson correlation: 7.1743e-01	Val MeanMult: 1.9245
# Epoch: 204	Duration: 123.99s	Train loss: 0.1325	Val loss: 0.1513	Val bias:596.2642	Val Pearson correlation: 7.1800e-01	Val MeanMult: 1.9242
# Epoch: 205	Duration: 124.05s	Train loss: 0.1334	Val loss: 0.1490	Val bias:589.6353	Val Pearson correlation: 7.1769e-01	Val MeanMult: 1.9138
# Epoch: 206	Duration: 124.00s	Train loss: 0.1324	Val loss: 0.1555	Val bias:612.1359	Val Pearson correlation: 7.1697e-01	Val MeanMult: 1.9437
# Epoch: 207	Duration: 124.12s	Train loss: 0.1317	Val loss: 0.1507	Val bias:595.3286	Val Pearson correlation: 7.1728e-01	Val MeanMult: 1.9236
# Epoch: 208	Duration: 123.91s	Train loss: 0.1336	Val loss: 0.1440	Val bias:572.8050	Val Pearson correlation: 7.1748e-01	Val MeanMult: 1.8925
# Epoch: 209	Duration: 124.17s	Train loss: 0.1312	Val loss: 0.1448	Val bias:581.7566	Val Pearson correlation: 7.1683e-01	Val MeanMult: 1.8989
# Epoch: 210	Duration: 124.46s	Train loss: 0.1321	Val loss: 0.1540	Val bias:610.8521	Val Pearson correlation: 7.1698e-01	Val MeanMult: 1.9395
# Epoch: 211	Duration: 124.76s	Train loss: 0.1317	Val loss: 0.1487	Val bias:589.7821	Val Pearson correlation: 7.1775e-01	Val MeanMult: 1.9124
# Epoch: 212	Duration: 123.96s	Train loss: 0.1324	Val loss: 0.1517	Val bias:597.1624	Val Pearson correlation: 7.1845e-01	Val MeanMult: 1.9255
# Epoch: 213	Duration: 123.89s	Train loss: 0.1316	Val loss: 0.1457	Val bias:580.3119	Val Pearson correlation: 7.1837e-01	Val MeanMult: 1.8997
# Epoch: 214	Duration: 124.47s	Train loss: 0.1321	Val loss: 0.1487	Val bias:587.7066	Val Pearson correlation: 7.1851e-01	Val MeanMult: 1.9137
# Epoch: 215	Duration: 124.06s	Train loss: 0.1329	Val loss: 0.1509	Val bias:598.9279	Val Pearson correlation: 7.1905e-01	Val MeanMult: 1.9246
# Epoch: 216	Duration: 126.08s	Train loss: 0.1313	Val loss: 0.1422	Val bias:571.4954	Val Pearson correlation: 7.1954e-01	Val MeanMult: 1.8868
# Epoch: 217	Duration: 123.91s	Train loss: 0.1324	Val loss: 0.1427	Val bias:575.3868	Val Pearson correlation: 7.1997e-01	Val MeanMult: 1.8889
# Epoch: 218	Duration: 123.95s	Train loss: 0.1316	Val loss: 0.1474	Val bias:586.7966	Val Pearson correlation: 7.1994e-01	Val MeanMult: 1.9063
# Epoch: 219	Duration: 124.21s	Train loss: 0.1327	Val loss: 0.1522	Val bias:599.1359	Val Pearson correlation: 7.1969e-01	Val MeanMult: 1.9268
# Epoch: 220	Duration: 124.05s	Train loss: 0.1319	Val loss: 0.1489	Val bias:592.0744	Val Pearson correlation: 7.1934e-01	Val MeanMult: 1.9143
# Epoch: 221	Duration: 123.98s	Train loss: 0.1317	Val loss: 0.1516	Val bias:601.9758	Val Pearson correlation: 7.2024e-01	Val MeanMult: 1.9256
# Epoch: 222	Duration: 124.02s	Train loss: 0.1314	Val loss: 0.1477	Val bias:590.2579	Val Pearson correlation: 7.2009e-01	Val MeanMult: 1.9100
# Epoch: 223	Duration: 124.04s	Train loss: 0.1318	Val loss: 0.1538	Val bias:608.5562	Val Pearson correlation: 7.2006e-01	Val MeanMult: 1.9373
# Epoch: 224	Duration: 125.93s	Train loss: 0.1315	Val loss: 0.1518	Val bias:600.7646	Val Pearson correlation: 7.2100e-01	Val MeanMult: 1.9268
# Epoch: 225	Duration: 124.83s	Train loss: 0.1318	Val loss: 0.1490	Val bias:592.3072	Val Pearson correlation: 7.2136e-01	Val MeanMult: 1.9142
# Epoch: 226	Duration: 126.36s	Train loss: 0.1317	Val loss: 0.1478	Val bias:591.9464	Val Pearson correlation: 7.2153e-01	Val MeanMult: 1.9091
# Epoch: 227	Duration: 124.57s	Train loss: 0.1314	Val loss: 0.1509	Val bias:597.5913	Val Pearson correlation: 7.2188e-01	Val MeanMult: 1.9209
# Epoch: 228	Duration: 123.92s	Train loss: 0.1318	Val loss: 0.1480	Val bias:592.6769	Val Pearson correlation: 7.2242e-01	Val MeanMult: 1.9100
# Epoch: 229	Duration: 125.29s	Train loss: 0.1308	Val loss: 0.1467	Val bias:592.6850	Val Pearson correlation: 7.2186e-01	Val MeanMult: 1.9072
# Epoch: 230	Duration: 124.06s	Train loss: 0.1304	Val loss: 0.1406	Val bias:569.5635	Val Pearson correlation: 7.2260e-01	Val MeanMult: 1.8789
# Epoch: 231	Duration: 123.94s	Train loss: 0.1309	Val loss: 0.1399	Val bias:569.4711	Val Pearson correlation: 7.2280e-01	Val MeanMult: 1.8758
# Epoch: 232	Duration: 123.89s	Train loss: 0.1307	Val loss: 0.1439	Val bias:578.3227	Val Pearson correlation: 7.2367e-01	Val MeanMult: 1.8924
# Epoch: 233	Duration: 125.07s	Train loss: 0.1307	Val loss: 0.1464	Val bias:586.2113	Val Pearson correlation: 7.2353e-01	Val MeanMult: 1.9029
# Epoch: 234	Duration: 124.07s	Train loss: 0.1307	Val loss: 0.1419	Val bias:569.0428	Val Pearson correlation: 7.2402e-01	Val MeanMult: 1.8819
# Epoch: 235	Duration: 124.21s	Train loss: 0.1304	Val loss: 0.1395	Val bias:565.5251	Val Pearson correlation: 7.2486e-01	Val MeanMult: 1.8716
# Epoch: 236	Duration: 124.05s	Train loss: 0.1308	Val loss: 0.1450	Val bias:582.1145	Val Pearson correlation: 7.2459e-01	Val MeanMult: 1.8961
# Epoch: 237	Duration: 123.96s	Train loss: 0.1295	Val loss: 0.1457	Val bias:583.6744	Val Pearson correlation: 7.2491e-01	Val MeanMult: 1.8994
# Epoch: 238	Duration: 123.93s	Train loss: 0.1303	Val loss: 0.1369	Val bias:561.4551	Val Pearson correlation: 7.2495e-01	Val MeanMult: 1.8637
# Epoch: 239	Duration: 125.01s	Train loss: 0.1300	Val loss: 0.1479	Val bias:589.8529	Val Pearson correlation: 7.2551e-01	Val MeanMult: 1.9085
# Epoch: 240	Duration: 124.38s	Train loss: 0.1299	Val loss: 0.1372	Val bias:560.0611	Val Pearson correlation: 7.2525e-01	Val MeanMult: 1.8636
# Epoch: 241	Duration: 124.01s	Train loss: 0.1301	Val loss: 0.1386	Val bias:564.3682	Val Pearson correlation: 7.2525e-01	Val MeanMult: 1.8708
# Epoch: 242	Duration: 123.88s	Train loss: 0.1311	Val loss: 0.1415	Val bias:569.4650	Val Pearson correlation: 7.2543e-01	Val MeanMult: 1.8799
# Epoch: 243	Duration: 124.09s	Train loss: 0.1302	Val loss: 0.1481	Val bias:587.6080	Val Pearson correlation: 7.2556e-01	Val MeanMult: 1.9078
# Epoch: 244	Duration: 124.32s	Train loss: 0.1301	Val loss: 0.1427	Val bias:577.5493	Val Pearson correlation: 7.2498e-01	Val MeanMult: 1.8869
# Epoch: 245	Duration: 126.48s	Train loss: 0.1290	Val loss: 0.1392	Val bias:565.6670	Val Pearson correlation: 7.2476e-01	Val MeanMult: 1.8721
# Epoch: 246	Duration: 123.99s	Train loss: 0.1303	Val loss: 0.1427	Val bias:574.2408	Val Pearson correlation: 7.2574e-01	Val MeanMult: 1.8849
# Epoch: 247	Duration: 123.92s	Train loss: 0.1305	Val loss: 0.1433	Val bias:577.4432	Val Pearson correlation: 7.2561e-01	Val MeanMult: 1.8880
# Epoch: 248	Duration: 124.24s	Train loss: 0.1301	Val loss: 0.1405	Val bias:567.0301	Val Pearson correlation: 7.2528e-01	Val MeanMult: 1.8775
# Epoch: 249	Duration: 124.03s	Train loss: 0.1298	Val loss: 0.1450	Val bias:586.1440	Val Pearson correlation: 7.2516e-01	Val MeanMult: 1.8970
# Epoch: 250	Duration: 123.97s	Train loss: 0.1303	Val loss: 0.1416	Val bias:568.8061	Val Pearson correlation: 7.2594e-01	Val MeanMult: 1.8795
# Epoch: 251	Duration: 123.94s	Train loss: 0.1305	Val loss: 0.1468	Val bias:583.5747	Val Pearson correlation: 7.2559e-01	Val MeanMult: 1.9021
# Epoch: 252	Duration: 125.32s	Train loss: 0.1297	Val loss: 0.1423	Val bias:573.3069	Val Pearson correlation: 7.2572e-01	Val MeanMult: 1.8836
# Epoch: 253	Duration: 124.00s	Train loss: 0.1295	Val loss: 0.1372	Val bias:562.5030	Val Pearson correlation: 7.2569e-01	Val MeanMult: 1.8656
# Epoch: 254	Duration: 125.59s	Train loss: 0.1296	Val loss: 0.1436	Val bias:575.9735	Val Pearson correlation: 7.2658e-01	Val MeanMult: 1.8887
# Epoch: 255	Duration: 124.02s	Train loss: 0.1294	Val loss: 0.1358	Val bias:561.2866	Val Pearson correlation: 7.2607e-01	Val MeanMult: 1.8603
# Epoch: 256	Duration: 124.07s	Train loss: 0.1292	Val loss: 0.1417	Val bias:576.7860	Val Pearson correlation: 7.2430e-01	Val MeanMult: 1.8859
# Epoch: 257	Duration: 124.15s	Train loss: 0.1299	Val loss: 0.1447	Val bias:582.5037	Val Pearson correlation: 7.2541e-01	Val MeanMult: 1.8957
# Epoch: 258	Duration: 124.12s	Train loss: 0.1299	Val loss: 0.1435	Val bias:575.9648	Val Pearson correlation: 7.2649e-01	Val MeanMult: 1.8877
# Epoch: 259	Duration: 124.60s	Train loss: 0.1298	Val loss: 0.1396	Val bias:567.9554	Val Pearson correlation: 7.2594e-01	Val MeanMult: 1.8752
# Epoch: 260	Duration: 124.06s	Train loss: 0.1296	Val loss: 0.1409	Val bias:569.8817	Val Pearson correlation: 7.2574e-01	Val MeanMult: 1.8770
# Epoch: 261	Duration: 123.93s	Train loss: 0.1300	Val loss: 0.1425	Val bias:572.2779	Val Pearson correlation: 7.2521e-01	Val MeanMult: 1.8868
# Epoch: 262	Duration: 124.22s	Train loss: 0.1297	Val loss: 0.1479	Val bias:590.3108	Val Pearson correlation: 7.2598e-01	Val MeanMult: 1.9069
# Epoch: 263	Duration: 125.76s	Train loss: 0.1308	Val loss: 0.1373	Val bias:560.6934	Val Pearson correlation: 7.2626e-01	Val MeanMult: 1.8619
# Epoch: 264	Duration: 124.51s	Train loss: 0.1300	Val loss: 0.1407	Val bias:567.9296	Val Pearson correlation: 7.2634e-01	Val MeanMult: 1.8775
# Epoch: 265	Duration: 124.87s	Train loss: 0.1303	Val loss: 0.1429	Val bias:577.2652	Val Pearson correlation: 7.2645e-01	Val MeanMult: 1.8878
# Epoch: 266	Duration: 123.99s	Train loss: 0.1300	Val loss: 0.1414	Val bias:571.1218	Val Pearson correlation: 7.2602e-01	Val MeanMult: 1.8817
# Epoch: 267	Duration: 123.98s	Train loss: 0.1293	Val loss: 0.1400	Val bias:567.8047	Val Pearson correlation: 7.2574e-01	Val MeanMult: 1.8758
# Epoch: 268	Duration: 124.00s	Train loss: 0.1299	Val loss: 0.1228	Val bias:554.6687	Val Pearson correlation: 7.2538e-01	Val MeanMult: 1.8424
# Epoch: 269	Duration: 124.10s	Train loss: 0.1308	Val loss: 0.1475	Val bias:587.6430	Val Pearson correlation: 7.2621e-01	Val MeanMult: 1.9055
# Epoch: 270	Duration: 126.47s	Train loss: 0.1301	Val loss: 0.1428	Val bias:573.1664	Val Pearson correlation: 7.2644e-01	Val MeanMult: 1.8867
# Epoch: 271	Duration: 126.49s	Train loss: 0.1298	Val loss: 0.1404	Val bias:567.9672	Val Pearson correlation: 7.2656e-01	Val MeanMult: 1.8759
# Epoch: 272	Duration: 123.84s	Train loss: 0.1298	Val loss: 0.1421	Val bias:571.1368	Val Pearson correlation: 7.2672e-01	Val MeanMult: 1.8816
# Epoch: 273	Duration: 124.36s	Train loss: 0.1294	Val loss: 0.1374	Val bias:562.1579	Val Pearson correlation: 7.2659e-01	Val MeanMult: 1.8645
# Epoch: 274	Duration: 124.04s	Train loss: 0.1293	Val loss: 0.1392	Val bias:564.3344	Val Pearson correlation: 7.2638e-01	Val MeanMult: 1.8708
# Epoch: 275	Duration: 124.02s	Train loss: 0.1287	Val loss: 0.1410	Val bias:570.0512	Val Pearson correlation: 7.2587e-01	Val MeanMult: 1.8799
# Epoch: 276	Duration: 124.59s	Train loss: 0.1297	Val loss: 0.1460	Val bias:584.0100	Val Pearson correlation: 7.2702e-01	Val MeanMult: 1.8990
# Epoch: 277	Duration: 124.09s	Train loss: 0.1302	Val loss: 0.1453	Val bias:583.5223	Val Pearson correlation: 7.2608e-01	Val MeanMult: 1.8977
# Epoch: 278	Duration: 124.02s	Train loss: 0.1305	Val loss: 0.1412	Val bias:571.1986	Val Pearson correlation: 7.2523e-01	Val MeanMult: 1.8807
# Epoch: 279	Duration: 124.13s	Train loss: 0.1298	Val loss: 0.1367	Val bias:561.9366	Val Pearson correlation: 7.2547e-01	Val MeanMult: 1.8627
# Epoch: 280	Duration: 123.97s	Train loss: 0.1297	Val loss: 0.1410	Val bias:568.0304	Val Pearson correlation: 7.2578e-01	Val MeanMult: 1.8769
# Epoch: 281	Duration: 123.89s	Train loss: 0.1290	Val loss: 0.1418	Val bias:572.7497	Val Pearson correlation: 7.2638e-01	Val MeanMult: 1.8805
# Epoch: 282	Duration: 124.11s	Train loss: 0.1296	Val loss: 0.1406	Val bias:570.2101	Val Pearson correlation: 7.2593e-01	Val MeanMult: 1.8777
# Epoch: 283	Duration: 123.86s	Train loss: 0.1302	Val loss: 0.1422	Val bias:577.8103	Val Pearson correlation: 7.2634e-01	Val MeanMult: 1.8827
# Epoch: 284	Duration: 124.12s	Train loss: 0.1293	Val loss: 0.1419	Val bias:574.3516	Val Pearson correlation: 7.2666e-01	Val MeanMult: 1.8828
# Epoch: 285	Duration: 124.05s	Train loss: 0.1293	Val loss: 0.1396	Val bias:566.6099	Val Pearson correlation: 7.2562e-01	Val MeanMult: 1.8728
# Epoch: 286	Duration: 124.60s	Train loss: 0.1296	Val loss: 0.1407	Val bias:570.4494	Val Pearson correlation: 7.2656e-01	Val MeanMult: 1.8760
# Epoch: 287	Duration: 124.05s	Train loss: 0.1292	Val loss: 0.1394	Val bias:569.4811	Val Pearson correlation: 7.2595e-01	Val MeanMult: 1.8724
# Epoch: 288	Duration: 123.91s	Train loss: 0.1302	Val loss: 0.1397	Val bias:568.6750	Val Pearson correlation: 7.2606e-01	Val MeanMult: 1.8739
# Epoch: 289	Duration: 123.98s	Train loss: 0.1303	Val loss: 0.1445	Val bias:582.7787	Val Pearson correlation: 7.2573e-01	Val MeanMult: 1.8943
# Epoch: 290	Duration: 123.93s	Train loss: 0.1302	Val loss: 0.1468	Val bias:587.8538	Val Pearson correlation: 7.2484e-01	Val MeanMult: 1.9059
# Epoch: 291	Duration: 125.41s	Train loss: 0.1301	Val loss: 0.1455	Val bias:581.4483	Val Pearson correlation: 7.2545e-01	Val MeanMult: 1.8970
# Epoch: 292	Duration: 125.88s	Train loss: 0.1297	Val loss: 0.1444	Val bias:586.2856	Val Pearson correlation: 7.2568e-01	Val MeanMult: 1.8947
# Epoch: 293	Duration: 123.90s	Train loss: 0.1299	Val loss: 0.1449	Val bias:582.0986	Val Pearson correlation: 7.2523e-01	Val MeanMult: 1.8950
# Epoch: 294	Duration: 124.20s	Train loss: 0.1302	Val loss: 0.1412	Val bias:576.3524	Val Pearson correlation: 7.2616e-01	Val MeanMult: 1.8813
# Epoch: 295	Duration: 123.99s	Train loss: 0.1295	Val loss: 0.1404	Val bias:570.9372	Val Pearson correlation: 7.2534e-01	Val MeanMult: 1.8773
# Epoch: 296	Duration: 124.07s	Train loss: 0.1290	Val loss: 0.1490	Val bias:594.7176	Val Pearson correlation: 7.2594e-01	Val MeanMult: 1.9133
# Epoch: 297	Duration: 124.13s	Train loss: 0.1305	Val loss: 0.1422	Val bias:575.0308	Val Pearson correlation: 7.2569e-01	Val MeanMult: 1.8837
# Epoch: 298	Duration: 124.01s	Train loss: 0.1300	Val loss: 0.1435	Val bias:585.5936	Val Pearson correlation: 7.2436e-01	Val MeanMult: 1.8937
# Epoch: 299	Duration: 124.11s	Train loss: 0.1295	Val loss: 0.1416	Val bias:573.0036	Val Pearson correlation: 7.2569e-01	Val MeanMult: 1.8816
# Epoch: 300	Duration: 124.05s	Train loss: 0.1296	Val loss: 0.1368	Val bias:558.1121	Val Pearson correlation: 7.2472e-01	Val MeanMult: 1.8635
# Epoch: 301	Duration: 123.92s	Train loss: 0.1295	Val loss: 0.1422	Val bias:577.1614	Val Pearson correlation: 7.2629e-01	Val MeanMult: 1.8850
# Epoch: 302	Duration: 123.98s	Train loss: 0.1296	Val loss: 0.1388	Val bias:566.2312	Val Pearson correlation: 7.2560e-01	Val MeanMult: 1.8709
# Epoch: 303	Duration: 124.02s	Train loss: 0.1304	Val loss: 0.1473	Val bias:587.9856	Val Pearson correlation: 7.2482e-01	Val MeanMult: 1.9068
# Epoch: 304	Duration: 124.37s	Train loss: 0.1292	Val loss: 0.1445	Val bias:585.5821	Val Pearson correlation: 7.2617e-01	Val MeanMult: 1.8956
# Epoch: 305	Duration: 124.03s	Train loss: 0.1306	Val loss: 0.1498	Val bias:598.2512	Val Pearson correlation: 7.2546e-01	Val MeanMult: 1.9191
# Epoch: 306	Duration: 123.95s	Train loss: 0.1299	Val loss: 0.1499	Val bias:595.6686	Val Pearson correlation: 7.2609e-01	Val MeanMult: 1.9170
# Epoch: 307	Duration: 123.94s	Train loss: 0.1295	Val loss: 0.1436	Val bias:583.4605	Val Pearson correlation: 7.2536e-01	Val MeanMult: 1.8933
# Epoch: 308	Duration: 124.60s	Train loss: 0.1296	Val loss: 0.1425	Val bias:574.5093	Val Pearson correlation: 7.2521e-01	Val MeanMult: 1.8856
# Epoch: 309	Duration: 123.90s	Train loss: 0.1301	Val loss: 0.1361	Val bias:562.5619	Val Pearson correlation: 7.2518e-01	Val MeanMult: 1.8615
# Epoch: 310	Duration: 126.31s	Train loss: 0.1299	Val loss: 0.1424	Val bias:577.5489	Val Pearson correlation: 7.2526e-01	Val MeanMult: 1.8858
# Epoch: 311	Duration: 124.16s	Train loss: 0.1305	Val loss: 0.1432	Val bias:574.4615	Val Pearson correlation: 7.2629e-01	Val MeanMult: 1.8842
# Epoch: 312	Duration: 123.88s	Train loss: 0.1304	Val loss: 0.1437	Val bias:583.7362	Val Pearson correlation: 7.2516e-01	Val MeanMult: 1.8926
# Epoch: 313	Duration: 124.62s	Train loss: 0.1298	Val loss: 0.1442	Val bias:580.6034	Val Pearson correlation: 7.2518e-01	Val MeanMult: 1.8920
# Epoch: 314	Duration: 124.44s	Train loss: 0.1298	Val loss: 0.1429	Val bias:581.3111	Val Pearson correlation: 7.2467e-01	Val MeanMult: 1.8892
# Epoch: 315	Duration: 126.38s	Train loss: 0.1287	Val loss: 0.1388	Val bias:564.1249	Val Pearson correlation: 7.2508e-01	Val MeanMult: 1.8689
# Epoch: 316	Duration: 126.72s	Train loss: 0.1299	Val loss: 0.1440	Val bias:580.1167	Val Pearson correlation: 7.2519e-01	Val MeanMult: 1.8913
# Epoch: 317	Duration: 126.72s	Train loss: 0.1289	Val loss: 0.1401	Val bias:571.2387	Val Pearson correlation: 7.2567e-01	Val MeanMult: 1.8755
# Epoch: 318	Duration: 126.67s	Train loss: 0.1296	Val loss: 0.1418	Val bias:573.0208	Val Pearson correlation: 7.2516e-01	Val MeanMult: 1.8817
# Epoch: 319	Duration: 126.62s	Train loss: 0.1293	Val loss: 0.1509	Val bias:600.1550	Val Pearson correlation: 7.2574e-01	Val MeanMult: 1.9216
# Epoch: 320	Duration: 125.45s	Train loss: 0.1295	Val loss: 0.1446	Val bias:582.9986	Val Pearson correlation: 7.2475e-01	Val MeanMult: 1.8933
# Epoch: 321	Duration: 124.95s	Train loss: 0.1297	Val loss: 0.1433	Val bias:578.3473	Val Pearson correlation: 7.2536e-01	Val MeanMult: 1.8875
# Epoch: 322	Duration: 124.14s	Train loss: 0.1299	Val loss: 0.1476	Val bias:591.7615	Val Pearson correlation: 7.2540e-01	Val MeanMult: 1.9058
# Epoch: 323	Duration: 123.97s	Train loss: 0.1291	Val loss: 0.1478	Val bias:594.9051	Val Pearson correlation: 7.2417e-01	Val MeanMult: 1.9096
# Epoch: 324	Duration: 125.17s	Train loss: 0.1298	Val loss: 0.1433	Val bias:581.1435	Val Pearson correlation: 7.2455e-01	Val MeanMult: 1.8903
# Epoch: 325	Duration: 126.44s	Train loss: 0.1298	Val loss: 0.1460	Val bias:588.1447	Val Pearson correlation: 7.2460e-01	Val MeanMult: 1.9004
# Epoch: 326	Duration: 124.33s	Train loss: 0.1300	Val loss: 0.1460	Val bias:592.6306	Val Pearson correlation: 7.2370e-01	Val MeanMult: 1.9037
# Epoch: 327	Duration: 123.96s	Train loss: 0.1292	Val loss: 0.1453	Val bias:587.1334	Val Pearson correlation: 7.2512e-01	Val MeanMult: 1.8986
# Epoch: 328	Duration: 124.10s	Train loss: 0.1290	Val loss: 0.1419	Val bias:580.9874	Val Pearson correlation: 7.2519e-01	Val MeanMult: 1.8852
# Epoch: 329	Duration: 124.28s	Train loss: 0.1293	Val loss: 0.1433	Val bias:582.8948	Val Pearson correlation: 7.2526e-01	Val MeanMult: 1.8910
# Epoch: 330	Duration: 124.10s	Train loss: 0.1292	Val loss: 0.1454	Val bias:590.8169	Val Pearson correlation: 7.2627e-01	Val MeanMult: 1.8982
# Epoch: 331	Duration: 124.13s	Train loss: 0.1288	Val loss: 0.1412	Val bias:579.1373	Val Pearson correlation: 7.2494e-01	Val MeanMult: 1.8836
# Epoch: 332	Duration: 124.02s	Train loss: 0.1285	Val loss: 0.1457	Val bias:591.7877	Val Pearson correlation: 7.2619e-01	Val MeanMult: 1.9013
# Epoch: 333	Duration: 126.39s	Train loss: 0.1285	Val loss: 0.1467	Val bias:594.9697	Val Pearson correlation: 7.2620e-01	Val MeanMult: 1.9056
# Epoch: 334	Duration: 124.05s	Train loss: 0.1290	Val loss: 0.1410	Val bias:574.2370	Val Pearson correlation: 7.2657e-01	Val MeanMult: 1.8789
# Epoch: 335	Duration: 123.95s	Train loss: 0.1284	Val loss: 0.1506	Val bias:612.7939	Val Pearson correlation: 7.2641e-01	Val MeanMult: 1.9252
# Epoch: 336	Duration: 125.75s	Train loss: 0.1281	Val loss: 0.1424	Val bias:579.9569	Val Pearson correlation: 7.2608e-01	Val MeanMult: 1.8866
# Epoch: 337	Duration: 124.25s	Train loss: 0.1285	Val loss: 0.1458	Val bias:589.6600	Val Pearson correlation: 7.2581e-01	Val MeanMult: 1.9002
# Epoch: 338	Duration: 123.93s	Train loss: 0.1280	Val loss: 0.1460	Val bias:591.6459	Val Pearson correlation: 7.2686e-01	Val MeanMult: 1.8999
# Epoch: 339	Duration: 124.08s	Train loss: 0.1283	Val loss: 0.1444	Val bias:589.2727	Val Pearson correlation: 7.2698e-01	Val MeanMult: 1.8954
# Epoch: 340	Duration: 124.07s	Train loss: 0.1287	Val loss: 0.1410	Val bias:579.6617	Val Pearson correlation: 7.2650e-01	Val MeanMult: 1.8811
# Epoch: 341	Duration: 124.00s	Train loss: 0.1288	Val loss: 0.1452	Val bias:588.2481	Val Pearson correlation: 7.2629e-01	Val MeanMult: 1.8962
# Epoch: 342	Duration: 123.88s	Train loss: 0.1286	Val loss: 0.1481	Val bias:595.8842	Val Pearson correlation: 7.2641e-01	Val MeanMult: 1.9110
# Epoch: 343	Duration: 126.33s	Train loss: 0.1281	Val loss: 0.1448	Val bias:588.6075	Val Pearson correlation: 7.2649e-01	Val MeanMult: 1.8948
# Epoch: 344	Duration: 126.33s	Train loss: 0.1289	Val loss: 0.1462	Val bias:586.4055	Val Pearson correlation: 7.2676e-01	Val MeanMult: 1.8989
# Epoch: 345	Duration: 124.94s	Train loss: 0.1282	Val loss: 0.1391	Val bias:578.3191	Val Pearson correlation: 7.2658e-01	Val MeanMult: 1.8731
# Epoch: 346	Duration: 123.92s	Train loss: 0.1290	Val loss: 0.1442	Val bias:587.8367	Val Pearson correlation: 7.2694e-01	Val MeanMult: 1.8903
# Epoch: 347	Duration: 126.28s	Train loss: 0.1287	Val loss: 0.1453	Val bias:588.7040	Val Pearson correlation: 7.2720e-01	Val MeanMult: 1.8970
# Epoch: 348	Duration: 124.05s	Train loss: 0.1280	Val loss: 0.1421	Val bias:584.4915	Val Pearson correlation: 7.2598e-01	Val MeanMult: 1.8868
# Epoch: 349	Duration: 123.97s	Train loss: 0.1277	Val loss: 0.1407	Val bias:579.3772	Val Pearson correlation: 7.2709e-01	Val MeanMult: 1.8768
# Epoch: 350	Duration: 123.95s	Train loss: 0.1279	Val loss: 0.1390	Val bias:573.7380	Val Pearson correlation: 7.2688e-01	Val MeanMult: 1.8709
# Epoch: 351	Duration: 126.51s	Train loss: 0.1283	Val loss: 0.1483	Val bias:596.1337	Val Pearson correlation: 7.2659e-01	Val MeanMult: 1.9078
# Epoch: 352	Duration: 124.09s	Train loss: 0.1285	Val loss: 0.1454	Val bias:590.5484	Val Pearson correlation: 7.2652e-01	Val MeanMult: 1.8981
# Epoch: 353	Duration: 123.81s	Train loss: 0.1281	Val loss: 0.1382	Val bias:570.4933	Val Pearson correlation: 7.2754e-01	Val MeanMult: 1.8689
# Epoch: 354	Duration: 124.30s	Train loss: 0.1272	Val loss: 0.1424	Val bias:585.3765	Val Pearson correlation: 7.2806e-01	Val MeanMult: 1.8856
# Epoch: 355	Duration: 125.23s	Train loss: 0.1282	Val loss: 0.1483	Val bias:599.7791	Val Pearson correlation: 7.2681e-01	Val MeanMult: 1.9119
# Epoch: 356	Duration: 125.90s	Train loss: 0.1282	Val loss: 0.1492	Val bias:610.2983	Val Pearson correlation: 7.2807e-01	Val MeanMult: 1.9166
# Epoch: 357	Duration: 124.03s	Train loss: 0.1280	Val loss: 0.1441	Val bias:588.6972	Val Pearson correlation: 7.2763e-01	Val MeanMult: 1.8928
# Epoch: 358	Duration: 124.07s	Train loss: 0.1270	Val loss: 0.1444	Val bias:587.8610	Val Pearson correlation: 7.2790e-01	Val MeanMult: 1.8913
# Epoch: 359	Duration: 123.96s	Train loss: 0.1278	Val loss: 0.1409	Val bias:576.6107	Val Pearson correlation: 7.2799e-01	Val MeanMult: 1.8772
# Epoch: 360	Duration: 123.88s	Train loss: 0.1280	Val loss: 0.1398	Val bias:575.1580	Val Pearson correlation: 7.2763e-01	Val MeanMult: 1.8736
# Epoch: 361	Duration: 124.03s	Train loss: 0.1276	Val loss: 0.1449	Val bias:591.3106	Val Pearson correlation: 7.2873e-01	Val MeanMult: 1.8942
# Epoch: 362	Duration: 124.83s	Train loss: 0.1279	Val loss: 0.1427	Val bias:581.6061	Val Pearson correlation: 7.2819e-01	Val MeanMult: 1.8847
# Epoch: 363	Duration: 123.85s	Train loss: 0.1288	Val loss: 0.1408	Val bias:575.7491	Val Pearson correlation: 7.2854e-01	Val MeanMult: 1.8762
# Epoch: 364	Duration: 123.85s	Train loss: 0.1278	Val loss: 0.1407	Val bias:578.7793	Val Pearson correlation: 7.2779e-01	Val MeanMult: 1.8790
# Epoch: 365	Duration: 124.02s	Train loss: 0.1280	Val loss: 0.1475	Val bias:599.9978	Val Pearson correlation: 7.2795e-01	Val MeanMult: 1.9060
# Epoch: 366	Duration: 123.96s	Train loss: 0.1286	Val loss: 0.1463	Val bias:595.8769	Val Pearson correlation: 7.2757e-01	Val MeanMult: 1.9012
# Epoch: 367	Duration: 124.14s	Train loss: 0.1289	Val loss: 0.1511	Val bias:612.2311	Val Pearson correlation: 7.2799e-01	Val MeanMult: 1.9248
# Epoch: 368	Duration: 126.29s	Train loss: 0.1282	Val loss: 0.1442	Val bias:585.5008	Val Pearson correlation: 7.2855e-01	Val MeanMult: 1.8908
# Epoch: 369	Duration: 123.90s	Train loss: 0.1266	Val loss: 0.1389	Val bias:571.3926	Val Pearson correlation: 7.2838e-01	Val MeanMult: 1.8704
# Epoch: 370	Duration: 123.97s	Train loss: 0.1274	Val loss: 0.1488	Val bias:602.3534	Val Pearson correlation: 7.2830e-01	Val MeanMult: 1.9122
# Epoch: 371	Duration: 123.95s	Train loss: 0.1277	Val loss: 0.1453	Val bias:594.6864	Val Pearson correlation: 7.2859e-01	Val MeanMult: 1.8954
# Epoch: 372	Duration: 123.87s	Train loss: 0.1279	Val loss: 0.1454	Val bias:594.0562	Val Pearson correlation: 7.2725e-01	Val MeanMult: 1.8974
# Epoch: 373	Duration: 126.42s	Train loss: 0.1282	Val loss: 0.1458	Val bias:592.5687	Val Pearson correlation: 7.2761e-01	Val MeanMult: 1.8983
# Epoch: 374	Duration: 123.89s	Train loss: 0.1273	Val loss: 0.1461	Val bias:593.4369	Val Pearson correlation: 7.2807e-01	Val MeanMult: 1.9003
# Epoch: 375	Duration: 123.94s	Train loss: 0.1279	Val loss: 0.1485	Val bias:601.7918	Val Pearson correlation: 7.2853e-01	Val MeanMult: 1.9088
# Epoch: 376	Duration: 124.22s	Train loss: 0.1276	Val loss: 0.1421	Val bias:580.7829	Val Pearson correlation: 7.2823e-01	Val MeanMult: 1.8804
# Epoch: 377	Duration: 124.78s	Train loss: 0.1282	Val loss: 0.1490	Val bias:604.6925	Val Pearson correlation: 7.2891e-01	Val MeanMult: 1.9115
# Epoch: 378	Duration: 124.76s	Train loss: 0.1285	Val loss: 0.1403	Val bias:571.8524	Val Pearson correlation: 7.2871e-01	Val MeanMult: 1.8732
# Epoch: 379	Duration: 126.61s	Train loss: 0.1276	Val loss: 0.1403	Val bias:572.4251	Val Pearson correlation: 7.2891e-01	Val MeanMult: 1.8741
# Epoch: 380	Duration: 124.06s	Train loss: 0.1272	Val loss: 0.1405	Val bias:584.8679	Val Pearson correlation: 7.2873e-01	Val MeanMult: 1.8775
# Epoch: 381	Duration: 124.66s	Train loss: 0.1270	Val loss: 0.1381	Val bias:571.1909	Val Pearson correlation: 7.2815e-01	Val MeanMult: 1.8669
# Epoch: 382	Duration: 124.48s	Train loss: 0.1281	Val loss: 0.1460	Val bias:594.1730	Val Pearson correlation: 7.2867e-01	Val MeanMult: 1.8998
# Epoch: 383	Duration: 126.49s	Train loss: 0.1276	Val loss: 0.1420	Val bias:582.3731	Val Pearson correlation: 7.2855e-01	Val MeanMult: 1.8818
# Epoch: 384	Duration: 126.69s	Train loss: 0.1282	Val loss: 0.1437	Val bias:588.3615	Val Pearson correlation: 7.2782e-01	Val MeanMult: 1.8888
# Epoch: 385	Duration: 126.66s	Train loss: 0.1278	Val loss: 0.1423	Val bias:584.9158	Val Pearson correlation: 7.2840e-01	Val MeanMult: 1.8827
# Epoch: 386	Duration: 124.14s	Train loss: 0.1273	Val loss: 0.1443	Val bias:588.8990	Val Pearson correlation: 7.2964e-01	Val MeanMult: 1.8925
# Epoch: 387	Duration: 124.06s	Train loss: 0.1280	Val loss: 0.1410	Val bias:579.3563	Val Pearson correlation: 7.2860e-01	Val MeanMult: 1.8783
# Epoch: 388	Duration: 124.04s	Train loss: 0.1280	Val loss: 0.1505	Val bias:607.7602	Val Pearson correlation: 7.2898e-01	Val MeanMult: 1.9188
# Epoch: 389	Duration: 124.28s	Train loss: 0.1277	Val loss: 0.1469	Val bias:595.1426	Val Pearson correlation: 7.2914e-01	Val MeanMult: 1.9035
# Epoch: 390	Duration: 123.98s	Train loss: 0.1270	Val loss: 0.1464	Val bias:595.7665	Val Pearson correlation: 7.2861e-01	Val MeanMult: 1.9019
# Epoch: 391	Duration: 123.90s	Train loss: 0.1282	Val loss: 0.1418	Val bias:577.8321	Val Pearson correlation: 7.2892e-01	Val MeanMult: 1.8816
# Epoch: 392	Duration: 124.50s	Train loss: 0.1278	Val loss: 0.1471	Val bias:601.2654	Val Pearson correlation: 7.2899e-01	Val MeanMult: 1.9046
# Epoch: 393	Duration: 126.18s	Train loss: 0.1277	Val loss: 0.1473	Val bias:597.9512	Val Pearson correlation: 7.2828e-01	Val MeanMult: 1.9046
# Epoch: 394	Duration: 123.86s	Train loss: 0.1273	Val loss: 0.1439	Val bias:592.3192	Val Pearson correlation: 7.2891e-01	Val MeanMult: 1.8923
# Epoch: 395	Duration: 124.02s	Train loss: 0.1280	Val loss: 0.1438	Val bias:586.6521	Val Pearson correlation: 7.2865e-01	Val MeanMult: 1.8899
# Epoch: 396	Duration: 125.60s	Train loss: 0.1272	Val loss: 0.1439	Val bias:591.4381	Val Pearson correlation: 7.2793e-01	Val MeanMult: 1.8925
# Epoch: 397	Duration: 124.09s	Train loss: 0.1280	Val loss: 0.1472	Val bias:600.5132	Val Pearson correlation: 7.2826e-01	Val MeanMult: 1.9067
# Epoch: 398	Duration: 123.90s	Train loss: 0.1271	Val loss: 0.1423	Val bias:581.9730	Val Pearson correlation: 7.2750e-01	Val MeanMult: 1.8855
# Epoch: 399	Duration: 124.14s	Train loss: 0.1277	Val loss: 0.1467	Val bias:594.6603	Val Pearson correlation: 7.2777e-01	Val MeanMult: 1.9043
# Epoch: 400	Duration: 123.90s	Train loss: 0.1277	Val loss: 0.1451	Val bias:593.5977	Val Pearson correlation: 7.2860e-01	Val MeanMult: 1.8960
# Epoch: 401	Duration: 123.85s	Train loss: 0.1277	Val loss: 0.1444	Val bias:589.3193	Val Pearson correlation: 7.2938e-01	Val MeanMult: 1.8927
# Epoch: 402	Duration: 123.88s	Train loss: 0.1282	Val loss: 0.1415	Val bias:581.0039	Val Pearson correlation: 7.2856e-01	Val MeanMult: 1.8806
# Epoch: 403	Duration: 123.91s	Train loss: 0.1274	Val loss: 0.1428	Val bias:583.0882	Val Pearson correlation: 7.2914e-01	Val MeanMult: 1.8859
# Epoch: 404	Duration: 123.90s	Train loss: 0.1281	Val loss: 0.1464	Val bias:596.0598	Val Pearson correlation: 7.2892e-01	Val MeanMult: 1.9007
# Epoch: 405	Duration: 123.93s	Train loss: 0.1274	Val loss: 0.1446	Val bias:591.9639	Val Pearson correlation: 7.2854e-01	Val MeanMult: 1.8943
# Epoch: 406	Duration: 123.96s	Train loss: 0.1277	Val loss: 0.1463	Val bias:596.1944	Val Pearson correlation: 7.2913e-01	Val MeanMult: 1.9007
# Epoch: 407	Duration: 124.37s	Train loss: 0.1279	Val loss: 0.1420	Val bias:584.5952	Val Pearson correlation: 7.2925e-01	Val MeanMult: 1.8835
# Epoch: 408	Duration: 126.45s	Train loss: 0.1274	Val loss: 0.1413	Val bias:583.8065	Val Pearson correlation: 7.2943e-01	Val MeanMult: 1.8815
# Epoch: 409	Duration: 124.11s	Train loss: 0.1282	Val loss: 0.1473	Val bias:596.5138	Val Pearson correlation: 7.2785e-01	Val MeanMult: 1.9057
# Epoch: 410	Duration: 124.20s	Train loss: 0.1280	Val loss: 0.1454	Val bias:587.9633	Val Pearson correlation: 7.2909e-01	Val MeanMult: 1.8958
# Epoch: 411	Duration: 123.92s	Train loss: 0.1281	Val loss: 0.1452	Val bias:591.1042	Val Pearson correlation: 7.2810e-01	Val MeanMult: 1.8981
# Epoch: 412	Duration: 124.37s	Train loss: 0.1276	Val loss: 0.1403	Val bias:577.3745	Val Pearson correlation: 7.2871e-01	Val MeanMult: 1.8759
# Epoch: 413	Duration: 126.39s	Train loss: 0.1272	Val loss: 0.1414	Val bias:578.6341	Val Pearson correlation: 7.2864e-01	Val MeanMult: 1.8805
# Epoch: 414	Duration: 124.06s	Train loss: 0.1279	Val loss: 0.1400	Val bias:576.0417	Val Pearson correlation: 7.2729e-01	Val MeanMult: 1.8762
# Epoch: 415	Duration: 124.69s	Train loss: 0.1273	Val loss: 0.1424	Val bias:575.8260	Val Pearson correlation: 7.2850e-01	Val MeanMult: 1.8822
# Epoch: 416	Duration: 124.88s	Train loss: 0.1278	Val loss: 0.1422	Val bias:584.4720	Val Pearson correlation: 7.2847e-01	Val MeanMult: 1.8868
# Epoch: 417	Duration: 126.39s	Train loss: 0.1278	Val loss: 0.1448	Val bias:587.1760	Val Pearson correlation: 7.2769e-01	Val MeanMult: 1.8939
# Epoch: 418	Duration: 123.63s	Train loss: 0.1272	Val loss: 0.1457	Val bias:592.6636	Val Pearson correlation: 7.2807e-01	Val MeanMult: 1.8982
# Epoch: 419	Duration: 124.55s	Train loss: 0.1269	Val loss: 0.1419	Val bias:580.9458	Val Pearson correlation: 7.2825e-01	Val MeanMult: 1.8832
# Epoch: 420	Duration: 123.57s	Train loss: 0.1269	Val loss: 0.1459	Val bias:591.5360	Val Pearson correlation: 7.2908e-01	Val MeanMult: 1.8997
# Epoch: 421	Duration: 123.46s	Train loss: 0.1278	Val loss: 0.1413	Val bias:583.6115	Val Pearson correlation: 7.2750e-01	Val MeanMult: 1.8817
# Epoch: 422	Duration: 126.09s	Train loss: 0.1271	Val loss: 0.1476	Val bias:607.2201	Val Pearson correlation: 7.2650e-01	Val MeanMult: 1.9142
# Epoch: 423	Duration: 123.60s	Train loss: 0.1281	Val loss: 0.1454	Val bias:593.3244	Val Pearson correlation: 7.2897e-01	Val MeanMult: 1.8978
# Epoch: 424	Duration: 125.38s	Train loss: 0.1279	Val loss: 0.1418	Val bias:582.4433	Val Pearson correlation: 7.2874e-01	Val MeanMult: 1.8825
# Epoch: 425	Duration: 123.88s	Train loss: 0.1273	Val loss: 0.1471	Val bias:604.6236	Val Pearson correlation: 7.2828e-01	Val MeanMult: 1.9086
# Epoch: 426	Duration: 124.82s	Train loss: 0.1279	Val loss: 0.1475	Val bias:597.9141	Val Pearson correlation: 7.2914e-01	Val MeanMult: 1.9069
# Epoch: 427	Duration: 124.51s	Train loss: 0.1271	Val loss: 0.1438	Val bias:590.4245	Val Pearson correlation: 7.2930e-01	Val MeanMult: 1.8940
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 11>()
#      18 val_steps = 0
#      20 for (x, y) in train_dataloader:
# ---> 21     (x, y) = (x.to(device), y.to(device))
#      22     pred = model(x)
#      23     loss = MSE(pred, y.reshape((y.shape[0], 1)))
#
# KeyboardInterrupt:

# %% [markdown]
# torch.cuda.empty_cache()

# %%
import csv

# 创建一个空列表来存储pred和y的值
data_to_save = []

test1_df = test_df.sample(5)

mae = 0.0 
total_samples = 0

test_dataloader1 = create_dataloader(test1_df) 
test_random = compute_eval_metrics(test_dataloader1,model) 
print(test_random)

for(x,y) in test_dataloader: 
    (x,y) = (x.to(device),y.to(device)) 
    pred = model(x) 
    for i in range(len(pred)):
        data_to_save.append([pred[i].item(), y[i].item()])

# 指定要保存的CSV文件名
csv_filename = 'predictions.csv'

# 打开CSV文件并将数据写入
with open(csv_filename, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # 写入列名（如果需要）
    csv_writer.writerow(['Prediction', 'Actual'])
    
    # 写入数据
    csv_writer.writerows(data_to_save)

print(f'Data saved to {csv_filename}')
#     print(pred,'///',y)

#     # 计算绝对误差
#     absolute_error = torch.abs(pred-y)

#     # 累加绝对误差和样本数
#     mae += absolute_error.sum().item()
    

# #     计算平均绝对误差


# mae /= 5 
# print("MAE:", mae)

# %%
with torch.no_grad():
    eval_test = compute_eval_metrics(test_dataloader, model)
    print(eval_test)

# %% [markdown]
# #
