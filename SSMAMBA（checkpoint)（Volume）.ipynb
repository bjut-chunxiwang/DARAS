# %% [markdown]
# # Model Prototyping
#
# Building the basis for our model experimentation

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import numpy as np
import pandas as pd
import torch
import os
import json

from torch.utils import data
from torch.nn import Conv2d, AvgPool2d, ReLU, Dropout, Flatten, Linear, Sequential, Module
from torch.optim import Adam
from time import time

from tqdm import tqdm

device = torch.device("cuda:0")
torch.set_default_dtype(torch.float64)

MODELS_DIR  = '/home/cxw/sonos_rirs/models/'

# %%
model_dict = {}
model_dict['name'] = "testrun2_regularization"
model_dict['notes'] = "same as test run but with regularization"
model_dict['data_path'] = '/home/cxw/sonos_rirs/features/080122_5k_phase/feature_df.csv'
model_dict['model_path'] = os.path.join(MODELS_DIR, model_dict['name'])

# %%
try:
    # 尝试导入IPython
    from IPython import get_ipython
    # 检查是否在IPython环境下
    if get_ipython() is not None:
        # 加载autoreload扩展
        # %load_ext autoreload
        # 设置autoreload为2
        # %autoreload 2
except ImportError:
    # 如果IPython没有被安装，则不作任何操作
    pass

# %%
# %autoreload 2
# import volume_estimation.modeling as model_funcs
# model_funcs.train_model(model_funcs.Baseline_Model, model_dict,\
#                         overwrite=True, epochs=1,log=False) #######################################################

# %%
feat_df = pd.read_csv(model_dict['data_path'])
model_path = os.path.join(MODELS_DIR, model_dict['name'])

dataset = []

    
def create_dataloader(feature_df, batch_size=1, log=True):
    dataset = []
    for row in tqdm(feature_df.iterrows()):
        feat_file = row[1]['file_feature']
        loaded = np.load(feat_file)

        feature = loaded['feat']
        feature = feature.reshape((feature.shape[0], feature.shape[1]))
        feature = np.real(feature)

        vol = loaded['vol']
        if log:
            vol = np.log10(vol)
        dataset.append((feature, vol))
    
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
    return dataloader

dataloader = create_dataloader(feat_df, log=False)
# Out:
# 32000it [00:11, 2794.89it/s]

# %%
savename = './testmodeldict.json'
with open(savename, 'w') as f:
    json.dump(model_dict, f)
    
with open(savename) as f:
    load_dict = json.load(f)
    
for key in load_dict.keys():
    print(key, load_dict[key])
# Out:
# name testrun2_regularization
# notes same as test run but with regularization
# data_path /home/cxw/sonos_rirs/features/080122_5k_phase/feature_df.csv
# model_path /home/cxw/sonos_rirs/models/testrun2_regularization

# %%
train_df = feat_df[feat_df['split'].isin(['train','val'])]
val_df = feat_df[feat_df['split']=='test']
test_df = feat_df[feat_df['split']=='test']

print("Creating training dataloader")
train_dataloader = create_dataloader(train_df, batch_size=128)        ##################################batch_size

print("Creating validation dataloader")
val_dataloader = create_dataloader(val_df)

print("Creating test dataloader")
test_dataloader = create_dataloader(test_df)
# Out:
# Creating training dataloader
# 25620it [00:09, 2746.94it/s]
# Creating validation dataloader
# 6380it [00:02, 2750.41it/s]
# Creating test dataloader
# 6380it [00:02, 2771.12it/s]

# %%
features, labels = next(iter(train_dataloader))
# features = features.squeeze(1)
# features = features.transpose(1,2)
print(f"Feature batch shape: {features.size()}")
print(f"Labels batch shape: {labels.size()}")
# Out:
# Feature batch shape: torch.Size([128, 30, 1997])
# Labels batch shape: torch.Size([128])

# %%
# class Baseline_Model(Module):
#     def __init__(self, input_shape):
#         #accepts a tuple with the height/width of the feature
#         #matrix to set the FC layer dimensions
#         super(Baseline_Model, self).__init__()
        
#         #block1
#         Conv1 = Conv2d(1, 30, kernel_size=(1,10), stride=(1,1))
#         Avgpool1 = AvgPool2d((1,2), stride=(1,2))

#         #block2
#         Conv2 = Conv2d(30, 20, kernel_size=(1,10), stride=(1,1))
#         Avgpool2 = AvgPool2d((1,2), stride=(1,2))

#         #block3
#         Conv3 = Conv2d(20, 10, kernel_size=(1,10), stride=(1,1))
#         Avgpool3 = AvgPool2d((1,2), stride=(1,2))

#         #block4
#         Conv4 = Conv2d(10, 10, kernel_size=(1,10), stride=(1,1))
#         Avgpool4 = AvgPool2d((1,2), stride=(1,2))

#         #block5
#         Conv5 = Conv2d(10, 5, kernel_size=(3,9), stride=(1,1))
#         Avgpool5 = AvgPool2d((1,2), stride=(1,2))

#         #block6
#         Conv6 = Conv2d(5, 5, kernel_size=(3,9), stride=(1,1))
#         Avgpool6 = AvgPool2d((2,2), stride=(2,2))

#         #dropout
#         dropout_layer = Dropout(p=0.5)
#         height5 = input_shape[0] - 2
#         height6 = (height5 - 2) // 2

#         time1 = (input_shape[1] - 9) // 2
#         time2 = (time1 - 9) // 2
#         time3 = (time2 - 9) // 2
#         time4 = (time3 - 9) // 2
#         time5 = (time4 - 7) // 2
#         time6 = (time5 - 7) // 2

#         flat_dims = 5 * height6 * time6
#         fc_layer = Linear(flat_dims, 1)
        
#         self.net = Sequential(
#                     Conv1, ReLU(), Avgpool1,
#                     Conv2, ReLU(), Avgpool2,
#                     Conv3, ReLU(), Avgpool3,
#                     Conv4, ReLU(), Avgpool4,
#                     Conv5, ReLU(), Avgpool5,
#                     Conv6, ReLU(), Avgpool6,
#                     dropout_layer, Flatten(),
#                     fc_layer, Flatten()
#                 )
#     def forward(self, x):
#         for layer in self.net:
#             x = layer(x)
#         return x

# %%
"""
Author: Siavash Shams
Date: 4/10/2024

This script contains the implementation of the AMBAModel and ASTModel for audio processing tasks.
The ASTModel is adapted from Yuan Gong's code.

"""
import os
os.environ["HF_ENDPOINT"]='https://hf-mirror.com'
import torch.nn as nn
import torch
import sys

from timm.models.layers import trunc_normal_
import timm
import numpy as np
from timm.models.layers import to_2tuple
from random import randrange
from matplotlib import pyplot as plt
import random

# from src.models.mamba.benchmarks.benchmark_generation_mamba_simple import device
device = "cuda"
sys.path.append('/home/cxw/Vim')
sys.path.append('/home/cxw/Vim/vim')
sys.path.append('/home/cxw/Vim/vim/mamba-1p1p1')



from models_mamba import VisionMamba
from mamba_ssm.ops.triton.layernorm import RMSNorm, layer_norm_fn, rms_norm_fn
    

    
    
class PatchEmbed(nn.Module):
    """ Image to Patch Embedding
    """
    def __init__(self, img_size=224, patch_size=16, in_chans=3, embed_dim=768):
        super().__init__()
        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        num_patches = (img_size[1] // patch_size[1]) * (img_size[0] // patch_size[0])
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = num_patches

        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=patch_size, stride=patch_size)

    def forward(self, x):
        x = self.proj(x).flatten(2).transpose(1, 2)
        return x

def get_sinusoid_encoding(n_position, d_hid):
    ''' Sinusoid position encoding table '''

    def get_position_angle_vec(position):
        return [position / np.power(10000, 2 * (hid_j // 2) / d_hid) for hid_j in range(d_hid)]

    sinusoid_table = np.array([get_position_angle_vec(pos_i) for pos_i in range(n_position)])
    sinusoid_table[:, 0::2] = np.sin(sinusoid_table[:, 0::2])  # dim 2i
    sinusoid_table[:, 1::2] = np.cos(sinusoid_table[:, 1::2])  # dim 2i+1

    return torch.FloatTensor(sinusoid_table).unsqueeze(0)

class AMBAModel(nn.Module):
    def __init__(self, label_dim=527,
                 fshape=128, tshape=2, fstride=128, tstride=2,
                 input_fdim=128, input_tdim=1024, model_size='base',
                 pretrain_stage=True, load_pretrained_mdl_path=None, vision_mamba_config=None):
        
        print("Vision Mamba Config:", vision_mamba_config)
        super(AMBAModel, self).__init__()
        #assert timm.__version__ == '0.4.5', 'Please use timm == 0.4.5, the code might not be compatible with newer versions.'

        # override timm input shape restriction
        timm.models.vision_transformer.PatchEmbed = PatchEmbed

        # pretrain the AMBA models
        if pretrain_stage == True:
            if load_pretrained_mdl_path != None:
                raise ValueError('Setting load_pretrained_mdl_path at pretraining stage is useless, pretraining is always from scratch, please change it to None.')
            if fstride != fshape or tstride != tshape:
                raise ValueError('fstride != fshape or tstride != tshape, they must be same at the pretraining stage, patch split overlapping is not supported.')

            
            default_vision_mamba_config = {
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 24,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': True,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': False,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        }
            
            
            combined_vision_mamba_config = {**default_vision_mamba_config, **vision_mamba_config}
            # Replace self.v with MambaBlocksSequential
            print("combined_vision_mamba_config",combined_vision_mamba_config)
            self.v = VisionMamba(**combined_vision_mamba_config)

            self.cls_token_num = 1
            self.original_num_patches = self.v.patch_embed.num_patches
            self.oringal_hw = int(self.original_num_patches ** 0.5)
            self.original_embedding_dim = self.v.pos_embed.shape[2]

            # SSL Pretraining Code
            self.softmax = nn.Softmax(dim=-1)
            self.lsoftmax = nn.LogSoftmax(dim=-1)
            self.fshape, self.tshape = fshape, tshape
            self.fstride, self.tstride = fstride, tstride
            self.input_fdim, self.input_tdim = input_fdim, input_tdim
            # this is a trick to make state_dict to track pretraining input_fdim and input_tdim and save them by using torch.save
            self.p_input_fdim, self.p_input_tdim = nn.Parameter(torch.tensor(input_fdim), requires_grad=False), nn.Parameter(torch.tensor(input_tdim), requires_grad=False)

            self.cpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            # masked patch reconstruction (generative objective) layer
            self.gpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            self.unfold = torch.nn.Unfold(kernel_size=(fshape, tshape), stride=(fstride, tstride))

            # we use learnable mask embedding (follow the BEIT paper), but using a fixed mask embedding (e.g., 0) leads to same performance.
            self.mask_embed = nn.Parameter(torch.zeros([1, 1, self.original_embedding_dim]))
            self.mask_embed = torch.nn.init.xavier_normal_(self.mask_embed)

            # get the intermediate shape
            self.p_f_dim, self.p_t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            num_patches = self.p_f_dim * self.p_t_dim
            self.num_patches = num_patches
            self.v.patch_embed.num_patches = num_patches
            print('pretraining patch split stride: frequency={:d}, time={:d}'.format(fstride, tstride))
            print('pretraining patch shape: frequency={:d}, time={:d}'.format(fshape, tshape))
            print('pretraining patch array dimension: frequency={:d}, time={:d}'.format(self.p_f_dim, self.p_t_dim))
            print('pretraining number of patches={:d}'.format(num_patches))

            # the linear patch projection layer, use 1 channel for spectrogram rather than the original 3 channels for RGB images.
            new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
            self.v.patch_embed.proj = new_proj

            # use trainable positional embedding
            new_pos_embed = nn.Parameter(torch.zeros(1, self.v.patch_embed.num_patches + self.cls_token_num, self.original_embedding_dim))
            self.v.pos_embed = new_pos_embed
            trunc_normal_(self.v.pos_embed, std=.02)

        # use a pretrained models for finetuning
        elif pretrain_stage == False:
            device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
            if load_pretrained_mdl_path == None:
                raise ValueError('Please set load_pretrained_mdl_path to load a pretrained models.')
            sd = torch.load(load_pretrained_mdl_path, map_location=device)
            # get the fshape and tshape, input_fdim and input_tdim in the pretraining stage
            try:
                p_fshape, p_tshape = sd['module.v.patch_embed.proj.weight'].shape[2], sd['module.v.patch_embed.proj.weight'].shape[3]
                p_input_fdim, p_input_tdim = sd['module.p_input_fdim'].item(), sd['module.p_input_tdim'].item()
            except:
                raise  ValueError('The model loaded is not from a torch.nn.Dataparallel object. Wrap it with torch.nn.Dataparallel and try again.')

            print('now load a SSL pretrained models from ' + load_pretrained_mdl_path)
            # during pretraining, fstride=fshape and tstride=tshape because no patch overlapping is used
            # here, input_fdim and input_tdim should be that used in pretraining, not that in the fine-tuning.
            # we need to know input_fdim and input_tdim to do positional embedding cut/interpolation.
            # generally it should be better to use same input_fdim during pretraining and finetuning, but input_tdim can be safely different
            default_vision_mamba_config = {
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 24,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': True,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': False,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        }
            
            
            combined_vision_mamba_config = {**default_vision_mamba_config, **vision_mamba_config}
            # Replace self.v with MambaBlocksSequential
            print("combined_vision_mamba_config",combined_vision_mamba_config)

            audio_model = AMBAModel(fstride=p_fshape, tstride=p_tshape, fshape=p_fshape, tshape=p_tshape,
                                   input_fdim=p_input_fdim, input_tdim=p_input_tdim, pretrain_stage=True, model_size=model_size, vision_mamba_config=combined_vision_mamba_config)
            
            audio_model = torch.nn.DataParallel(audio_model)
            audio_model.load_state_dict(sd, strict=False)
            device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            self.v = audio_model.module.v
            self.original_embedding_dim = self.v.pos_embed.shape[2]
            self.cls_token_num = audio_model.module.cls_token_num

            # mlp head for fine-tuning
            self.mlp_head = nn.Sequential(nn.LayerNorm(self.original_embedding_dim),
                                          nn.Linear(self.original_embedding_dim, label_dim))

            f_dim, t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            # patch array dimension during pretraining
            p_f_dim, p_t_dim = audio_model.module.p_f_dim, audio_model.module.p_t_dim
            num_patches = f_dim * t_dim
            p_num_patches = p_f_dim * p_t_dim
            self.v.patch_embed.num_patches = num_patches
            print('fine-tuning patch split stride: frequncey={:d}, time={:d}'.format(fstride, tstride))
            print('fine-tuning number of patches={:d}'.format(num_patches))

            # patch shape should be same for pretraining and fine-tuning
            # if fshape != p_fshape or tshape != p_tshape:
            #     raise ValueError('The patch shape of pretraining and fine-tuning is not consistant, pretraining: f={:d}, t={:d}, finetuning: f={:d}, t={:d}'.format(p_fshape, p_tshape, fshape, tshape))

            # patch split stride generally should be different for pretraining and fine-tuning, as patch split overlapping is only used in finetuning
            # during pretraining, p_fshape = p_fstride and p_tshape = p_tstride
            if fstride != p_fshape or tstride != p_tshape:
                # initialize a new patch embedding layer with desired new stride.
                new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
                # but the weights of patch embedding layer is still got from the pretrained models
                new_proj.weight = torch.nn.Parameter(torch.sum(self.v.patch_embed.proj.weight, dim=1).unsqueeze(1))
                new_proj.bias = self.v.patch_embed.proj.bias
                self.v.patch_embed.proj = new_proj

            new_pos_embed = self.v.pos_embed[:, self.cls_token_num:, :].detach().reshape(1, p_num_patches, self.original_embedding_dim).transpose(1, 2).reshape(1, self.original_embedding_dim, p_f_dim, p_t_dim)
            # cut or interpolate the positional embedding
            if t_dim < p_t_dim:
                new_pos_embed = new_pos_embed[:, :, :, int(p_t_dim/2) - int(t_dim / 2): int(p_t_dim/2) - int(t_dim / 2) + t_dim]
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(8, t_dim), mode='bilinear')
            if f_dim < p_f_dim:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')

            new_pos_embed = new_pos_embed.reshape(1, self.original_embedding_dim, num_patches).transpose(1, 2)
            self.v.pos_embed = nn.Parameter(torch.cat([self.v.pos_embed[:, :self.cls_token_num, :].detach(), new_pos_embed], dim=1))

    # get the shape of intermediate representation.
    def get_shape(self, fstride, tstride, input_fdim, input_tdim, fshape, tshape):
        test_input = torch.randn(1, 1, input_fdim, input_tdim)
        test_proj = nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
        test_out = test_proj(test_input)
        f_dim = test_out.shape[2]
        t_dim = test_out.shape[3]
        return f_dim, t_dim

    # generate mask for 16*16 patch
    def gen_maskid_patch(self, sequence_len=512, mask_size=100, cluster=3):
        mask_id = []

        # randomize clutering factor in [3,6)
        cur_clus = randrange(cluster) + 3

        while len(list(set(mask_id))) <= mask_size:
            start_id = randrange(sequence_len)

            # this improves the efficiency, but might change the pretrained model
            # while start_id in mask_id:
            #     start_id = randrange(sequence_len)

            cur_mask = []
            for i in range(0, cur_clus):
                for j in range(0, cur_clus):
                    mask_cand = start_id + self.p_t_dim * i + j
                    if mask_cand > 0 and mask_cand < sequence_len:
                        cur_mask.append(mask_cand)
            mask_id = mask_id + cur_mask
        mask_id = list(set(mask_id))[:mask_size]
        return torch.tensor(mask_id)

    # using cluster for frame masking hurts the performance, so just use the naive random sampling
    def gen_maskid_frame(self, sequence_len=512, mask_size=100):
        mask_id = random.sample(range(0, sequence_len), mask_size)
        return torch.tensor(mask_id)
    
    def finetuningavgtok_1sec(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                hidden_states, residual = layer(hidden_states, residual)
        else:
            for i in range(len(self.v.layers) // 2):
                hidden_states_f, residual_f = self.v.layers[i * 2](hidden_states, residual)
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](hidden_states.flip([1]), None if residual is None else residual.flip([1]))
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        x = self.v.norm_f(hidden_states)

        # Average output of tokens within each 1-second segment
        tokens_per_second = x.shape[1] // 60  
        x_averaged = torch.stack([torch.mean(x[:, i * tokens_per_second:(i + 1) * tokens_per_second, :], dim=1) for i in range(60)], dim=1)
        x_averaged = self.mlp_head(x_averaged)
        return x_averaged

    def finetuningavgtok(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x
        x = self.v.pos_drop(x)
        
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        x = self.v.norm_f(hidden_states)

        # average output of all tokens except cls token(s)
        x = torch.mean(x[:, self.cls_token_num:, :], dim=1)
        x = self.mlp_head(x)
        return x

    def finetuningcls(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

       
        x = self.v.norm_f(hidden_states)


        # if models has two cls tokens (DEIT), average as the clip-level representation
        if self.cls_token_num == 2:
            x = (x[:, 0] + x[:, 1]) / 2
        else:
            x = x[:, 0]
        x = self.mlp_head(x)
        return x

    # masked patch pretraining with discriminative objective
    def mpc(self, x, mask_patch, cluster, show_mask=False):
        input = self.unfold(x).transpose(1, 2)
        B = x.shape[0]
        # x in shape (batch_size, sequence_len, embedding dim)
        x = self.v.patch_embed(x)

        # encode the patch
        # size 12(batch_size) * 100(#mask_patch) * 768(hidden_dim), prepare to save the true values of masked samples
        encode_samples = torch.empty((B, mask_patch, 256), device=x.device, requires_grad=False).float()
        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)

        # for each audio clip in the batch
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            # copy the masked embeddings, note gradients are stopped in this path
            encode_samples[i] = input[i, mask_index[i], :].clone().detach()
            # mask the encode samples with 0
            mask_dense[i, mask_index[i], :] = 0

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # mask the patch
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # pass through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        #dist_token = self.v.dist_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
    
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        # return only cls token if it exists
        
        x = self.v.norm_f(hidden_states)
        
        
   
        pred = torch.empty((B, mask_patch, 256), device='cpu').float()  # e.g. size 12*100*768
        for i in range(B):
            #  +2 for indexes because skipping the cls and dis token
            # we map the output of transformer (768-dim for base models) to 256-dim patch input space, and then dot product with flattened patch input (also 256-dim) to calculate loss.
            # alternatively, you can map the output of transformer to 768-dim patch embedding space, and dot product with patch embedding. Performance-wise they are similar, but map to 256 space is more efficient.
            pred[i] = self.cpredlayer(x[i, mask_index[i] + self.cls_token_num, :])

        # calculate the NCE loss
        nce = torch.tensor(0.0).to(x.device)
        correct = torch.tensor(0.0).to(x.device)
        for i in np.arange(0, B):
            # negative samples are from the same batch
            # 8/12/2022: has a difference with equation (1) in the ssast paper but (likely) performance-wise similar, see https://github.com/YuanGongND/ssast/issues/13
            total = torch.mm(encode_samples[i], torch.transpose(pred[i], 0, 1))  # e.g. size 100*100
            correct += torch.sum(torch.eq(torch.argmax(self.softmax(total), dim=0), torch.arange(0, mask_patch, device=x.device)))  # correct is a tensor
            nce += torch.sum(torch.diag(self.lsoftmax(total)))  # nce is a tensor
        acc = 1. * correct / (B * mask_patch)
        nce = nce / (-1. * B * mask_patch)

        # visualize the masked area, for probing test only, set show_mask = False for any training/inference.
        if show_mask == False:
            return acc, nce
        else:
            if B > 1:
                raise Exception('Currently only support single spectrogram probing test.')

            self.mask_correct = torch.nn.Parameter(torch.arange(0, mask_patch), requires_grad=False)

            pred = input.clone()  # [B, 512, 256]
            masked = input.clone()

            for i in range(B):
                result = [float(t) * 99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)]
                pred[i, mask_index[i], :] = torch.tensor(result).reshape(mask_patch, 1).expand(mask_patch, 256)
                masked[i, mask_index[i], :] = 99.0

            # print(total)
            # print(self.softmax(total))
            # print(torch.argmax(self.softmax(total), dim=0))
            # print(self.mask_correct)
            # print(torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct))
            # print([float(t)*99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)])

            fold = torch.nn.Fold(output_size=([self.input_fdim, self.input_tdim]), kernel_size=(self.fshape, self.tshape), stride=(self.fstride, self.tstride))
            pred = fold(pred.transpose(1, 2))
            masked = fold(masked.transpose(1, 2))

            return pred, masked

        
    # # masked patch pretraining with generative objective
    def mpg(self, input, mask_patch, cluster):
        
        B = input.shape[0]
        x = self.v.patch_embed(input)
        input = self.unfold(input).transpose(1, 2)

        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            mask_dense[i, mask_index[i], :] = 0

        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # go through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        #dist_token = self.v.dist_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        
        x = self.v.norm_f(hidden_states)
        
        pred = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float()  # e.g. size 12*100*256
        target = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float() # e.g. size 12*100*256

        for i in range(B):
            #  +2 for indexes because cls and dis token
            pred[i] = self.gpredlayer(x[i, mask_index[i] + self.cls_token_num, :])
            target[i] = input[i, mask_index[i], :]

        # calculate the MSE loss
        mse = torch.mean((pred - target) ** 2)

        return mse
        
     
    def forward(self, x, task, cluster=True, mask_patch=400):
        # expect input x = (batch_size, time_frame_num, frequency_bins), e.g., (12, 1024, 128)
        x = x.unsqueeze(1)
        x = x.transpose(2, 3)
        # finetuning (ft), use the mean of all token (patch) output as clip-level representation.
        # this is default for SSAMBA fine-tuning as during pretraining, supervision signal is given to each token, not the [cls] token
        if task == 'ft_avgtok':
            return self.finetuningavgtok(x)
        elif task == 'ft_avgtok_1sec':
            return self.finetuningavgtok_1sec(x)
        # alternatively, use the [cls] token output as clip-level representation.
        elif task == 'ft_cls':
            return self.finetuningcls(x)
        # pretraining, masked patch classification (discriminative objective)
        elif task == 'pretrain_mpc':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster)
        # pretraining, masked patch reconstruction (generative objective)
        elif task == 'pretrain_mpg':
            return self.mpg(x, mask_patch=mask_patch, cluster=cluster)
        elif task == 'visualize_mask':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster, show_mask=True)
        else:
            raise Exception('Task unrecognized.')

            
class ASTModel(nn.Module):
    def __init__(self, label_dim=527,
                 fshape=128, tshape=2, fstride=128, tstride=2,
                 input_fdim=128, input_tdim=1024, model_size='base_nokd',
                 pretrain_stage=True, load_pretrained_mdl_path=None):

        super(ASTModel, self).__init__()
        assert timm.__version__ == '0.4.5', 'Please use timm == 0.4.5, the code might not be compatible with newer versions.'

        # override timm input shape restriction
        timm.models.vision_transformer.PatchEmbed = PatchEmbed

        # pretrain the AST models
        if pretrain_stage == True:
            if load_pretrained_mdl_path != None:
                raise ValueError('Setting load_pretrained_mdl_path at pretraining stage is useless, pretraining is always from scratch, please change it to None.')
            if fstride != fshape or tstride != tshape:
                raise ValueError('fstride != fshape or tstride != tshape, they must be same at the pretraining stage, patch split overlapping is not supported.')

            # if AudioSet pretraining is not used (but ImageNet pretraining may still apply)
            if model_size == 'tiny':
                self.v = timm.create_model('vit_deit_tiny_distilled_patch16_224', pretrained=False)
                self.heads, self.depth = 3, 12
                self.cls_token_num = 2
            elif model_size == 'small':
                self.v = timm.create_model('vit_deit_small_distilled_patch16_224', pretrained=False)
                self.heads, self.depth = 6, 12
                self.cls_token_num = 2
            elif model_size == 'base':
                self.v = timm.create_model('vit_deit_base_distilled_patch16_384', pretrained=False)
                self.heads, self.depth = 12, 12
                self.cls_token_num = 2
            elif model_size == 'base_nokd':
                self.v = timm.create_model('vit_deit_base_patch16_384', pretrained=False)
                self.heads, self.depth = 12, 12
                self.cls_token_num = 1
            else:
                raise Exception('Model size must be one of tiny, small, base, base_nokd')

            self.original_num_patches = self.v.patch_embed.num_patches
            self.oringal_hw = int(self.original_num_patches ** 0.5)
            self.original_embedding_dim = self.v.pos_embed.shape[2]

            # SSL Pretraining Code
            self.softmax = nn.Softmax(dim=-1)
            self.lsoftmax = nn.LogSoftmax(dim=-1)
            self.fshape, self.tshape = fshape, tshape
            self.fstride, self.tstride = fstride, tstride
            self.input_fdim, self.input_tdim = input_fdim, input_tdim
            # this is a trick to make state_dict to track pretraining input_fdim and input_tdim and save them by using torch.save
            self.p_input_fdim, self.p_input_tdim = nn.Parameter(torch.tensor(input_fdim), requires_grad=False), nn.Parameter(torch.tensor(input_tdim), requires_grad=False)

            # masked patch classification (discriminative objective) layer
            # we use two layers for pretext task, but using a single layer has similar performance.
            # we map the output of transformer (768-dim for base models) to 256-dim patch input space, and then dot product with flattened patch input (also 256-dim) to calculate loss.
            # alternatively, you can map the output of transformer to 768-dim patch embedding space, and dot product with patch embedding. Performance-wise they are similar, but map to 256 space is more efficient.
            self.cpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            # masked patch reconstruction (generative objective) layer
            self.gpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            self.unfold = torch.nn.Unfold(kernel_size=(fshape, tshape), stride=(fstride, tstride))

            # we use learnable mask embedding (follow the BEIT paper), but using a fixed mask embedding (e.g., 0) leads to same performance.
            self.mask_embed = nn.Parameter(torch.zeros([1, 1, self.original_embedding_dim]))
            self.mask_embed = torch.nn.init.xavier_normal_(self.mask_embed)

            # get the intermediate shape
            self.p_f_dim, self.p_t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            num_patches = self.p_f_dim * self.p_t_dim
            self.num_patches = num_patches
            self.v.patch_embed.num_patches = num_patches
            print('pretraining patch split stride: frequency={:d}, time={:d}'.format(fstride, tstride))
            print('pretraining patch shape: frequency={:d}, time={:d}'.format(fshape, tshape))
            print('pretraining patch array dimension: frequency={:d}, time={:d}'.format(self.p_f_dim, self.p_t_dim))
            print('pretraining number of patches={:d}'.format(num_patches))

            # the linear patch projection layer, use 1 channel for spectrogram rather than the original 3 channels for RGB images.
            new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
            self.v.patch_embed.proj = new_proj

            # use trainable positional embedding
            new_pos_embed = nn.Parameter(torch.zeros(1, self.v.patch_embed.num_patches + self.cls_token_num, self.original_embedding_dim))
            self.v.pos_embed = new_pos_embed
            trunc_normal_(self.v.pos_embed, std=.02)

        # use a pretrained models for finetuning
        elif pretrain_stage == False:
            device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            if load_pretrained_mdl_path == None:
                raise ValueError('Please set load_pretrained_mdl_path to load a pretrained models.')
            sd = torch.load(load_pretrained_mdl_path, map_location=device)
            # get the fshape and tshape, input_fdim and input_tdim in the pretraining stage
            try:
                p_fshape, p_tshape = sd['module.v.patch_embed.proj.weight'].shape[2], sd['module.v.patch_embed.proj.weight'].shape[3]
                p_input_fdim, p_input_tdim = sd['module.p_input_fdim'].item(), sd['module.p_input_tdim'].item()
            except:
                raise  ValueError('The model loaded is not from a torch.nn.Dataparallel object. Wrap it with torch.nn.Dataparallel and try again.')

            print('now load a SSL pretrained models from ' + load_pretrained_mdl_path)
            # during pretraining, fstride=fshape and tstride=tshape because no patch overlapping is used
            # here, input_fdim and input_tdim should be that used in pretraining, not that in the fine-tuning.
            # we need to know input_fdim and input_tdim to do positional embedding cut/interpolation.
            # generally it should be better to use same input_fdim during pretraining and finetuning, but input_tdim can be safely different
            audio_model = ASTModel(fstride=p_fshape, tstride=p_tshape, fshape=p_fshape, tshape=p_tshape,
                                   input_fdim=p_input_fdim, input_tdim=p_input_tdim, pretrain_stage=True, model_size=model_size)
            audio_model = torch.nn.DataParallel(audio_model)
            audio_model.load_state_dict(sd, strict=False)

            self.v = audio_model.module.v
            self.original_embedding_dim = self.v.pos_embed.shape[2]
            self.cls_token_num = audio_model.module.cls_token_num

            # mlp head for fine-tuning
            self.mlp_head = nn.Sequential(nn.LayerNorm(self.original_embedding_dim),
                                          nn.Linear(self.original_embedding_dim, label_dim))

            f_dim, t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            # patch array dimension during pretraining
            p_f_dim, p_t_dim = audio_model.module.p_f_dim, audio_model.module.p_t_dim
            num_patches = f_dim * t_dim
            p_num_patches = p_f_dim * p_t_dim
            self.v.patch_embed.num_patches = num_patches
            print('fine-tuning patch split stride: frequncey={:d}, time={:d}'.format(fstride, tstride))
            print('fine-tuning number of patches={:d}'.format(num_patches))

            # patch shape should be same for pretraining and fine-tuning
            if fshape != p_fshape or tshape != p_tshape:
                raise ValueError('The patch shape of pretraining and fine-tuning is not consistant, pretraining: f={:d}, t={:d}, finetuning: f={:d}, t={:d}'.format(p_fshape, p_tshape, fshape, tshape))

            # patch split stride generally should be different for pretraining and fine-tuning, as patch split overlapping is only used in finetuning
            # during pretraining, p_fshape = p_fstride and p_tshape = p_tstride
            if fstride != p_fshape or tstride != p_tshape:
                # initialize a new patch embedding layer with desired new stride.
                new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
                # but the weights of patch embedding layer is still got from the pretrained models
                new_proj.weight = torch.nn.Parameter(torch.sum(self.v.patch_embed.proj.weight, dim=1).unsqueeze(1))
                new_proj.bias = self.v.patch_embed.proj.bias
                self.v.patch_embed.proj = new_proj

            new_pos_embed = self.v.pos_embed[:, self.cls_token_num:, :].detach().reshape(1, p_num_patches, self.original_embedding_dim).transpose(1, 2).reshape(1, self.original_embedding_dim, p_f_dim, p_t_dim)
            # cut or interpolate the positional embedding
            if t_dim < p_t_dim:
                new_pos_embed = new_pos_embed[:, :, :, int(p_t_dim/2) - int(t_dim / 2): int(p_t_dim/2) - int(t_dim / 2) + t_dim]
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(8, t_dim), mode='bilinear')
            if f_dim < p_f_dim:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')

            new_pos_embed = new_pos_embed.reshape(1, self.original_embedding_dim, num_patches).transpose(1, 2)
            self.v.pos_embed = nn.Parameter(torch.cat([self.v.pos_embed[:, :self.cls_token_num, :].detach(), new_pos_embed], dim=1))

    # get the shape of intermediate representation.
    def get_shape(self, fstride, tstride, input_fdim, input_tdim, fshape, tshape):
        test_input = torch.randn(1, 1, input_fdim, input_tdim)
        test_proj = nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
        test_out = test_proj(test_input)
        f_dim = test_out.shape[2]
        t_dim = test_out.shape[3]
        return f_dim, t_dim

    # generate mask for 16*16 patch
    def gen_maskid_patch(self, sequence_len=512, mask_size=100, cluster=3):
        mask_id = []

        # randomize clutering factor in [3,6)
        cur_clus = randrange(cluster) + 3

        while len(list(set(mask_id))) <= mask_size:
            start_id = randrange(sequence_len)

            # this improves the efficiency, but might change the pretrained model
            # while start_id in mask_id:
            #     start_id = randrange(sequence_len)

            cur_mask = []
            for i in range(0, cur_clus):
                for j in range(0, cur_clus):
                    mask_cand = start_id + self.p_t_dim * i + j
                    if mask_cand > 0 and mask_cand < sequence_len:
                        cur_mask.append(mask_cand)
            mask_id = mask_id + cur_mask
        mask_id = list(set(mask_id))[:mask_size]
        return torch.tensor(mask_id)

    # using cluster for frame masking hurts the performance, so just use the naive random sampling
    def gen_maskid_frame(self, sequence_len=512, mask_size=100):
        mask_id = random.sample(range(0, sequence_len), mask_size)
        return torch.tensor(mask_id)
    
    def finetuningavgtok_1sec(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        for blk_id, blk in enumerate(self.v.blocks):
            x = blk(x)
        x = self.v.norm(x)

        # Average output of tokens within each 1-second segment
        tokens_per_second = x.shape[1] // 60  
        x_averaged = torch.stack([torch.mean(x[:, i * tokens_per_second:(i + 1) * tokens_per_second, :], dim=1) for i in range(60)], dim=1)
        x_averaged = self.mlp_head(x_averaged)
        return x_averaged
        

    def finetuningavgtok(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)

        for blk_id, blk in enumerate(self.v.blocks):
            x = blk(x)
        x = self.v.norm(x)

        # average output of all tokens except cls token(s)
        x = torch.mean(x[:, self.cls_token_num:, :], dim=1)
        x = self.mlp_head(x)
        return x

    def finetuningcls(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)

        for blk_id, blk in enumerate(self.v.blocks):
            x = blk(x)
        x = self.v.norm(x)

        # if models has two cls tokens (DEIT), average as the clip-level representation
        if self.cls_token_num == 2:
            x = (x[:, 0] + x[:, 1]) / 2
        else:
            x = x[:, 0]
        x = self.mlp_head(x)
        return x

    # masked patch pretraining with discriminative objective
    def mpc(self, x, mask_patch, cluster, show_mask=False):
        input = self.unfold(x).transpose(1, 2)
        B = x.shape[0]
        # x in shape (batch_size, sequence_len, embedding dim)
        x = self.v.patch_embed(x)

        # encode the patch
        # size 12(batch_size) * 100(#mask_patch) * 768(hidden_dim), prepare to save the true values of masked samples
        encode_samples = torch.empty((B, mask_patch, 256), device=x.device, requires_grad=False).float()
        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)

        # for each audio clip in the batch
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            # copy the masked embeddings, note gradients are stopped in this path
            encode_samples[i] = input[i, mask_index[i], :].clone().detach()
            # mask the encode samples with 0
            mask_dense[i, mask_index[i], :] = 0

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # mask the patch
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # pass through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        if self.cls_token_num == 2: 
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        #print("x before blk.shape",x.shape)
        for blk in self.v.blocks:
            x = blk(x)
            #print("blk(x).shape",x.shape)
        x = self.v.norm(x)

        # prediction of the masked patch
        pred = torch.empty((B, mask_patch, 256), device=x.device).float()  # e.g. size 12*100*768
        for i in range(B):
            #  +2 for indexes because skipping the cls and dis token
            # we map the output of transformer (768-dim for base models) to 256-dim patch input space, and then dot product with flattened patch input (also 256-dim) to calculate loss.
            # alternatively, you can map the output of transformer to 768-dim patch embedding space, and dot product with patch embedding. Performance-wise they are similar, but map to 256 space is more efficient.
            pred[i] = self.cpredlayer(x[i, mask_index[i] + self.cls_token_num, :])

        # calculate the NCE loss
        nce = torch.tensor(0.0).to(x.device)
        correct = torch.tensor(0.0).to(x.device)
        for i in np.arange(0, B):
            # negative samples are from the same batch
            # 8/12/2022: has a difference with equation (1) in the ssast paper but (likely) performance-wise similar, see https://github.com/YuanGongND/ssast/issues/13
            total = torch.mm(encode_samples[i], torch.transpose(pred[i], 0, 1))  # e.g. size 100*100
            correct += torch.sum(torch.eq(torch.argmax(self.softmax(total), dim=0), torch.arange(0, mask_patch, device=x.device)))  # correct is a tensor
            nce += torch.sum(torch.diag(self.lsoftmax(total)))  # nce is a tensor
        acc = 1. * correct / (B * mask_patch)
        nce = nce / (-1. * B * mask_patch)

        # visualize the masked area, for probing test only, set show_mask = False for any training/inference.
        if show_mask == False:
            return acc, nce
        else:
            if B > 1:
                raise Exception('Currently only support single spectrogram probing test.')

            self.mask_correct = torch.nn.Parameter(torch.arange(0, mask_patch), requires_grad=False)

            pred = input.clone()  # [B, 512, 256]
            masked = input.clone()

            for i in range(B):
                result = [float(t) * 99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)]
                pred[i, mask_index[i], :] = torch.tensor(result).reshape(mask_patch, 1).expand(mask_patch, 256)
                masked[i, mask_index[i], :] = 99.0

            # print(total)
            # print(self.softmax(total))
            # print(torch.argmax(self.softmax(total), dim=0))
            # print(self.mask_correct)
            # print(torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct))
            # print([float(t)*99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)])

            fold = torch.nn.Fold(output_size=([self.input_fdim, self.input_tdim]), kernel_size=(self.fshape, self.tshape), stride=(self.fstride, self.tstride))
            pred = fold(pred.transpose(1, 2))
            masked = fold(masked.transpose(1, 2))

            return pred, masked

    # # masked patch pretraining with generative objective
    def mpg(self, input, mask_patch, cluster):
        B = input.shape[0]
        x = self.v.patch_embed(input)
        input = self.unfold(input).transpose(1, 2)

        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            mask_dense[i, mask_index[i], :] = 0

        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # go through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        if self.cls_token_num == 2: 
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        for blk in self.v.blocks:
            x = blk(x)
        x = self.v.norm(x)

        pred = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float()  # e.g. size 12*100*256
        target = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float() # e.g. size 12*100*256

        for i in range(B):
            #  +2 for indexes because cls and dis token
            pred[i] = self.gpredlayer(x[i, mask_index[i] + self.cls_token_num, :])
            target[i] = input[i, mask_index[i], :]

        # calculate the MSE loss
        mse = torch.mean((pred - target) ** 2)

        return mse

    def forward(self, x, task, cluster=True, mask_patch=400):
        # expect input x = (batch_size, time_frame_num, frequency_bins), e.g., (12, 1024, 128)
        x = x.unsqueeze(1)
        x = x.transpose(2, 3)

        # finetuning (ft), use the mean of all token (patch) output as clip-level representation.
        # this is default for SSAST fine-tuning as during pretraining, supervision signal is given to each token, not the [cls] token
        if task == 'ft_avgtok':
            return self.finetuningavgtok(x)
        elif task == 'ft_avgtok_1sec':
            return self.finetuningavgtok_1sec(x)
        # alternatively, use the [cls] token output as clip-level representation.
        elif task == 'ft_cls':
            return self.finetuningcls(x)
        # pretraining, masked patch classification (discriminative objective)
        elif task == 'pretrain_mpc':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster)
        # pretraining, masked patch reconstruction (generative objective)
        elif task == 'pretrain_mpg':
            return self.mpg(x, mask_patch=mask_patch, cluster=cluster)
        elif task == 'visualize_mask':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster, show_mask=True)
        else:
            raise Exception('Task unrecognized.')


if __name__ == '__main__':
    # fine-tuning stage
    # now you have a labeled dataset you want to finetune AST on
    # suppose the avg length is 100 frames (1s) and there are 35 classes
    # the fshape and tshape must be same in pretraining and finetuning
    # but fstride and tstride can be different in pretraining and finetuning
    # using smaller strides improves the performance but also increase the computational overhead
    # set pretrain_stage as False since now is in the finetuning stage
    # provide the path of the pretrained model you want to load
    input_tdim = 1997  # fine-tuning data length can be different with pretraining data length
    ast_mdl = AMBAModel(label_dim=1,
                 fshape=16, tshape=16, fstride=10, tstride=10,
                 input_fdim=30, input_tdim=1997, model_size='base',
                 pretrain_stage=False, load_pretrained_mdl_path='./ssamba_base_400.pth', vision_mamba_config={
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 48,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': True,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': False,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        })
    # # alternatively, use a frame based AST model
    # ast_mdl = ASTModel(label_dim=35,
    #              fshape=128, tshape=2, fstride=128, tstride=1,
    #              input_fdim=128, input_tdim=input_tdim, model_size='base',
    #              pretrain_stage=False, load_pretrained_mdl_path='./test_mdl.pth')

    # do finetuning, see src/traintest.py for our finetuning code
    test_input = torch.zeros([128, 1997, 30]).to(device)
    ast_mdl = ast_mdl.to(device)
    ast_mdl = ast_mdl.cuda()
    # print('test_input.shape',test_input.shape)
    prediction = ast_mdl(test_input, task='ft_avgtok')
    # output should in shape [batch_size, label_dim]
    print(prediction.shape)
    # calculate the loss, do back propagate, etc

    # # (optional) do some probe test
    # test_input = torch.zeros([1, input_tdim, 128]).to(device)
    # acc, nce = ast_mdl(test_input, task='pretrain_mpc', mask_patch=100)
    # # you can visualize the mask
    # pred, masked = ast_mdl(test_input, task='visualize_mask', mask_patch=100)
    # plt.imshow(masked[0,0])
    # plt.show()
# Out:
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# now load a SSL pretrained models from ./ssamba_base_400.pth
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# pretraining patch split stride: frequency=16, time=16
# pretraining patch shape: frequency=16, time=16
# pretraining patch array dimension: frequency=8, time=64
# pretraining number of patches=512
# fine-tuning patch split stride: frequncey=10, time=10
# fine-tuning number of patches=398
# torch.Size([128, 1])

# %%
input_height = features.size()[1]
input_width = features.size()[2]
model = AMBAModel(label_dim=1,
                 fshape=16, tshape=16, fstride=10, tstride=10,
                 input_fdim=30, input_tdim=1997, model_size='base',
                 pretrain_stage=False, load_pretrained_mdl_path='./ssamba_base_400.pth', vision_mamba_config={
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 36,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': False,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': True,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        }).to(device)
# model = Baseline_Model((input_height, input_width)).to(device)
# Out:
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# now load a SSL pretrained models from ./ssamba_base_400.pth
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# pretraining patch split stride: frequency=16, time=16
# pretraining patch shape: frequency=16, time=16
# pretraining patch array dimension: frequency=8, time=64
# pretraining number of patches=512
# fine-tuning patch split stride: frequncey=10, time=10
# fine-tuning number of patches=398

# %%
def MSE(output, target):
    loss = torch.mean((output - target)**2)
    return loss

def Bias(output, target):
    loss = torch.mean(output - target)
    return loss

def CovStep(output, target, output_mean, target_mean):
    loss = torch.mean(((output - output_mean) * (target - target_mean)))
    return loss

def MeanAbsLogStep(output, target, log=True):
    #convert out of log
    if log:
        vol_pred = 10**output
        vol_target = 10**target
    else:
        vol_pred = output
        vol_target = target
    loss = torch.mean(torch.abs(torch.log(vol_pred/vol_target)))
    return loss

def compute_eval_metrics(dataloader, model, log=True):
    target_sum = 0
    pred_sum = 0
    n_steps = 0
    
    for (x,y) in dataloader:        
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        target_sum += y.sum()
        pred_sum += pred.sum()
        n_steps += 1
    
    target_mean = target_sum/n_steps
    pred_mean = pred_sum/n_steps
    
    mse = 0
    mean_error = 0
    cov = 0
    abs_log_ratio = 0
    
    var_pred = 0 #technically var * N but gets cancelled out in Pearson calculation
    var_target = 0 
    
    for (x,y) in dataloader:        
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        mse += MSE(pred, y)
        mean_error += Bias(pred, y)
        cov += CovStep(pred, y, pred_mean, target_mean)
        abs_log_ratio += MeanAbsLogStep(pred, y, log=log)
        
        var_pred += MSE(pred, pred_mean)
        var_target += MSE(y, target_mean)
        
        pears = CovStep(pred, y, pred_mean, target_mean)/(torch.sqrt(MSE(pred, pred_mean))*torch.sqrt(MSE(y, target_mean)))
    
    out_dict = {}
    out_dict['mse'] = (mse / n_steps).item()
    out_dict['bias'] = (mean_error / n_steps).item()
    out_dict['pearson_cor'] = (cov/(torch.sqrt(var_pred) * torch.sqrt(var_target))).item()
    out_dict['mean_mult'] = (torch.exp(abs_log_ratio/n_steps)).item()
    
    return out_dict
    
# eval_dict = compute_eval_metrics(val_dataloader, model)
# print(eval_dict)

# %%
import os
import torch
from torch.optim import Adam
from torch.optim.lr_scheduler import StepLR
from time import time

def save_checkpoint(epoch, model, opt, filename='checkpoint.pth.tar'):
    state = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': opt.state_dict()
    }
    torch.save(state, filename)

def load_checkpoint(filename='checkpoint.pth.tar'):
    checkpoint = torch.load(filename)
    return checkpoint['epoch'], checkpoint['model_state_dict'], checkpoint['optimizer_state_dict']

# 设置保存模型的文件夹和文件名
save_dir = 'model_checkpoints'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
checkpoint_path = os.path.join(save_dir, 'checkpoint.pth.tar')
torch.set_default_dtype(torch.float32)
opt = Adam(model.parameters(),lr=0.0002, weight_decay=1e-5)

# 初始化学习率调度器
scheduler = StepLR(opt, step_size=1000, gamma=0.5)

start_epoch = 0
if os.path.isfile(checkpoint_path):
    print(f"Loading checkpoint from '{checkpoint_path}'")
    start_epoch, model_state_dict, optimizer_state_dict = load_checkpoint(checkpoint_path)
    model.load_state_dict(model_state_dict)
    opt.load_state_dict(optimizer_state_dict)
    print(f"Resuming from epoch {start_epoch}")

hist = {
	"train_loss": [],
	"val_loss": [],
    "val_bias": [],
    "val_pearson_cor": [],
    "val_mean_mult": []
}

for ep in range(1200000):     #########################################################################                   
    t_start = time()
    model.train()
    
    train_loss = 0
    val_loss = 0
    train_steps = 0
    val_steps = 0
    
    for (x, y) in train_dataloader:
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        loss = MSE(pred, y.reshape((y.shape[0], 1))).to(device)
        
        opt.zero_grad()
        loss.backward()
        opt.step()
        
        train_loss += loss
        train_steps += 1
    
    with torch.no_grad():
        model.eval()
        
        val_metrics = compute_eval_metrics(val_dataloader, model)
    
    
    hist['train_loss'].append(train_loss/train_steps)
    hist['val_loss'].append(val_metrics['mse'])
    hist['val_bias'].append(val_metrics['bias'])
    hist['val_pearson_cor'].append(val_metrics['pearson_cor'])
    hist['val_mean_mult'].append(val_metrics['mean_mult'])
    
    t_end = time()
    
    t_elapsed = t_end - t_start
    print("Epoch: {}\tDuration: {:.2f}s\tTrain loss: {:.4f}\tVal loss: {:.4f}\tVal bias:{:.4f}\tVal Pearson correlation: {:.4e}\tVal MeanMult: {:.4f}"\
          .format(ep, t_elapsed, train_loss/train_steps, val_metrics['mse'],\
                  val_metrics['bias'], val_metrics['pearson_cor'],val_metrics['mean_mult']))

# 更新学习率调度器
    scheduler.step()
    current_lr = opt.param_groups[0]['lr']
    print(f"Current learning rate: {current_lr}")
    
    if (ep + 1) % 20 == 0:
        save_checkpoint(ep + 1, model, opt, checkpoint_path)
        print(f"Checkpoint saved at epoch {ep + 1}")
# Out:
# Epoch: 0	Duration: 86.63s	Train loss: 0.8329	Val loss: 0.6714	Val bias:-0.1008	Val Pearson correlation: 3.3976e-01	Val MeanMult: 4.9186
# Current learning rate: 0.0002
# Epoch: 1	Duration: 106.58s	Train loss: 0.6692	Val loss: 0.6723	Val bias:-0.1538	Val Pearson correlation: 3.6337e-01	Val MeanMult: 4.7689
# Current learning rate: 0.0002
# Epoch: 2	Duration: 84.69s	Train loss: 0.6638	Val loss: 0.6620	Val bias:-0.1384	Val Pearson correlation: 3.7412e-01	Val MeanMult: 4.7084
# Current learning rate: 0.0002
# Epoch: 3	Duration: 85.94s	Train loss: 0.6589	Val loss: 0.6643	Val bias:-0.1591	Val Pearson correlation: 3.8089e-01	Val MeanMult: 4.6848
# Current learning rate: 0.0002
# Epoch: 4	Duration: 85.78s	Train loss: 0.6547	Val loss: 0.6716	Val bias:-0.1890	Val Pearson correlation: 3.8626e-01	Val MeanMult: 4.6715
# Current learning rate: 0.0002
# Epoch: 5	Duration: 84.54s	Train loss: 0.6508	Val loss: 0.6769	Val bias:-0.2094	Val Pearson correlation: 3.9110e-01	Val MeanMult: 4.6611
# Current learning rate: 0.0002
# Epoch: 6	Duration: 89.97s	Train loss: 0.6467	Val loss: 0.6786	Val bias:-0.2197	Val Pearson correlation: 3.9568e-01	Val MeanMult: 4.6473
# Current learning rate: 0.0002
# Epoch: 7	Duration: 95.42s	Train loss: 0.6431	Val loss: 0.6760	Val bias:-0.2200	Val Pearson correlation: 4.0025e-01	Val MeanMult: 4.6269
# Current learning rate: 0.0002
# Epoch: 8	Duration: 88.52s	Train loss: 0.6391	Val loss: 0.6720	Val bias:-0.2172	Val Pearson correlation: 4.0494e-01	Val MeanMult: 4.6044
# Current learning rate: 0.0002
# Epoch: 9	Duration: 95.69s	Train loss: 0.6354	Val loss: 0.6668	Val bias:-0.2120	Val Pearson correlation: 4.0986e-01	Val MeanMult: 4.5789
# Current learning rate: 0.0002
# Epoch: 10	Duration: 85.03s	Train loss: 0.6314	Val loss: 0.6611	Val bias:-0.2061	Val Pearson correlation: 4.1510e-01	Val MeanMult: 4.5511
# Current learning rate: 0.0002
# Epoch: 11	Duration: 97.55s	Train loss: 0.6274	Val loss: 0.6563	Val bias:-0.2029	Val Pearson correlation: 4.2074e-01	Val MeanMult: 4.5205
# Current learning rate: 0.0002
# Epoch: 12	Duration: 84.75s	Train loss: 0.6230	Val loss: 0.6511	Val bias:-0.1995	Val Pearson correlation: 4.2681e-01	Val MeanMult: 4.4864
# Current learning rate: 0.0002
# Epoch: 13	Duration: 84.77s	Train loss: 0.6183	Val loss: 0.6459	Val bias:-0.1967	Val Pearson correlation: 4.3327e-01	Val MeanMult: 4.4483
# Current learning rate: 0.0002
# Epoch: 14	Duration: 98.23s	Train loss: 0.6134	Val loss: 0.6408	Val bias:-0.1949	Val Pearson correlation: 4.4002e-01	Val MeanMult: 4.4082
# Current learning rate: 0.0002
# Epoch: 15	Duration: 84.79s	Train loss: 0.6082	Val loss: 0.6366	Val bias:-0.1955	Val Pearson correlation: 4.4678e-01	Val MeanMult: 4.3672
# Current learning rate: 0.0002
# Epoch: 16	Duration: 105.44s	Train loss: 0.6029	Val loss: 0.6318	Val bias:-0.1942	Val Pearson correlation: 4.5335e-01	Val MeanMult: 4.3300
# Current learning rate: 0.0002
# Epoch: 17	Duration: 85.89s	Train loss: 0.5980	Val loss: 0.6280	Val bias:-0.1950	Val Pearson correlation: 4.5950e-01	Val MeanMult: 4.2982
# Current learning rate: 0.0002
# Epoch: 18	Duration: 85.84s	Train loss: 0.5932	Val loss: 0.6245	Val bias:-0.1955	Val Pearson correlation: 4.6514e-01	Val MeanMult: 4.2712
# Current learning rate: 0.0002
# Epoch: 19	Duration: 84.52s	Train loss: 0.5887	Val loss: 0.6208	Val bias:-0.1950	Val Pearson correlation: 4.7032e-01	Val MeanMult: 4.2481
# Current learning rate: 0.0002
# Checkpoint saved at epoch 20
# Epoch: 20	Duration: 84.92s	Train loss: 0.5845	Val loss: 0.6171	Val bias:-0.1938	Val Pearson correlation: 4.7511e-01	Val MeanMult: 4.2279
# Current learning rate: 0.0002
# Epoch: 21	Duration: 84.74s	Train loss: 0.5804	Val loss: 0.6143	Val bias:-0.1943	Val Pearson correlation: 4.7960e-01	Val MeanMult: 4.2106
# Current learning rate: 0.0002
# Epoch: 22	Duration: 84.77s	Train loss: 0.5767	Val loss: 0.6115	Val bias:-0.1945	Val Pearson correlation: 4.8387e-01	Val MeanMult: 4.1945
# Current learning rate: 0.0002
# Epoch: 23	Duration: 84.89s	Train loss: 0.5730	Val loss: 0.6091	Val bias:-0.1956	Val Pearson correlation: 4.8796e-01	Val MeanMult: 4.1789
# Current learning rate: 0.0002
# Epoch: 24	Duration: 84.89s	Train loss: 0.5692	Val loss: 0.6070	Val bias:-0.1972	Val Pearson correlation: 4.9192e-01	Val MeanMult: 4.1641
# Current learning rate: 0.0002
# Epoch: 25	Duration: 84.78s	Train loss: 0.5658	Val loss: 0.6043	Val bias:-0.1972	Val Pearson correlation: 4.9575e-01	Val MeanMult: 4.1494
# Current learning rate: 0.0002
# Epoch: 26	Duration: 93.54s	Train loss: 0.5622	Val loss: 0.6026	Val bias:-0.1994	Val Pearson correlation: 4.9945e-01	Val MeanMult: 4.1369
# Current learning rate: 0.0002
# Epoch: 27	Duration: 87.37s	Train loss: 0.5587	Val loss: 0.6006	Val bias:-0.2007	Val Pearson correlation: 5.0302e-01	Val MeanMult: 4.1254
# Current learning rate: 0.0002
# Epoch: 28	Duration: 86.57s	Train loss: 0.5553	Val loss: 0.5986	Val bias:-0.2015	Val Pearson correlation: 5.0643e-01	Val MeanMult: 4.1143
# Current learning rate: 0.0002
# Epoch: 29	Duration: 84.86s	Train loss: 0.5519	Val loss: 0.5966	Val bias:-0.2023	Val Pearson correlation: 5.0969e-01	Val MeanMult: 4.1040
# Current learning rate: 0.0002
# Epoch: 30	Duration: 84.87s	Train loss: 0.5486	Val loss: 0.5951	Val bias:-0.2038	Val Pearson correlation: 5.1279e-01	Val MeanMult: 4.0956
# Current learning rate: 0.0002
# Epoch: 31	Duration: 84.89s	Train loss: 0.5455	Val loss: 0.5931	Val bias:-0.2040	Val Pearson correlation: 5.1571e-01	Val MeanMult: 4.0870
# Current learning rate: 0.0002
# Epoch: 32	Duration: 94.09s	Train loss: 0.5427	Val loss: 0.5911	Val bias:-0.2037	Val Pearson correlation: 5.1844e-01	Val MeanMult: 4.0785
# Current learning rate: 0.0002
# Epoch: 33	Duration: 84.91s	Train loss: 0.5398	Val loss: 0.5892	Val bias:-0.2036	Val Pearson correlation: 5.2100e-01	Val MeanMult: 4.0708
# Current learning rate: 0.0002
# Epoch: 34	Duration: 84.99s	Train loss: 0.5370	Val loss: 0.5873	Val bias:-0.2031	Val Pearson correlation: 5.2341e-01	Val MeanMult: 4.0631
# Current learning rate: 0.0002
# Epoch: 35	Duration: 86.14s	Train loss: 0.5345	Val loss: 0.5852	Val bias:-0.2020	Val Pearson correlation: 5.2571e-01	Val MeanMult: 4.0546
# Current learning rate: 0.0002
# Epoch: 36	Duration: 95.33s	Train loss: 0.5321	Val loss: 0.5830	Val bias:-0.2004	Val Pearson correlation: 5.2786e-01	Val MeanMult: 4.0461
# Current learning rate: 0.0002
# Epoch: 37	Duration: 97.61s	Train loss: 0.5299	Val loss: 0.5812	Val bias:-0.1997	Val Pearson correlation: 5.2985e-01	Val MeanMult: 4.0389
# Current learning rate: 0.0002
# Epoch: 38	Duration: 86.03s	Train loss: 0.5278	Val loss: 0.5792	Val bias:-0.1983	Val Pearson correlation: 5.3177e-01	Val MeanMult: 4.0309
# Current learning rate: 0.0002
# Epoch: 39	Duration: 86.10s	Train loss: 0.5260	Val loss: 0.5776	Val bias:-0.1978	Val Pearson correlation: 5.3358e-01	Val MeanMult: 4.0242
# Current learning rate: 0.0002
# Checkpoint saved at epoch 40
# Epoch: 40	Duration: 84.70s	Train loss: 0.5241	Val loss: 0.5759	Val bias:-0.1967	Val Pearson correlation: 5.3527e-01	Val MeanMult: 4.0171
# Current learning rate: 0.0002
# Epoch: 41	Duration: 84.86s	Train loss: 0.5223	Val loss: 0.5745	Val bias:-0.1964	Val Pearson correlation: 5.3689e-01	Val MeanMult: 4.0107
# Current learning rate: 0.0002
# Epoch: 42	Duration: 91.81s	Train loss: 0.5207	Val loss: 0.5724	Val bias:-0.1943	Val Pearson correlation: 5.3844e-01	Val MeanMult: 4.0023
# Current learning rate: 0.0002
# Epoch: 43	Duration: 85.85s	Train loss: 0.5190	Val loss: 0.5711	Val bias:-0.1938	Val Pearson correlation: 5.3989e-01	Val MeanMult: 3.9964
# Current learning rate: 0.0002
# Epoch: 44	Duration: 86.00s	Train loss: 0.5176	Val loss: 0.5695	Val bias:-0.1927	Val Pearson correlation: 5.4127e-01	Val MeanMult: 3.9895
# Current learning rate: 0.0002
# Epoch: 45	Duration: 84.63s	Train loss: 0.5160	Val loss: 0.5677	Val bias:-0.1906	Val Pearson correlation: 5.4260e-01	Val MeanMult: 3.9818
# Current learning rate: 0.0002
# Epoch: 46	Duration: 85.98s	Train loss: 0.5148	Val loss: 0.5666	Val bias:-0.1903	Val Pearson correlation: 5.4385e-01	Val MeanMult: 3.9763
# Current learning rate: 0.0002
# Epoch: 47	Duration: 84.77s	Train loss: 0.5134	Val loss: 0.5655	Val bias:-0.1903	Val Pearson correlation: 5.4509e-01	Val MeanMult: 3.9708
# Current learning rate: 0.0002
# Epoch: 48	Duration: 99.57s	Train loss: 0.5121	Val loss: 0.5641	Val bias:-0.1893	Val Pearson correlation: 5.4625e-01	Val MeanMult: 3.9648
# Current learning rate: 0.0002
# Epoch: 49	Duration: 86.14s	Train loss: 0.5111	Val loss: 0.5633	Val bias:-0.1893	Val Pearson correlation: 5.4733e-01	Val MeanMult: 3.9604
# Current learning rate: 0.0002
# Epoch: 50	Duration: 86.31s	Train loss: 0.5099	Val loss: 0.5619	Val bias:-0.1882	Val Pearson correlation: 5.4844e-01	Val MeanMult: 3.9539
# Current learning rate: 0.0002
# Epoch: 51	Duration: 84.85s	Train loss: 0.5088	Val loss: 0.5609	Val bias:-0.1875	Val Pearson correlation: 5.4944e-01	Val MeanMult: 3.9487
# Current learning rate: 0.0002
# Epoch: 52	Duration: 85.81s	Train loss: 0.5077	Val loss: 0.5597	Val bias:-0.1870	Val Pearson correlation: 5.5048e-01	Val MeanMult: 3.9433
# Current learning rate: 0.0002
# Epoch: 53	Duration: 84.86s	Train loss: 0.5067	Val loss: 0.5589	Val bias:-0.1869	Val Pearson correlation: 5.5146e-01	Val MeanMult: 3.9388
# Current learning rate: 0.0002
# Epoch: 54	Duration: 84.75s	Train loss: 0.5057	Val loss: 0.5586	Val bias:-0.1881	Val Pearson correlation: 5.5240e-01	Val MeanMult: 3.9358
# Current learning rate: 0.0002
# Epoch: 55	Duration: 85.95s	Train loss: 0.5047	Val loss: 0.5571	Val bias:-0.1861	Val Pearson correlation: 5.5333e-01	Val MeanMult: 3.9290
# Current learning rate: 0.0002
# Epoch: 56	Duration: 88.88s	Train loss: 0.5037	Val loss: 0.5562	Val bias:-0.1859	Val Pearson correlation: 5.5429e-01	Val MeanMult: 3.9243
# Current learning rate: 0.0002
# Epoch: 57	Duration: 84.75s	Train loss: 0.5028	Val loss: 0.5553	Val bias:-0.1854	Val Pearson correlation: 5.5512e-01	Val MeanMult: 3.9197
# Current learning rate: 0.0002
# Epoch: 58	Duration: 93.04s	Train loss: 0.5018	Val loss: 0.5548	Val bias:-0.1858	Val Pearson correlation: 5.5598e-01	Val MeanMult: 3.9158
# Current learning rate: 0.0002
# Epoch: 59	Duration: 85.00s	Train loss: 0.5009	Val loss: 0.5540	Val bias:-0.1857	Val Pearson correlation: 5.5685e-01	Val MeanMult: 3.9115
# Current learning rate: 0.0002
# Checkpoint saved at epoch 60
# Epoch: 60	Duration: 96.72s	Train loss: 0.5001	Val loss: 0.5534	Val bias:-0.1860	Val Pearson correlation: 5.5766e-01	Val MeanMult: 3.9078
# Current learning rate: 0.0002
# Epoch: 61	Duration: 89.58s	Train loss: 0.4992	Val loss: 0.5528	Val bias:-0.1862	Val Pearson correlation: 5.5847e-01	Val MeanMult: 3.9040
# Current learning rate: 0.0002
# Epoch: 62	Duration: 85.01s	Train loss: 0.4985	Val loss: 0.5523	Val bias:-0.1868	Val Pearson correlation: 5.5931e-01	Val MeanMult: 3.9004
# Current learning rate: 0.0002
# Epoch: 63	Duration: 84.75s	Train loss: 0.4976	Val loss: 0.5511	Val bias:-0.1855	Val Pearson correlation: 5.6012e-01	Val MeanMult: 3.8949
# Current learning rate: 0.0002
# Epoch: 64	Duration: 84.75s	Train loss: 0.4966	Val loss: 0.5501	Val bias:-0.1844	Val Pearson correlation: 5.6091e-01	Val MeanMult: 3.8894
# Current learning rate: 0.0002
# Epoch: 65	Duration: 85.76s	Train loss: 0.4956	Val loss: 0.5490	Val bias:-0.1833	Val Pearson correlation: 5.6170e-01	Val MeanMult: 3.8839
# Current learning rate: 0.0002
# Epoch: 66	Duration: 103.47s	Train loss: 0.4950	Val loss: 0.5492	Val bias:-0.1855	Val Pearson correlation: 5.6245e-01	Val MeanMult: 3.8829
# Current learning rate: 0.0002
# Epoch: 67	Duration: 84.73s	Train loss: 0.4942	Val loss: 0.5481	Val bias:-0.1842	Val Pearson correlation: 5.6320e-01	Val MeanMult: 3.8772
# Current learning rate: 0.0002
# Epoch: 68	Duration: 85.98s	Train loss: 0.4936	Val loss: 0.5480	Val bias:-0.1861	Val Pearson correlation: 5.6400e-01	Val MeanMult: 3.8755
# Current learning rate: 0.0002
# Epoch: 69	Duration: 86.03s	Train loss: 0.4927	Val loss: 0.5463	Val bias:-0.1829	Val Pearson correlation: 5.6472e-01	Val MeanMult: 3.8677
# Current learning rate: 0.0002
# Epoch: 70	Duration: 99.85s	Train loss: 0.4919	Val loss: 0.5466	Val bias:-0.1857	Val Pearson correlation: 5.6546e-01	Val MeanMult: 3.8672
# Current learning rate: 0.0002
# Epoch: 71	Duration: 93.67s	Train loss: 0.4912	Val loss: 0.5452	Val bias:-0.1833	Val Pearson correlation: 5.6614e-01	Val MeanMult: 3.8607
# Current learning rate: 0.0002
# Epoch: 72	Duration: 103.35s	Train loss: 0.4904	Val loss: 0.5455	Val bias:-0.1861	Val Pearson correlation: 5.6690e-01	Val MeanMult: 3.8599
# Current learning rate: 0.0002
# Epoch: 73	Duration: 84.60s	Train loss: 0.4897	Val loss: 0.5443	Val bias:-0.1844	Val Pearson correlation: 5.6761e-01	Val MeanMult: 3.8542
# Current learning rate: 0.0002
# Epoch: 74	Duration: 85.74s	Train loss: 0.4890	Val loss: 0.5433	Val bias:-0.1833	Val Pearson correlation: 5.6834e-01	Val MeanMult: 3.8490
# Current learning rate: 0.0002
# Epoch: 75	Duration: 84.70s	Train loss: 0.4882	Val loss: 0.5431	Val bias:-0.1844	Val Pearson correlation: 5.6904e-01	Val MeanMult: 3.8467
# Current learning rate: 0.0002
# Epoch: 76	Duration: 90.23s	Train loss: 0.4877	Val loss: 0.5429	Val bias:-0.1854	Val Pearson correlation: 5.6972e-01	Val MeanMult: 3.8444
# Current learning rate: 0.0002
# Epoch: 77	Duration: 96.74s	Train loss: 0.4868	Val loss: 0.5421	Val bias:-0.1849	Val Pearson correlation: 5.7041e-01	Val MeanMult: 3.8401
# Current learning rate: 0.0002
# Epoch: 78	Duration: 99.52s	Train loss: 0.4862	Val loss: 0.5404	Val bias:-0.1821	Val Pearson correlation: 5.7112e-01	Val MeanMult: 3.8324
# Current learning rate: 0.0002
# Epoch: 79	Duration: 90.31s	Train loss: 0.4854	Val loss: 0.5400	Val bias:-0.1826	Val Pearson correlation: 5.7181e-01	Val MeanMult: 3.8294
# Current learning rate: 0.0002
# Checkpoint saved at epoch 80
# Epoch: 80	Duration: 103.39s	Train loss: 0.4848	Val loss: 0.5397	Val bias:-0.1832	Val Pearson correlation: 5.7245e-01	Val MeanMult: 3.8269
# Current learning rate: 0.0002
# Epoch: 81	Duration: 104.09s	Train loss: 0.4841	Val loss: 0.5395	Val bias:-0.1844	Val Pearson correlation: 5.7314e-01	Val MeanMult: 3.8251
# Current learning rate: 0.0002
# Epoch: 82	Duration: 92.02s	Train loss: 0.4834	Val loss: 0.5381	Val bias:-0.1820	Val Pearson correlation: 5.7381e-01	Val MeanMult: 3.8184
# Current learning rate: 0.0002
# Epoch: 83	Duration: 103.93s	Train loss: 0.4828	Val loss: 0.5377	Val bias:-0.1826	Val Pearson correlation: 5.7448e-01	Val MeanMult: 3.8154
# Current learning rate: 0.0002
# Epoch: 84	Duration: 86.94s	Train loss: 0.4820	Val loss: 0.5371	Val bias:-0.1826	Val Pearson correlation: 5.7515e-01	Val MeanMult: 3.8119
# Current learning rate: 0.0002
# Epoch: 85	Duration: 84.78s	Train loss: 0.4813	Val loss: 0.5356	Val bias:-0.1802	Val Pearson correlation: 5.7580e-01	Val MeanMult: 3.8054
# Current learning rate: 0.0002
# Epoch: 86	Duration: 84.71s	Train loss: 0.4807	Val loss: 0.5361	Val bias:-0.1831	Val Pearson correlation: 5.7643e-01	Val MeanMult: 3.8059
# Current learning rate: 0.0002
# Epoch: 87	Duration: 112.34s	Train loss: 0.4800	Val loss: 0.5354	Val bias:-0.1826	Val Pearson correlation: 5.7705e-01	Val MeanMult: 3.8018
# Current learning rate: 0.0002
# Epoch: 88	Duration: 84.76s	Train loss: 0.4795	Val loss: 0.5348	Val bias:-0.1824	Val Pearson correlation: 5.7765e-01	Val MeanMult: 3.7985
# Current learning rate: 0.0002
# Epoch: 89	Duration: 84.88s	Train loss: 0.4789	Val loss: 0.5339	Val bias:-0.1814	Val Pearson correlation: 5.7825e-01	Val MeanMult: 3.7939
# Current learning rate: 0.0002
# Epoch: 90	Duration: 85.01s	Train loss: 0.4783	Val loss: 0.5336	Val bias:-0.1821	Val Pearson correlation: 5.7884e-01	Val MeanMult: 3.7916
# Current learning rate: 0.0002
# Epoch: 91	Duration: 86.06s	Train loss: 0.4777	Val loss: 0.5331	Val bias:-0.1820	Val Pearson correlation: 5.7938e-01	Val MeanMult: 3.7884
# Current learning rate: 0.0002
# Epoch: 92	Duration: 84.89s	Train loss: 0.4771	Val loss: 0.5319	Val bias:-0.1802	Val Pearson correlation: 5.7995e-01	Val MeanMult: 3.7831
# Current learning rate: 0.0002
# Epoch: 93	Duration: 84.86s	Train loss: 0.4763	Val loss: 0.5318	Val bias:-0.1811	Val Pearson correlation: 5.8050e-01	Val MeanMult: 3.7811
# Current learning rate: 0.0002
# Epoch: 94	Duration: 84.87s	Train loss: 0.4759	Val loss: 0.5310	Val bias:-0.1802	Val Pearson correlation: 5.8103e-01	Val MeanMult: 3.7770
# Current learning rate: 0.0002
# Epoch: 95	Duration: 84.62s	Train loss: 0.4755	Val loss: 0.5307	Val bias:-0.1809	Val Pearson correlation: 5.8162e-01	Val MeanMult: 3.7746
# Current learning rate: 0.0002
# Epoch: 96	Duration: 85.50s	Train loss: 0.4748	Val loss: 0.5302	Val bias:-0.1805	Val Pearson correlation: 5.8210e-01	Val MeanMult: 3.7715
# Current learning rate: 0.0002
# Epoch: 97	Duration: 86.12s	Train loss: 0.4742	Val loss: 0.5293	Val bias:-0.1794	Val Pearson correlation: 5.8262e-01	Val MeanMult: 3.7673
# Current learning rate: 0.0002
# Epoch: 98	Duration: 111.66s	Train loss: 0.4737	Val loss: 0.5294	Val bias:-0.1808	Val Pearson correlation: 5.8309e-01	Val MeanMult: 3.7664
# Current learning rate: 0.0002
# Epoch: 99	Duration: 84.92s	Train loss: 0.4733	Val loss: 0.5292	Val bias:-0.1815	Val Pearson correlation: 5.8361e-01	Val MeanMult: 3.7644
# Current learning rate: 0.0002
# Checkpoint saved at epoch 100
# Epoch: 100	Duration: 84.80s	Train loss: 0.4726	Val loss: 0.5283	Val bias:-0.1805	Val Pearson correlation: 5.8415e-01	Val MeanMult: 3.7604
# Current learning rate: 0.0002
# Epoch: 101	Duration: 85.94s	Train loss: 0.4721	Val loss: 0.5272	Val bias:-0.1785	Val Pearson correlation: 5.8462e-01	Val MeanMult: 3.7554
# Current learning rate: 0.0002
# Epoch: 102	Duration: 84.80s	Train loss: 0.4717	Val loss: 0.5277	Val bias:-0.1809	Val Pearson correlation: 5.8507e-01	Val MeanMult: 3.7558
# Current learning rate: 0.0002
# Epoch: 103	Duration: 84.72s	Train loss: 0.4713	Val loss: 0.5265	Val bias:-0.1788	Val Pearson correlation: 5.8556e-01	Val MeanMult: 3.7508
# Current learning rate: 0.0002
# Epoch: 104	Duration: 84.77s	Train loss: 0.4708	Val loss: 0.5265	Val bias:-0.1800	Val Pearson correlation: 5.8602e-01	Val MeanMult: 3.7497
# Current learning rate: 0.0002
# Epoch: 105	Duration: 85.11s	Train loss: 0.4702	Val loss: 0.5256	Val bias:-0.1784	Val Pearson correlation: 5.8647e-01	Val MeanMult: 3.7452
# Current learning rate: 0.0002
# Epoch: 106	Duration: 84.75s	Train loss: 0.4697	Val loss: 0.5257	Val bias:-0.1800	Val Pearson correlation: 5.8696e-01	Val MeanMult: 3.7449
# Current learning rate: 0.0002
# Epoch: 107	Duration: 84.89s	Train loss: 0.4693	Val loss: 0.5253	Val bias:-0.1801	Val Pearson correlation: 5.8742e-01	Val MeanMult: 3.7423
# Current learning rate: 0.0002
# Epoch: 108	Duration: 85.11s	Train loss: 0.4688	Val loss: 0.5245	Val bias:-0.1789	Val Pearson correlation: 5.8786e-01	Val MeanMult: 3.7385
# Current learning rate: 0.0002
# Epoch: 109	Duration: 86.18s	Train loss: 0.4683	Val loss: 0.5239	Val bias:-0.1786	Val Pearson correlation: 5.8834e-01	Val MeanMult: 3.7356
# Current learning rate: 0.0002
# Epoch: 110	Duration: 84.80s	Train loss: 0.4678	Val loss: 0.5234	Val bias:-0.1781	Val Pearson correlation: 5.8876e-01	Val MeanMult: 3.7328
# Current learning rate: 0.0002
# Epoch: 111	Duration: 84.78s	Train loss: 0.4673	Val loss: 0.5232	Val bias:-0.1789	Val Pearson correlation: 5.8922e-01	Val MeanMult: 3.7314
# Current learning rate: 0.0002
# Epoch: 112	Duration: 84.87s	Train loss: 0.4668	Val loss: 0.5229	Val bias:-0.1789	Val Pearson correlation: 5.8961e-01	Val MeanMult: 3.7294
# Current learning rate: 0.0002
# Epoch: 113	Duration: 85.11s	Train loss: 0.4665	Val loss: 0.5219	Val bias:-0.1773	Val Pearson correlation: 5.9010e-01	Val MeanMult: 3.7247
# Current learning rate: 0.0002
# Epoch: 114	Duration: 93.20s	Train loss: 0.4661	Val loss: 0.5218	Val bias:-0.1781	Val Pearson correlation: 5.9050e-01	Val MeanMult: 3.7237
# Current learning rate: 0.0002
# Epoch: 115	Duration: 85.90s	Train loss: 0.4655	Val loss: 0.5216	Val bias:-0.1785	Val Pearson correlation: 5.9093e-01	Val MeanMult: 3.7221
# Current learning rate: 0.0002
# Epoch: 116	Duration: 99.52s	Train loss: 0.4649	Val loss: 0.5207	Val bias:-0.1771	Val Pearson correlation: 5.9137e-01	Val MeanMult: 3.7179
# Current learning rate: 0.0002
# Epoch: 117	Duration: 84.82s	Train loss: 0.4647	Val loss: 0.5205	Val bias:-0.1775	Val Pearson correlation: 5.9180e-01	Val MeanMult: 3.7160
# Current learning rate: 0.0002
# Epoch: 118	Duration: 92.37s	Train loss: 0.4640	Val loss: 0.5198	Val bias:-0.1767	Val Pearson correlation: 5.9222e-01	Val MeanMult: 3.7126
# Current learning rate: 0.0002
# Epoch: 119	Duration: 86.05s	Train loss: 0.4636	Val loss: 0.5198	Val bias:-0.1779	Val Pearson correlation: 5.9265e-01	Val MeanMult: 3.7120
# Current learning rate: 0.0002
# Checkpoint saved at epoch 120
# Epoch: 120	Duration: 84.74s	Train loss: 0.4632	Val loss: 0.5193	Val bias:-0.1774	Val Pearson correlation: 5.9308e-01	Val MeanMult: 3.7088
# Current learning rate: 0.0002
# Epoch: 121	Duration: 84.74s	Train loss: 0.4628	Val loss: 0.5185	Val bias:-0.1761	Val Pearson correlation: 5.9345e-01	Val MeanMult: 3.7050
# Current learning rate: 0.0002
# Epoch: 122	Duration: 86.01s	Train loss: 0.4623	Val loss: 0.5184	Val bias:-0.1766	Val Pearson correlation: 5.9384e-01	Val MeanMult: 3.7035
# Current learning rate: 0.0002
# Epoch: 123	Duration: 90.99s	Train loss: 0.4619	Val loss: 0.5180	Val bias:-0.1772	Val Pearson correlation: 5.9433e-01	Val MeanMult: 3.7015
# Current learning rate: 0.0002
# Epoch: 124	Duration: 87.67s	Train loss: 0.4615	Val loss: 0.5169	Val bias:-0.1750	Val Pearson correlation: 5.9476e-01	Val MeanMult: 3.6964
# Current learning rate: 0.0002
# Epoch: 125	Duration: 84.77s	Train loss: 0.4612	Val loss: 0.5167	Val bias:-0.1755	Val Pearson correlation: 5.9517e-01	Val MeanMult: 3.6947
# Current learning rate: 0.0002
# Epoch: 126	Duration: 101.88s	Train loss: 0.4608	Val loss: 0.5166	Val bias:-0.1761	Val Pearson correlation: 5.9559e-01	Val MeanMult: 3.6933
# Current learning rate: 0.0002
# Epoch: 127	Duration: 85.83s	Train loss: 0.4602	Val loss: 0.5159	Val bias:-0.1751	Val Pearson correlation: 5.9597e-01	Val MeanMult: 3.6899
# Current learning rate: 0.0002
# Epoch: 128	Duration: 84.69s	Train loss: 0.4596	Val loss: 0.5161	Val bias:-0.1768	Val Pearson correlation: 5.9642e-01	Val MeanMult: 3.6900
# Current learning rate: 0.0002
# Epoch: 129	Duration: 84.76s	Train loss: 0.4593	Val loss: 0.5153	Val bias:-0.1758	Val Pearson correlation: 5.9688e-01	Val MeanMult: 3.6861
# Current learning rate: 0.0002
# Epoch: 130	Duration: 86.00s	Train loss: 0.4590	Val loss: 0.5155	Val bias:-0.1771	Val Pearson correlation: 5.9724e-01	Val MeanMult: 3.6857
# Current learning rate: 0.0002
# Epoch: 131	Duration: 86.26s	Train loss: 0.4585	Val loss: 0.5140	Val bias:-0.1743	Val Pearson correlation: 5.9767e-01	Val MeanMult: 3.6795
# Current learning rate: 0.0002
# Epoch: 132	Duration: 84.80s	Train loss: 0.4581	Val loss: 0.5148	Val bias:-0.1775	Val Pearson correlation: 5.9809e-01	Val MeanMult: 3.6815
# Current learning rate: 0.0002
# Epoch: 133	Duration: 84.64s	Train loss: 0.4575	Val loss: 0.5141	Val bias:-0.1762	Val Pearson correlation: 5.9848e-01	Val MeanMult: 3.6776
# Current learning rate: 0.0002
# Epoch: 134	Duration: 86.08s	Train loss: 0.4572	Val loss: 0.5141	Val bias:-0.1776	Val Pearson correlation: 5.9895e-01	Val MeanMult: 3.6768
# Current learning rate: 0.0002
# Epoch: 135	Duration: 84.64s	Train loss: 0.4566	Val loss: 0.5124	Val bias:-0.1739	Val Pearson correlation: 5.9934e-01	Val MeanMult: 3.6697
# Current learning rate: 0.0002
# Epoch: 136	Duration: 84.43s	Train loss: 0.4562	Val loss: 0.5127	Val bias:-0.1756	Val Pearson correlation: 5.9973e-01	Val MeanMult: 3.6698
# Current learning rate: 0.0002
# Epoch: 137	Duration: 85.71s	Train loss: 0.4559	Val loss: 0.5124	Val bias:-0.1759	Val Pearson correlation: 6.0022e-01	Val MeanMult: 3.6677
# Current learning rate: 0.0002
# Epoch: 138	Duration: 96.46s	Train loss: 0.4556	Val loss: 0.5111	Val bias:-0.1732	Val Pearson correlation: 6.0060e-01	Val MeanMult: 3.6619
# Current learning rate: 0.0002
# Epoch: 139	Duration: 84.63s	Train loss: 0.4549	Val loss: 0.5117	Val bias:-0.1762	Val Pearson correlation: 6.0106e-01	Val MeanMult: 3.6632
# Current learning rate: 0.0002
# Checkpoint saved at epoch 140
# Epoch: 140	Duration: 85.11s	Train loss: 0.4546	Val loss: 0.5113	Val bias:-0.1760	Val Pearson correlation: 6.0150e-01	Val MeanMult: 3.6608
# Current learning rate: 0.0002
# Epoch: 141	Duration: 84.57s	Train loss: 0.4543	Val loss: 0.5095	Val bias:-0.1719	Val Pearson correlation: 6.0190e-01	Val MeanMult: 3.6528
# Current learning rate: 0.0002
# Epoch: 142	Duration: 85.84s	Train loss: 0.4536	Val loss: 0.5100	Val bias:-0.1745	Val Pearson correlation: 6.0233e-01	Val MeanMult: 3.6538
# Current learning rate: 0.0002
# Epoch: 143	Duration: 84.88s	Train loss: 0.4532	Val loss: 0.5098	Val bias:-0.1752	Val Pearson correlation: 6.0281e-01	Val MeanMult: 3.6521
# Current learning rate: 0.0002
# Epoch: 144	Duration: 89.65s	Train loss: 0.4529	Val loss: 0.5097	Val bias:-0.1757	Val Pearson correlation: 6.0322e-01	Val MeanMult: 3.6505
# Current learning rate: 0.0002
# Epoch: 145	Duration: 84.67s	Train loss: 0.4524	Val loss: 0.5080	Val bias:-0.1722	Val Pearson correlation: 6.0366e-01	Val MeanMult: 3.6434
# Current learning rate: 0.0002
# Epoch: 146	Duration: 84.72s	Train loss: 0.4519	Val loss: 0.5082	Val bias:-0.1741	Val Pearson correlation: 6.0413e-01	Val MeanMult: 3.6431
# Current learning rate: 0.0002
# Epoch: 147	Duration: 84.82s	Train loss: 0.4515	Val loss: 0.5079	Val bias:-0.1743	Val Pearson correlation: 6.0456e-01	Val MeanMult: 3.6410
# Current learning rate: 0.0002
# Epoch: 148	Duration: 84.84s	Train loss: 0.4510	Val loss: 0.5074	Val bias:-0.1739	Val Pearson correlation: 6.0499e-01	Val MeanMult: 3.6379
# Current learning rate: 0.0002
# Epoch: 149	Duration: 84.72s	Train loss: 0.4507	Val loss: 0.5075	Val bias:-0.1752	Val Pearson correlation: 6.0548e-01	Val MeanMult: 3.6370
# Current learning rate: 0.0002
# Epoch: 150	Duration: 84.93s	Train loss: 0.4502	Val loss: 0.5060	Val bias:-0.1721	Val Pearson correlation: 6.0591e-01	Val MeanMult: 3.6303
# Current learning rate: 0.0002
# Epoch: 151	Duration: 86.00s	Train loss: 0.4495	Val loss: 0.5060	Val bias:-0.1733	Val Pearson correlation: 6.0637e-01	Val MeanMult: 3.6294
# Current learning rate: 0.0002
# Epoch: 152	Duration: 84.81s	Train loss: 0.4493	Val loss: 0.5046	Val bias:-0.1707	Val Pearson correlation: 6.0685e-01	Val MeanMult: 3.6231
# Current learning rate: 0.0002
# Epoch: 153	Duration: 84.75s	Train loss: 0.4489	Val loss: 0.5056	Val bias:-0.1745	Val Pearson correlation: 6.0728e-01	Val MeanMult: 3.6255
# Current learning rate: 0.0002
# Epoch: 154	Duration: 84.92s	Train loss: 0.4483	Val loss: 0.5051	Val bias:-0.1745	Val Pearson correlation: 6.0778e-01	Val MeanMult: 3.6227
# Current learning rate: 0.0002
# Epoch: 155	Duration: 84.88s	Train loss: 0.4481	Val loss: 0.5044	Val bias:-0.1733	Val Pearson correlation: 6.0821e-01	Val MeanMult: 3.6189
# Current learning rate: 0.0002
# Epoch: 156	Duration: 84.61s	Train loss: 0.4474	Val loss: 0.5040	Val bias:-0.1736	Val Pearson correlation: 6.0869e-01	Val MeanMult: 3.6163
# Current learning rate: 0.0002
# Epoch: 157	Duration: 97.95s	Train loss: 0.4468	Val loss: 0.5031	Val bias:-0.1720	Val Pearson correlation: 6.0915e-01	Val MeanMult: 3.6119
# Current learning rate: 0.0002
# Epoch: 158	Duration: 84.57s	Train loss: 0.4464	Val loss: 0.5037	Val bias:-0.1749	Val Pearson correlation: 6.0962e-01	Val MeanMult: 3.6131
# Current learning rate: 0.0002
# Epoch: 159	Duration: 87.08s	Train loss: 0.4459	Val loss: 0.5022	Val bias:-0.1721	Val Pearson correlation: 6.1011e-01	Val MeanMult: 3.6063
# Current learning rate: 0.0002
# Checkpoint saved at epoch 160
# Epoch: 160	Duration: 84.65s	Train loss: 0.4456	Val loss: 0.5012	Val bias:-0.1703	Val Pearson correlation: 6.1057e-01	Val MeanMult: 3.6013
# Current learning rate: 0.0002
# Epoch: 161	Duration: 103.64s	Train loss: 0.4449	Val loss: 0.5019	Val bias:-0.1735	Val Pearson correlation: 6.1106e-01	Val MeanMult: 3.6027
# Current learning rate: 0.0002
# Epoch: 162	Duration: 84.88s	Train loss: 0.4446	Val loss: 0.5016	Val bias:-0.1740	Val Pearson correlation: 6.1156e-01	Val MeanMult: 3.6005
# Current learning rate: 0.0002
# Epoch: 163	Duration: 84.77s	Train loss: 0.4441	Val loss: 0.5000	Val bias:-0.1707	Val Pearson correlation: 6.1207e-01	Val MeanMult: 3.5934
# Current learning rate: 0.0002
# Epoch: 164	Duration: 85.89s	Train loss: 0.4435	Val loss: 0.4999	Val bias:-0.1717	Val Pearson correlation: 6.1256e-01	Val MeanMult: 3.5916
# Current learning rate: 0.0002
# Epoch: 165	Duration: 85.79s	Train loss: 0.4432	Val loss: 0.4993	Val bias:-0.1710	Val Pearson correlation: 6.1305e-01	Val MeanMult: 3.5880
# Current learning rate: 0.0002
# Epoch: 166	Duration: 84.81s	Train loss: 0.4427	Val loss: 0.4987	Val bias:-0.1705	Val Pearson correlation: 6.1353e-01	Val MeanMult: 3.5846
# Current learning rate: 0.0002
# Epoch: 167	Duration: 84.55s	Train loss: 0.4420	Val loss: 0.4982	Val bias:-0.1705	Val Pearson correlation: 6.1407e-01	Val MeanMult: 3.5814
# Current learning rate: 0.0002
# Epoch: 168	Duration: 84.63s	Train loss: 0.4415	Val loss: 0.4982	Val bias:-0.1719	Val Pearson correlation: 6.1455e-01	Val MeanMult: 3.5804
# Current learning rate: 0.0002
# Epoch: 169	Duration: 84.67s	Train loss: 0.4413	Val loss: 0.4973	Val bias:-0.1708	Val Pearson correlation: 6.1509e-01	Val MeanMult: 3.5756
# Current learning rate: 0.0002
# Epoch: 170	Duration: 102.77s	Train loss: 0.4406	Val loss: 0.4970	Val bias:-0.1709	Val Pearson correlation: 6.1558e-01	Val MeanMult: 3.5732
# Current learning rate: 0.0002
# Epoch: 171	Duration: 85.27s	Train loss: 0.4402	Val loss: 0.4963	Val bias:-0.1703	Val Pearson correlation: 6.1612e-01	Val MeanMult: 3.5692
# Current learning rate: 0.0002
# Epoch: 172	Duration: 84.61s	Train loss: 0.4397	Val loss: 0.4955	Val bias:-0.1690	Val Pearson correlation: 6.1658e-01	Val MeanMult: 3.5648
# Current learning rate: 0.0002
# Epoch: 173	Duration: 87.61s	Train loss: 0.4391	Val loss: 0.4952	Val bias:-0.1698	Val Pearson correlation: 6.1717e-01	Val MeanMult: 3.5625
# Current learning rate: 0.0002
# Epoch: 174	Duration: 86.22s	Train loss: 0.4387	Val loss: 0.4948	Val bias:-0.1701	Val Pearson correlation: 6.1762e-01	Val MeanMult: 3.5602
# Current learning rate: 0.0002
# Epoch: 175	Duration: 85.92s	Train loss: 0.4382	Val loss: 0.4937	Val bias:-0.1685	Val Pearson correlation: 6.1825e-01	Val MeanMult: 3.5546
# Current learning rate: 0.0002
# Epoch: 176	Duration: 84.76s	Train loss: 0.4376	Val loss: 0.4929	Val bias:-0.1675	Val Pearson correlation: 6.1878e-01	Val MeanMult: 3.5503
# Current learning rate: 0.0002
# Epoch: 177	Duration: 90.65s	Train loss: 0.4372	Val loss: 0.4927	Val bias:-0.1684	Val Pearson correlation: 6.1934e-01	Val MeanMult: 3.5481
# Current learning rate: 0.0002
# Epoch: 178	Duration: 85.82s	Train loss: 0.4367	Val loss: 0.4926	Val bias:-0.1696	Val Pearson correlation: 6.1986e-01	Val MeanMult: 3.5461
# Current learning rate: 0.0002
# Epoch: 179	Duration: 86.29s	Train loss: 0.4360	Val loss: 0.4903	Val bias:-0.1644	Val Pearson correlation: 6.2048e-01	Val MeanMult: 3.5361
# Current learning rate: 0.0002
# Checkpoint saved at epoch 180
# Epoch: 180	Duration: 85.79s	Train loss: 0.4354	Val loss: 0.4905	Val bias:-0.1665	Val Pearson correlation: 6.2108e-01	Val MeanMult: 3.5352
# Current learning rate: 0.0002
# Epoch: 181	Duration: 84.73s	Train loss: 0.4351	Val loss: 0.4905	Val bias:-0.1679	Val Pearson correlation: 6.2159e-01	Val MeanMult: 3.5342
# Current learning rate: 0.0002
# Epoch: 182	Duration: 84.71s	Train loss: 0.4344	Val loss: 0.4908	Val bias:-0.1702	Val Pearson correlation: 6.2216e-01	Val MeanMult: 3.5337
# Current learning rate: 0.0002
# Epoch: 183	Duration: 96.32s	Train loss: 0.4339	Val loss: 0.4889	Val bias:-0.1662	Val Pearson correlation: 6.2282e-01	Val MeanMult: 3.5250
# Current learning rate: 0.0002
# Epoch: 184	Duration: 85.78s	Train loss: 0.4333	Val loss: 0.4890	Val bias:-0.1685	Val Pearson correlation: 6.2339e-01	Val MeanMult: 3.5238
# Current learning rate: 0.0002
# Epoch: 185	Duration: 84.83s	Train loss: 0.4329	Val loss: 0.4874	Val bias:-0.1651	Val Pearson correlation: 6.2397e-01	Val MeanMult: 3.5165
# Current learning rate: 0.0002
# Epoch: 186	Duration: 85.89s	Train loss: 0.4323	Val loss: 0.4864	Val bias:-0.1636	Val Pearson correlation: 6.2459e-01	Val MeanMult: 3.5111
# Current learning rate: 0.0002
# Epoch: 187	Duration: 84.75s	Train loss: 0.4318	Val loss: 0.4869	Val bias:-0.1666	Val Pearson correlation: 6.2516e-01	Val MeanMult: 3.5115
# Current learning rate: 0.0002
# Epoch: 188	Duration: 84.74s	Train loss: 0.4315	Val loss: 0.4846	Val bias:-0.1611	Val Pearson correlation: 6.2571e-01	Val MeanMult: 3.5016
# Current learning rate: 0.0002
# Epoch: 189	Duration: 84.68s	Train loss: 0.4306	Val loss: 0.4854	Val bias:-0.1656	Val Pearson correlation: 6.2634e-01	Val MeanMult: 3.5028
# Current learning rate: 0.0002
# Epoch: 190	Duration: 84.76s	Train loss: 0.4301	Val loss: 0.4848	Val bias:-0.1653	Val Pearson correlation: 6.2699e-01	Val MeanMult: 3.4994
# Current learning rate: 0.0002
# Epoch: 191	Duration: 85.25s	Train loss: 0.4297	Val loss: 0.4835	Val bias:-0.1632	Val Pearson correlation: 6.2757e-01	Val MeanMult: 3.4928
# Current learning rate: 0.0002
# Epoch: 192	Duration: 89.19s	Train loss: 0.4292	Val loss: 0.4825	Val bias:-0.1617	Val Pearson correlation: 6.2818e-01	Val MeanMult: 3.4875
# Current learning rate: 0.0002
# Epoch: 193	Duration: 84.82s	Train loss: 0.4284	Val loss: 0.4815	Val bias:-0.1606	Val Pearson correlation: 6.2883e-01	Val MeanMult: 3.4820
# Current learning rate: 0.0002
# Epoch: 194	Duration: 85.84s	Train loss: 0.4280	Val loss: 0.4813	Val bias:-0.1615	Val Pearson correlation: 6.2940e-01	Val MeanMult: 3.4799
# Current learning rate: 0.0002
# Epoch: 195	Duration: 84.71s	Train loss: 0.4271	Val loss: 0.4805	Val bias:-0.1607	Val Pearson correlation: 6.3004e-01	Val MeanMult: 3.4748
# Current learning rate: 0.0002
# Epoch: 196	Duration: 85.60s	Train loss: 0.4269	Val loss: 0.4809	Val bias:-0.1639	Val Pearson correlation: 6.3058e-01	Val MeanMult: 3.4744
# Current learning rate: 0.0002
# Epoch: 197	Duration: 105.81s	Train loss: 0.4262	Val loss: 0.4786	Val bias:-0.1585	Val Pearson correlation: 6.3120e-01	Val MeanMult: 3.4646
# Current learning rate: 0.0002
# Epoch: 198	Duration: 84.64s	Train loss: 0.4258	Val loss: 0.4789	Val bias:-0.1608	Val Pearson correlation: 6.3177e-01	Val MeanMult: 3.4640
# Current learning rate: 0.0002
# Epoch: 199	Duration: 84.64s	Train loss: 0.4250	Val loss: 0.4780	Val bias:-0.1596	Val Pearson correlation: 6.3237e-01	Val MeanMult: 3.4584
# Current learning rate: 0.0002
# Checkpoint saved at epoch 200
# Epoch: 200	Duration: 87.23s	Train loss: 0.4247	Val loss: 0.4776	Val bias:-0.1601	Val Pearson correlation: 6.3297e-01	Val MeanMult: 3.4560
# Current learning rate: 0.0002
# Epoch: 201	Duration: 84.72s	Train loss: 0.4241	Val loss: 0.4766	Val bias:-0.1584	Val Pearson correlation: 6.3354e-01	Val MeanMult: 3.4509
# Current learning rate: 0.0002
# Epoch: 202	Duration: 86.04s	Train loss: 0.4237	Val loss: 0.4752	Val bias:-0.1557	Val Pearson correlation: 6.3406e-01	Val MeanMult: 3.4444
# Current learning rate: 0.0002
# Epoch: 203	Duration: 84.95s	Train loss: 0.4228	Val loss: 0.4751	Val bias:-0.1571	Val Pearson correlation: 6.3464e-01	Val MeanMult: 3.4421
# Current learning rate: 0.0002
# Epoch: 204	Duration: 109.56s	Train loss: 0.4223	Val loss: 0.4746	Val bias:-0.1568	Val Pearson correlation: 6.3517e-01	Val MeanMult: 3.4394
# Current learning rate: 0.0002
# Epoch: 205	Duration: 93.46s	Train loss: 0.4217	Val loss: 0.4748	Val bias:-0.1586	Val Pearson correlation: 6.3566e-01	Val MeanMult: 3.4382
# Current learning rate: 0.0002
# Epoch: 206	Duration: 84.89s	Train loss: 0.4216	Val loss: 0.4727	Val bias:-0.1535	Val Pearson correlation: 6.3615e-01	Val MeanMult: 3.4300
# Current learning rate: 0.0002
# Epoch: 207	Duration: 90.60s	Train loss: 0.4211	Val loss: 0.4726	Val bias:-0.1546	Val Pearson correlation: 6.3667e-01	Val MeanMult: 3.4282
# Current learning rate: 0.0002
# Epoch: 208	Duration: 85.99s	Train loss: 0.4206	Val loss: 0.4717	Val bias:-0.1532	Val Pearson correlation: 6.3711e-01	Val MeanMult: 3.4234
# Current learning rate: 0.0002
# Epoch: 209	Duration: 84.77s	Train loss: 0.4201	Val loss: 0.4720	Val bias:-0.1554	Val Pearson correlation: 6.3756e-01	Val MeanMult: 3.4228
# Current learning rate: 0.0002
# Epoch: 210	Duration: 89.96s	Train loss: 0.4195	Val loss: 0.4713	Val bias:-0.1545	Val Pearson correlation: 6.3805e-01	Val MeanMult: 3.4189
# Current learning rate: 0.0002
# Epoch: 211	Duration: 85.06s	Train loss: 0.4193	Val loss: 0.4701	Val bias:-0.1517	Val Pearson correlation: 6.3852e-01	Val MeanMult: 3.4146
# Current learning rate: 0.0002
# Epoch: 212	Duration: 104.16s	Train loss: 0.4186	Val loss: 0.4703	Val bias:-0.1542	Val Pearson correlation: 6.3900e-01	Val MeanMult: 3.4139
# Current learning rate: 0.0002
# Epoch: 213	Duration: 90.48s	Train loss: 0.4185	Val loss: 0.4683	Val bias:-0.1485	Val Pearson correlation: 6.3935e-01	Val MeanMult: 3.4055
# Current learning rate: 0.0002
# Epoch: 214	Duration: 85.95s	Train loss: 0.4179	Val loss: 0.4696	Val bias:-0.1537	Val Pearson correlation: 6.3974e-01	Val MeanMult: 3.4087
# Current learning rate: 0.0002
# Epoch: 215	Duration: 84.74s	Train loss: 0.4174	Val loss: 0.4691	Val bias:-0.1534	Val Pearson correlation: 6.4014e-01	Val MeanMult: 3.4056
# Current learning rate: 0.0002
# Epoch: 216	Duration: 87.97s	Train loss: 0.4172	Val loss: 0.4670	Val bias:-0.1478	Val Pearson correlation: 6.4052e-01	Val MeanMult: 3.3974
# Current learning rate: 0.0002
# Epoch: 217	Duration: 84.84s	Train loss: 0.4166	Val loss: 0.4674	Val bias:-0.1503	Val Pearson correlation: 6.4095e-01	Val MeanMult: 3.3980
# Current learning rate: 0.0002
# Epoch: 218	Duration: 85.78s	Train loss: 0.4161	Val loss: 0.4660	Val bias:-0.1464	Val Pearson correlation: 6.4127e-01	Val MeanMult: 3.3918
# Current learning rate: 0.0002
# Epoch: 219	Duration: 84.95s	Train loss: 0.4157	Val loss: 0.4659	Val bias:-0.1472	Val Pearson correlation: 6.4170e-01	Val MeanMult: 3.3903
# Current learning rate: 0.0002
# Checkpoint saved at epoch 220
# Epoch: 220	Duration: 85.05s	Train loss: 0.4155	Val loss: 0.4651	Val bias:-0.1453	Val Pearson correlation: 6.4201e-01	Val MeanMult: 3.3863
# Current learning rate: 0.0002
# Epoch: 221	Duration: 84.87s	Train loss: 0.4150	Val loss: 0.4650	Val bias:-0.1457	Val Pearson correlation: 6.4231e-01	Val MeanMult: 3.3845
# Current learning rate: 0.0002
# Epoch: 222	Duration: 84.94s	Train loss: 0.4147	Val loss: 0.4647	Val bias:-0.1463	Val Pearson correlation: 6.4275e-01	Val MeanMult: 3.3835
# Current learning rate: 0.0002
# Epoch: 223	Duration: 84.79s	Train loss: 0.4140	Val loss: 0.4628	Val bias:-0.1408	Val Pearson correlation: 6.4307e-01	Val MeanMult: 3.3758
# Current learning rate: 0.0002
# Epoch: 224	Duration: 91.27s	Train loss: 0.4137	Val loss: 0.4640	Val bias:-0.1460	Val Pearson correlation: 6.4338e-01	Val MeanMult: 3.3792
# Current learning rate: 0.0002
# Epoch: 225	Duration: 84.74s	Train loss: 0.4137	Val loss: 0.4624	Val bias:-0.1411	Val Pearson correlation: 6.4374e-01	Val MeanMult: 3.3730
# Current learning rate: 0.0002
# Epoch: 226	Duration: 84.85s	Train loss: 0.4134	Val loss: 0.4614	Val bias:-0.1387	Val Pearson correlation: 6.4403e-01	Val MeanMult: 3.3689
# Current learning rate: 0.0002
# Epoch: 227	Duration: 84.58s	Train loss: 0.4128	Val loss: 0.4624	Val bias:-0.1427	Val Pearson correlation: 6.4426e-01	Val MeanMult: 3.3713
# Current learning rate: 0.0002
# Epoch: 228	Duration: 84.71s	Train loss: 0.4126	Val loss: 0.4603	Val bias:-0.1365	Val Pearson correlation: 6.4461e-01	Val MeanMult: 3.3633
# Current learning rate: 0.0002
# Epoch: 229	Duration: 84.79s	Train loss: 0.4122	Val loss: 0.4605	Val bias:-0.1383	Val Pearson correlation: 6.4490e-01	Val MeanMult: 3.3633
# Current learning rate: 0.0002
# Epoch: 230	Duration: 84.67s	Train loss: 0.4118	Val loss: 0.4594	Val bias:-0.1346	Val Pearson correlation: 6.4518e-01	Val MeanMult: 3.3590
# Current learning rate: 0.0002
# Epoch: 231	Duration: 84.71s	Train loss: 0.4116	Val loss: 0.4601	Val bias:-0.1387	Val Pearson correlation: 6.4558e-01	Val MeanMult: 3.3613
# Current learning rate: 0.0002
# Epoch: 232	Duration: 98.89s	Train loss: 0.4110	Val loss: 0.4595	Val bias:-0.1365	Val Pearson correlation: 6.4573e-01	Val MeanMult: 3.3574
# Current learning rate: 0.0002
# Epoch: 233	Duration: 92.95s	Train loss: 0.4112	Val loss: 0.4589	Val bias:-0.1366	Val Pearson correlation: 6.4612e-01	Val MeanMult: 3.3551
# Current learning rate: 0.0002
# Epoch: 234	Duration: 89.34s	Train loss: 0.4105	Val loss: 0.4583	Val bias:-0.1341	Val Pearson correlation: 6.4628e-01	Val MeanMult: 3.3524
# Current learning rate: 0.0002
# Epoch: 235	Duration: 84.61s	Train loss: 0.4104	Val loss: 0.4580	Val bias:-0.1341	Val Pearson correlation: 6.4660e-01	Val MeanMult: 3.3510
# Current learning rate: 0.0002
# Epoch: 236	Duration: 84.90s	Train loss: 0.4102	Val loss: 0.4571	Val bias:-0.1314	Val Pearson correlation: 6.4680e-01	Val MeanMult: 3.3469
# Current learning rate: 0.0002
# Epoch: 237	Duration: 84.69s	Train loss: 0.4096	Val loss: 0.4570	Val bias:-0.1323	Val Pearson correlation: 6.4709e-01	Val MeanMult: 3.3463
# Current learning rate: 0.0002
# Epoch: 238	Duration: 84.81s	Train loss: 0.4092	Val loss: 0.4563	Val bias:-0.1307	Val Pearson correlation: 6.4737e-01	Val MeanMult: 3.3437
# Current learning rate: 0.0002
# Epoch: 239	Duration: 84.69s	Train loss: 0.4091	Val loss: 0.4550	Val bias:-0.1264	Val Pearson correlation: 6.4766e-01	Val MeanMult: 3.3390
# Current learning rate: 0.0002
# Checkpoint saved at epoch 240
# Epoch: 240	Duration: 84.63s	Train loss: 0.4085	Val loss: 0.4555	Val bias:-0.1290	Val Pearson correlation: 6.4794e-01	Val MeanMult: 3.3399
# Current learning rate: 0.0002
# Epoch: 241	Duration: 90.92s	Train loss: 0.4088	Val loss: 0.4556	Val bias:-0.1308	Val Pearson correlation: 6.4821e-01	Val MeanMult: 3.3399
# Current learning rate: 0.0002
# Epoch: 242	Duration: 85.84s	Train loss: 0.4083	Val loss: 0.4547	Val bias:-0.1277	Val Pearson correlation: 6.4843e-01	Val MeanMult: 3.3363
# Current learning rate: 0.0002
# Epoch: 243	Duration: 88.50s	Train loss: 0.4076	Val loss: 0.4550	Val bias:-0.1295	Val Pearson correlation: 6.4863e-01	Val MeanMult: 3.3364
# Current learning rate: 0.0002
# Epoch: 244	Duration: 87.79s	Train loss: 0.4076	Val loss: 0.4540	Val bias:-0.1268	Val Pearson correlation: 6.4883e-01	Val MeanMult: 3.3323
# Current learning rate: 0.0002
# Epoch: 245	Duration: 84.72s	Train loss: 0.4075	Val loss: 0.4538	Val bias:-0.1265	Val Pearson correlation: 6.4912e-01	Val MeanMult: 3.3313
# Current learning rate: 0.0002
# Epoch: 246	Duration: 84.92s	Train loss: 0.4070	Val loss: 0.4532	Val bias:-0.1247	Val Pearson correlation: 6.4932e-01	Val MeanMult: 3.3288
# Current learning rate: 0.0002
# Epoch: 247	Duration: 99.53s	Train loss: 0.4068	Val loss: 0.4531	Val bias:-0.1253	Val Pearson correlation: 6.4950e-01	Val MeanMult: 3.3279
# Current learning rate: 0.0002
# Epoch: 248	Duration: 85.87s	Train loss: 0.4063	Val loss: 0.4522	Val bias:-0.1232	Val Pearson correlation: 6.4987e-01	Val MeanMult: 3.3248
# Current learning rate: 0.0002
# Epoch: 249	Duration: 85.78s	Train loss: 0.4059	Val loss: 0.4522	Val bias:-0.1239	Val Pearson correlation: 6.5004e-01	Val MeanMult: 3.3237
# Current learning rate: 0.0002
# Epoch: 250	Duration: 84.74s	Train loss: 0.4057	Val loss: 0.4505	Val bias:-0.1171	Val Pearson correlation: 6.5018e-01	Val MeanMult: 3.3173
# Current learning rate: 0.0002
# Epoch: 251	Duration: 85.40s	Train loss: 0.4058	Val loss: 0.4520	Val bias:-0.1250	Val Pearson correlation: 6.5052e-01	Val MeanMult: 3.3220
# Current learning rate: 0.0002
# Epoch: 252	Duration: 84.73s	Train loss: 0.4054	Val loss: 0.4504	Val bias:-0.1192	Val Pearson correlation: 6.5072e-01	Val MeanMult: 3.3167
# Current learning rate: 0.0002
# Epoch: 253	Duration: 84.53s	Train loss: 0.4048	Val loss: 0.4505	Val bias:-0.1196	Val Pearson correlation: 6.5091e-01	Val MeanMult: 3.3164
# Current learning rate: 0.0002
# Epoch: 254	Duration: 84.76s	Train loss: 0.4046	Val loss: 0.4502	Val bias:-0.1195	Val Pearson correlation: 6.5125e-01	Val MeanMult: 3.3152
# Current learning rate: 0.0002
# Epoch: 255	Duration: 84.87s	Train loss: 0.4043	Val loss: 0.4495	Val bias:-0.1174	Val Pearson correlation: 6.5142e-01	Val MeanMult: 3.3124
# Current learning rate: 0.0002
# Epoch: 256	Duration: 91.57s	Train loss: 0.4041	Val loss: 0.4499	Val bias:-0.1198	Val Pearson correlation: 6.5159e-01	Val MeanMult: 3.3127
# Current learning rate: 0.0002
# Epoch: 257	Duration: 84.94s	Train loss: 0.4040	Val loss: 0.4471	Val bias:-0.1090	Val Pearson correlation: 6.5188e-01	Val MeanMult: 3.3042
# Current learning rate: 0.0002
# Epoch: 258	Duration: 84.84s	Train loss: 0.4035	Val loss: 0.4486	Val bias:-0.1157	Val Pearson correlation: 6.5202e-01	Val MeanMult: 3.3074
# Current learning rate: 0.0002
# Epoch: 259	Duration: 87.40s	Train loss: 0.4034	Val loss: 0.4475	Val bias:-0.1123	Val Pearson correlation: 6.5228e-01	Val MeanMult: 3.3041
# Current learning rate: 0.0002
# Checkpoint saved at epoch 260
# Epoch: 260	Duration: 84.58s	Train loss: 0.4032	Val loss: 0.4486	Val bias:-0.1174	Val Pearson correlation: 6.5241e-01	Val MeanMult: 3.3065
# Current learning rate: 0.0002
# Epoch: 261	Duration: 85.06s	Train loss: 0.4030	Val loss: 0.4475	Val bias:-0.1143	Val Pearson correlation: 6.5266e-01	Val MeanMult: 3.3026
# Current learning rate: 0.0002
# Epoch: 262	Duration: 97.34s	Train loss: 0.4024	Val loss: 0.4471	Val bias:-0.1127	Val Pearson correlation: 6.5283e-01	Val MeanMult: 3.3008
# Current learning rate: 0.0002
# Epoch: 263	Duration: 92.72s	Train loss: 0.4020	Val loss: 0.4465	Val bias:-0.1110	Val Pearson correlation: 6.5302e-01	Val MeanMult: 3.2983
# Current learning rate: 0.0002
# Epoch: 264	Duration: 99.15s	Train loss: 0.4018	Val loss: 0.4454	Val bias:-0.1064	Val Pearson correlation: 6.5331e-01	Val MeanMult: 3.2947
# Current learning rate: 0.0002
# Epoch: 265	Duration: 85.35s	Train loss: 0.4017	Val loss: 0.4453	Val bias:-0.1079	Val Pearson correlation: 6.5356e-01	Val MeanMult: 3.2944
# Current learning rate: 0.0002
# Epoch: 266	Duration: 85.14s	Train loss: 0.4016	Val loss: 0.4453	Val bias:-0.1081	Val Pearson correlation: 6.5368e-01	Val MeanMult: 3.2935
# Current learning rate: 0.0002
# Epoch: 267	Duration: 85.14s	Train loss: 0.4014	Val loss: 0.4450	Val bias:-0.1080	Val Pearson correlation: 6.5390e-01	Val MeanMult: 3.2923
# Current learning rate: 0.0002
# Epoch: 268	Duration: 86.20s	Train loss: 0.4009	Val loss: 0.4447	Val bias:-0.1071	Val Pearson correlation: 6.5411e-01	Val MeanMult: 3.2904
# Current learning rate: 0.0002
# Epoch: 269	Duration: 86.17s	Train loss: 0.4009	Val loss: 0.4451	Val bias:-0.1097	Val Pearson correlation: 6.5425e-01	Val MeanMult: 3.2914
# Current learning rate: 0.0002
# Epoch: 270	Duration: 86.34s	Train loss: 0.4006	Val loss: 0.4444	Val bias:-0.1079	Val Pearson correlation: 6.5447e-01	Val MeanMult: 3.2887
# Current learning rate: 0.0002
# Epoch: 271	Duration: 86.16s	Train loss: 0.4000	Val loss: 0.4434	Val bias:-0.1019	Val Pearson correlation: 6.5447e-01	Val MeanMult: 3.2845
# Current learning rate: 0.0002
# Epoch: 272	Duration: 85.05s	Train loss: 0.4001	Val loss: 0.4428	Val bias:-0.1005	Val Pearson correlation: 6.5474e-01	Val MeanMult: 3.2826
# Current learning rate: 0.0002
# Epoch: 273	Duration: 117.55s	Train loss: 0.3996	Val loss: 0.4432	Val bias:-0.1025	Val Pearson correlation: 6.5489e-01	Val MeanMult: 3.2830
# Current learning rate: 0.0002
# Epoch: 274	Duration: 86.06s	Train loss: 0.3997	Val loss: 0.4430	Val bias:-0.1035	Val Pearson correlation: 6.5518e-01	Val MeanMult: 3.2820
# Current learning rate: 0.0002
# Epoch: 275	Duration: 84.96s	Train loss: 0.3989	Val loss: 0.4427	Val bias:-0.1027	Val Pearson correlation: 6.5541e-01	Val MeanMult: 3.2809
# Current learning rate: 0.0002
# Epoch: 276	Duration: 85.11s	Train loss: 0.3992	Val loss: 0.4429	Val bias:-0.1044	Val Pearson correlation: 6.5554e-01	Val MeanMult: 3.2804
# Current learning rate: 0.0002
# Epoch: 277	Duration: 94.45s	Train loss: 0.3987	Val loss: 0.4419	Val bias:-0.1003	Val Pearson correlation: 6.5567e-01	Val MeanMult: 3.2769
# Current learning rate: 0.0002
# Epoch: 278	Duration: 85.85s	Train loss: 0.3987	Val loss: 0.4424	Val bias:-0.1039	Val Pearson correlation: 6.5592e-01	Val MeanMult: 3.2782
# Current learning rate: 0.0002
# Epoch: 279	Duration: 86.09s	Train loss: 0.3984	Val loss: 0.4408	Val bias:-0.0964	Val Pearson correlation: 6.5613e-01	Val MeanMult: 3.2735
# Current learning rate: 0.0002
# Checkpoint saved at epoch 280
# Epoch: 280	Duration: 86.72s	Train loss: 0.3982	Val loss: 0.4406	Val bias:-0.0963	Val Pearson correlation: 6.5630e-01	Val MeanMult: 3.2721
# Current learning rate: 0.0002
# Epoch: 281	Duration: 85.03s	Train loss: 0.3980	Val loss: 0.4406	Val bias:-0.0967	Val Pearson correlation: 6.5638e-01	Val MeanMult: 3.2709
# Current learning rate: 0.0002
# Epoch: 282	Duration: 85.70s	Train loss: 0.3974	Val loss: 0.4404	Val bias:-0.0978	Val Pearson correlation: 6.5664e-01	Val MeanMult: 3.2697
# Current learning rate: 0.0002
# ...
# Current learning rate: 0.0002
# Epoch: 664	Duration: 86.06s	Train loss: 0.3488	Val loss: 0.3965	Val bias:-0.0361	Val Pearson correlation: 6.9298e-01	Val MeanMult: 3.0686
# Current learning rate: 0.0002
# Epoch: 665	Duration: 84.64s	Train loss: 0.3487	Val loss: 0.3970	Val bias:-0.0419	Val Pearson correlation: 6.9298e-01	Val MeanMult: 3.0696
# Current learning rate: 0.0002
# Epoch: 666	Duration: 91.26s	Train loss: 0.3487	Val loss: 0.3966	Val bias:-0.0422	Val Pearson correlation: 6.9307e-01	Val MeanMult: 3.0682
# Current learning rate: 0.0002
# Epoch: 667	Duration: 95.16s	Train loss: 0.3483	Val loss: 0.3965	Val bias:-0.0401	Val Pearson correlation: 6.9317e-01	Val MeanMult: 3.0683
# Current learning rate: 0.0002
# Epoch: 668	Duration: 86.06s	Train loss: 0.3484	Val loss: 0.3969	Val bias:-0.0428	Val Pearson correlation: 6.9297e-01	Val MeanMult: 3.0683
# Current learning rate: 0.0002
# Epoch: 669	Duration: 84.99s	Train loss: 0.3486	Val loss: 0.3964	Val bias:-0.0389	Val Pearson correlation: 6.9311e-01	Val MeanMult: 3.0674
# Current learning rate: 0.0002
# Epoch: 670	Duration: 85.91s	Train loss: 0.3485	Val loss: 0.3964	Val bias:-0.0427	Val Pearson correlation: 6.9326e-01	Val MeanMult: 3.0673
# Current learning rate: 0.0002
# Epoch: 671	Duration: 84.91s	Train loss: 0.3482	Val loss: 0.3964	Val bias:-0.0387	Val Pearson correlation: 6.9325e-01	Val MeanMult: 3.0675
# Current learning rate: 0.0002
# Epoch: 672	Duration: 86.11s	Train loss: 0.3480	Val loss: 0.3965	Val bias:-0.0399	Val Pearson correlation: 6.9325e-01	Val MeanMult: 3.0674
# Current learning rate: 0.0002
# Epoch: 673	Duration: 84.60s	Train loss: 0.3482	Val loss: 0.3966	Val bias:-0.0424	Val Pearson correlation: 6.9323e-01	Val MeanMult: 3.0673
# Current learning rate: 0.0002
# Epoch: 674	Duration: 84.76s	Train loss: 0.3480	Val loss: 0.3964	Val bias:-0.0435	Val Pearson correlation: 6.9343e-01	Val MeanMult: 3.0669
# Current learning rate: 0.0002
# Epoch: 675	Duration: 85.74s	Train loss: 0.3479	Val loss: 0.3959	Val bias:-0.0371	Val Pearson correlation: 6.9347e-01	Val MeanMult: 3.0657
# Current learning rate: 0.0002
# Epoch: 676	Duration: 85.15s	Train loss: 0.3477	Val loss: 0.3962	Val bias:-0.0436	Val Pearson correlation: 6.9364e-01	Val MeanMult: 3.0658
# Current learning rate: 0.0002
# Epoch: 677	Duration: 84.54s	Train loss: 0.3475	Val loss: 0.3962	Val bias:-0.0392	Val Pearson correlation: 6.9339e-01	Val MeanMult: 3.0660
# Current learning rate: 0.0002
# Epoch: 678	Duration: 85.78s	Train loss: 0.3479	Val loss: 0.3960	Val bias:-0.0385	Val Pearson correlation: 6.9364e-01	Val MeanMult: 3.0663
# Current learning rate: 0.0002
# Epoch: 679	Duration: 84.55s	Train loss: 0.3477	Val loss: 0.3958	Val bias:-0.0352	Val Pearson correlation: 6.9373e-01	Val MeanMult: 3.0658
# Current learning rate: 0.0002
# Checkpoint saved at epoch 680
# Epoch: 680	Duration: 100.31s	Train loss: 0.3476	Val loss: 0.3958	Val bias:-0.0377	Val Pearson correlation: 6.9370e-01	Val MeanMult: 3.0654
# Current learning rate: 0.0002
# Epoch: 681	Duration: 84.67s	Train loss: 0.3475	Val loss: 0.3956	Val bias:-0.0389	Val Pearson correlation: 6.9372e-01	Val MeanMult: 3.0645
# Current learning rate: 0.0002
# Epoch: 682	Duration: 84.65s	Train loss: 0.3474	Val loss: 0.3959	Val bias:-0.0384	Val Pearson correlation: 6.9369e-01	Val MeanMult: 3.0652
# Current learning rate: 0.0002
# Epoch: 683	Duration: 85.67s	Train loss: 0.3468	Val loss: 0.3956	Val bias:-0.0383	Val Pearson correlation: 6.9403e-01	Val MeanMult: 3.0646
# Current learning rate: 0.0002
# Epoch: 684	Duration: 86.45s	Train loss: 0.3471	Val loss: 0.3958	Val bias:-0.0412	Val Pearson correlation: 6.9394e-01	Val MeanMult: 3.0650
# Current learning rate: 0.0002
# Epoch: 685	Duration: 92.46s	Train loss: 0.3470	Val loss: 0.3956	Val bias:-0.0385	Val Pearson correlation: 6.9392e-01	Val MeanMult: 3.0642
# Current learning rate: 0.0002
# Epoch: 686	Duration: 84.69s	Train loss: 0.3468	Val loss: 0.3958	Val bias:-0.0460	Val Pearson correlation: 6.9410e-01	Val MeanMult: 3.0641
# Current learning rate: 0.0002
# Epoch: 687	Duration: 84.65s	Train loss: 0.3466	Val loss: 0.3956	Val bias:-0.0366	Val Pearson correlation: 6.9399e-01	Val MeanMult: 3.0645
# Current learning rate: 0.0002
# Epoch: 688	Duration: 84.68s	Train loss: 0.3470	Val loss: 0.3957	Val bias:-0.0428	Val Pearson correlation: 6.9411e-01	Val MeanMult: 3.0637
# Current learning rate: 0.0002
# Epoch: 689	Duration: 88.87s	Train loss: 0.3466	Val loss: 0.3956	Val bias:-0.0394	Val Pearson correlation: 6.9404e-01	Val MeanMult: 3.0637
# Current learning rate: 0.0002
# Epoch: 690	Duration: 85.98s	Train loss: 0.3462	Val loss: 0.3952	Val bias:-0.0377	Val Pearson correlation: 6.9423e-01	Val MeanMult: 3.0628
# Current learning rate: 0.0002
# Epoch: 691	Duration: 85.39s	Train loss: 0.3466	Val loss: 0.3953	Val bias:-0.0371	Val Pearson correlation: 6.9434e-01	Val MeanMult: 3.0636
# Current learning rate: 0.0002
# Epoch: 692	Duration: 84.97s	Train loss: 0.3461	Val loss: 0.3957	Val bias:-0.0437	Val Pearson correlation: 6.9434e-01	Val MeanMult: 3.0639
# Current learning rate: 0.0002
# Epoch: 693	Duration: 85.91s	Train loss: 0.3462	Val loss: 0.3952	Val bias:-0.0396	Val Pearson correlation: 6.9435e-01	Val MeanMult: 3.0623
# Current learning rate: 0.0002
# Epoch: 694	Duration: 86.01s	Train loss: 0.3465	Val loss: 0.3952	Val bias:-0.0411	Val Pearson correlation: 6.9435e-01	Val MeanMult: 3.0622
# Current learning rate: 0.0002
# Epoch: 695	Duration: 84.87s	Train loss: 0.3461	Val loss: 0.3950	Val bias:-0.0407	Val Pearson correlation: 6.9450e-01	Val MeanMult: 3.0620
# Current learning rate: 0.0002
# Epoch: 696	Duration: 84.88s	Train loss: 0.3461	Val loss: 0.3954	Val bias:-0.0468	Val Pearson correlation: 6.9466e-01	Val MeanMult: 3.0623
# Current learning rate: 0.0002
# Epoch: 697	Duration: 84.83s	Train loss: 0.3458	Val loss: 0.3953	Val bias:-0.0414	Val Pearson correlation: 6.9456e-01	Val MeanMult: 3.0626
# Current learning rate: 0.0002
# Epoch: 698	Duration: 84.74s	Train loss: 0.3458	Val loss: 0.3952	Val bias:-0.0438	Val Pearson correlation: 6.9464e-01	Val MeanMult: 3.0615
# Current learning rate: 0.0002
# Epoch: 699	Duration: 84.74s	Train loss: 0.3454	Val loss: 0.3954	Val bias:-0.0409	Val Pearson correlation: 6.9450e-01	Val MeanMult: 3.0624
# Current learning rate: 0.0002
# Checkpoint saved at epoch 700
# Epoch: 700	Duration: 84.85s	Train loss: 0.3455	Val loss: 0.3945	Val bias:-0.0330	Val Pearson correlation: 6.9479e-01	Val MeanMult: 3.0610
# Current learning rate: 0.0002
# Epoch: 701	Duration: 84.75s	Train loss: 0.3457	Val loss: 0.3946	Val bias:-0.0390	Val Pearson correlation: 6.9484e-01	Val MeanMult: 3.0599
# Current learning rate: 0.0002
# Epoch: 702	Duration: 105.73s	Train loss: 0.3454	Val loss: 0.3952	Val bias:-0.0429	Val Pearson correlation: 6.9471e-01	Val MeanMult: 3.0610
# Current learning rate: 0.0002
# Epoch: 703	Duration: 85.63s	Train loss: 0.3450	Val loss: 0.3953	Val bias:-0.0433	Val Pearson correlation: 6.9482e-01	Val MeanMult: 3.0619
# Current learning rate: 0.0002
# Epoch: 704	Duration: 84.87s	Train loss: 0.3453	Val loss: 0.3950	Val bias:-0.0434	Val Pearson correlation: 6.9492e-01	Val MeanMult: 3.0607
# Current learning rate: 0.0002
# Epoch: 705	Duration: 94.20s	Train loss: 0.3451	Val loss: 0.3949	Val bias:-0.0437	Val Pearson correlation: 6.9501e-01	Val MeanMult: 3.0604
# Current learning rate: 0.0002
# Epoch: 706	Duration: 86.00s	Train loss: 0.3452	Val loss: 0.3947	Val bias:-0.0430	Val Pearson correlation: 6.9499e-01	Val MeanMult: 3.0598
# Current learning rate: 0.0002
# Epoch: 707	Duration: 84.65s	Train loss: 0.3449	Val loss: 0.3950	Val bias:-0.0441	Val Pearson correlation: 6.9504e-01	Val MeanMult: 3.0606
# Current learning rate: 0.0002
# Epoch: 708	Duration: 84.91s	Train loss: 0.3451	Val loss: 0.3951	Val bias:-0.0468	Val Pearson correlation: 6.9513e-01	Val MeanMult: 3.0608
# Current learning rate: 0.0002
# Epoch: 709	Duration: 85.89s	Train loss: 0.3450	Val loss: 0.3946	Val bias:-0.0435	Val Pearson correlation: 6.9516e-01	Val MeanMult: 3.0591
# Current learning rate: 0.0002
# Epoch: 710	Duration: 86.54s	Train loss: 0.3444	Val loss: 0.3944	Val bias:-0.0385	Val Pearson correlation: 6.9521e-01	Val MeanMult: 3.0596
# Current learning rate: 0.0002
# Epoch: 711	Duration: 85.72s	Train loss: 0.3443	Val loss: 0.3948	Val bias:-0.0439	Val Pearson correlation: 6.9529e-01	Val MeanMult: 3.0601
# Current learning rate: 0.0002
# Epoch: 712	Duration: 84.76s	Train loss: 0.3442	Val loss: 0.3944	Val bias:-0.0391	Val Pearson correlation: 6.9534e-01	Val MeanMult: 3.0597
# Current learning rate: 0.0002
# Epoch: 713	Duration: 84.84s	Train loss: 0.3442	Val loss: 0.3940	Val bias:-0.0384	Val Pearson correlation: 6.9548e-01	Val MeanMult: 3.0585
# Current learning rate: 0.0002
# Epoch: 714	Duration: 84.76s	Train loss: 0.3443	Val loss: 0.3941	Val bias:-0.0389	Val Pearson correlation: 6.9548e-01	Val MeanMult: 3.0586
# Current learning rate: 0.0002
# Epoch: 715	Duration: 86.83s	Train loss: 0.3443	Val loss: 0.3943	Val bias:-0.0440	Val Pearson correlation: 6.9565e-01	Val MeanMult: 3.0586
# Current learning rate: 0.0002
# Epoch: 716	Duration: 84.71s	Train loss: 0.3439	Val loss: 0.3942	Val bias:-0.0424	Val Pearson correlation: 6.9563e-01	Val MeanMult: 3.0578
# Current learning rate: 0.0002
# Epoch: 717	Duration: 117.02s	Train loss: 0.3435	Val loss: 0.3945	Val bias:-0.0432	Val Pearson correlation: 6.9556e-01	Val MeanMult: 3.0590
# Current learning rate: 0.0002
# Epoch: 718	Duration: 87.77s	Train loss: 0.3439	Val loss: 0.3942	Val bias:-0.0427	Val Pearson correlation: 6.9565e-01	Val MeanMult: 3.0576
# Current learning rate: 0.0002
# Epoch: 719	Duration: 85.74s	Train loss: 0.3438	Val loss: 0.3941	Val bias:-0.0428	Val Pearson correlation: 6.9572e-01	Val MeanMult: 3.0575
# Current learning rate: 0.0002
# Checkpoint saved at epoch 720
# Epoch: 720	Duration: 92.68s	Train loss: 0.3435	Val loss: 0.3945	Val bias:-0.0468	Val Pearson correlation: 6.9569e-01	Val MeanMult: 3.0582
# Current learning rate: 0.0002
# Epoch: 721	Duration: 84.96s	Train loss: 0.3435	Val loss: 0.3930	Val bias:-0.0312	Val Pearson correlation: 6.9602e-01	Val MeanMult: 3.0559
# Current learning rate: 0.0002
# Epoch: 722	Duration: 86.07s	Train loss: 0.3431	Val loss: 0.3934	Val bias:-0.0380	Val Pearson correlation: 6.9598e-01	Val MeanMult: 3.0558
# Current learning rate: 0.0002
# Epoch: 723	Duration: 84.88s	Train loss: 0.3430	Val loss: 0.3937	Val bias:-0.0385	Val Pearson correlation: 6.9599e-01	Val MeanMult: 3.0567
# Current learning rate: 0.0002
# Epoch: 724	Duration: 84.88s	Train loss: 0.3438	Val loss: 0.3941	Val bias:-0.0463	Val Pearson correlation: 6.9591e-01	Val MeanMult: 3.0565
# Current learning rate: 0.0002
# Epoch: 725	Duration: 106.50s	Train loss: 0.3431	Val loss: 0.3938	Val bias:-0.0438	Val Pearson correlation: 6.9617e-01	Val MeanMult: 3.0564
# Current learning rate: 0.0002
# Epoch: 726	Duration: 85.89s	Train loss: 0.3429	Val loss: 0.3939	Val bias:-0.0418	Val Pearson correlation: 6.9612e-01	Val MeanMult: 3.0567
# Current learning rate: 0.0002
# Epoch: 727	Duration: 88.40s	Train loss: 0.3430	Val loss: 0.3932	Val bias:-0.0396	Val Pearson correlation: 6.9633e-01	Val MeanMult: 3.0547
# Current learning rate: 0.0002
# Epoch: 728	Duration: 84.73s	Train loss: 0.3429	Val loss: 0.3934	Val bias:-0.0405	Val Pearson correlation: 6.9629e-01	Val MeanMult: 3.0552
# Current learning rate: 0.0002
# Epoch: 729	Duration: 88.34s	Train loss: 0.3425	Val loss: 0.3936	Val bias:-0.0404	Val Pearson correlation: 6.9621e-01	Val MeanMult: 3.0559
# Current learning rate: 0.0002
# Epoch: 730	Duration: 84.61s	Train loss: 0.3431	Val loss: 0.3931	Val bias:-0.0378	Val Pearson correlation: 6.9638e-01	Val MeanMult: 3.0543
# Current learning rate: 0.0002
# Epoch: 731	Duration: 84.80s	Train loss: 0.3421	Val loss: 0.3936	Val bias:-0.0471	Val Pearson correlation: 6.9637e-01	Val MeanMult: 3.0546
# Current learning rate: 0.0002
# Epoch: 732	Duration: 84.79s	Train loss: 0.3422	Val loss: 0.3933	Val bias:-0.0408	Val Pearson correlation: 6.9653e-01	Val MeanMult: 3.0547
# Current learning rate: 0.0002
# Epoch: 733	Duration: 85.80s	Train loss: 0.3422	Val loss: 0.3940	Val bias:-0.0487	Val Pearson correlation: 6.9643e-01	Val MeanMult: 3.0555
# Current learning rate: 0.0002
# Epoch: 734	Duration: 84.75s	Train loss: 0.3417	Val loss: 0.3936	Val bias:-0.0480	Val Pearson correlation: 6.9664e-01	Val MeanMult: 3.0547
# Current learning rate: 0.0002
# Epoch: 735	Duration: 85.96s	Train loss: 0.3419	Val loss: 0.3933	Val bias:-0.0470	Val Pearson correlation: 6.9666e-01	Val MeanMult: 3.0535
# Current learning rate: 0.0002
# Epoch: 736	Duration: 85.75s	Train loss: 0.3416	Val loss: 0.3928	Val bias:-0.0407	Val Pearson correlation: 6.9677e-01	Val MeanMult: 3.0530
# Current learning rate: 0.0002
# Epoch: 737	Duration: 84.96s	Train loss: 0.3417	Val loss: 0.3935	Val bias:-0.0472	Val Pearson correlation: 6.9668e-01	Val MeanMult: 3.0536
# Current learning rate: 0.0002
# Epoch: 738	Duration: 84.67s	Train loss: 0.3418	Val loss: 0.3930	Val bias:-0.0432	Val Pearson correlation: 6.9695e-01	Val MeanMult: 3.0533
# Current learning rate: 0.0002
# Epoch: 739	Duration: 89.40s	Train loss: 0.3416	Val loss: 0.3931	Val bias:-0.0474	Val Pearson correlation: 6.9692e-01	Val MeanMult: 3.0528
# Current learning rate: 0.0002
# Checkpoint saved at epoch 740
# Epoch: 740	Duration: 85.82s	Train loss: 0.3414	Val loss: 0.3935	Val bias:-0.0502	Val Pearson correlation: 6.9689e-01	Val MeanMult: 3.0539
# Current learning rate: 0.0002
# Epoch: 741	Duration: 84.82s	Train loss: 0.3409	Val loss: 0.3936	Val bias:-0.0468	Val Pearson correlation: 6.9685e-01	Val MeanMult: 3.0546
# Current learning rate: 0.0002
# Epoch: 742	Duration: 93.88s	Train loss: 0.3412	Val loss: 0.3938	Val bias:-0.0510	Val Pearson correlation: 6.9691e-01	Val MeanMult: 3.0546
# Current learning rate: 0.0002
# Epoch: 743	Duration: 87.71s	Train loss: 0.3410	Val loss: 0.3932	Val bias:-0.0473	Val Pearson correlation: 6.9701e-01	Val MeanMult: 3.0529
# Current learning rate: 0.0002
# Epoch: 744	Duration: 91.06s	Train loss: 0.3409	Val loss: 0.3932	Val bias:-0.0460	Val Pearson correlation: 6.9714e-01	Val MeanMult: 3.0530
# Current learning rate: 0.0002
# Epoch: 745	Duration: 84.64s	Train loss: 0.3411	Val loss: 0.3924	Val bias:-0.0366	Val Pearson correlation: 6.9713e-01	Val MeanMult: 3.0517
# Current learning rate: 0.0002
# Epoch: 746	Duration: 87.50s	Train loss: 0.3405	Val loss: 0.3925	Val bias:-0.0416	Val Pearson correlation: 6.9719e-01	Val MeanMult: 3.0513
# Current learning rate: 0.0002
# Epoch: 747	Duration: 110.66s	Train loss: 0.3405	Val loss: 0.3918	Val bias:-0.0336	Val Pearson correlation: 6.9730e-01	Val MeanMult: 3.0503
# Current learning rate: 0.0002
# Epoch: 748	Duration: 84.67s	Train loss: 0.3404	Val loss: 0.3928	Val bias:-0.0429	Val Pearson correlation: 6.9719e-01	Val MeanMult: 3.0522
# Current learning rate: 0.0002
# Epoch: 749	Duration: 85.91s	Train loss: 0.3407	Val loss: 0.3923	Val bias:-0.0399	Val Pearson correlation: 6.9743e-01	Val MeanMult: 3.0509
# Current learning rate: 0.0002
# Epoch: 750	Duration: 84.74s	Train loss: 0.3405	Val loss: 0.3928	Val bias:-0.0470	Val Pearson correlation: 6.9729e-01	Val MeanMult: 3.0510
# Current learning rate: 0.0002
# Epoch: 751	Duration: 85.92s	Train loss: 0.3401	Val loss: 0.3928	Val bias:-0.0450	Val Pearson correlation: 6.9746e-01	Val MeanMult: 3.0519
# Current learning rate: 0.0002
# Epoch: 752	Duration: 84.44s	Train loss: 0.3402	Val loss: 0.3920	Val bias:-0.0433	Val Pearson correlation: 6.9753e-01	Val MeanMult: 3.0492
# Current learning rate: 0.0002
# Epoch: 753	Duration: 90.89s	Train loss: 0.3402	Val loss: 0.3923	Val bias:-0.0461	Val Pearson correlation: 6.9767e-01	Val MeanMult: 3.0500
# Current learning rate: 0.0002
# Epoch: 754	Duration: 85.62s	Train loss: 0.3399	Val loss: 0.3929	Val bias:-0.0511	Val Pearson correlation: 6.9770e-01	Val MeanMult: 3.0511
# Current learning rate: 0.0002
# Epoch: 755	Duration: 85.41s	Train loss: 0.3396	Val loss: 0.3923	Val bias:-0.0453	Val Pearson correlation: 6.9769e-01	Val MeanMult: 3.0494
# Current learning rate: 0.0002
# Epoch: 756	Duration: 84.63s	Train loss: 0.3392	Val loss: 0.3917	Val bias:-0.0372	Val Pearson correlation: 6.9773e-01	Val MeanMult: 3.0489
# Current learning rate: 0.0002
# Epoch: 757	Duration: 94.41s	Train loss: 0.3391	Val loss: 0.3924	Val bias:-0.0461	Val Pearson correlation: 6.9780e-01	Val MeanMult: 3.0493
# Current learning rate: 0.0002

# %%
with torch.no_grad():
    eval_test = compute_eval_metrics(test_dataloader, model)
    print(eval_test)

# %%
torch.cuda.empty_cache()

# %%
hist.keys()
np.std(hist['val_loss'][15:])
np.arange(100)[-10:]

# %%
random_df = feat_df.sample(20)

random_dataloader = create_dataloader(random_df)
eval_random = compute_eval_metrics(random_dataloader, model)
print(eval_random)

for (x, y) in random_dataloader:
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        print(pred.item())

# %%
class print_Model(Module):
    def __init__(self, seq):
        super(print_Model, self).__init__()
        self.net = seq

    def forward(self, x):
        print("Start\n{}".format(x.size()))
        for layer in self.net:
            x = layer(x)
            print(layer)
            print(x.size())
        return x

# %%
# %load_ext autoreload

# %%
random_df = feat_df.sample(20)

random_dataloader = create_dataloader(random_df, log=False)


load_model = Baseline_Model((input_height, input_width)).to(device)
model_name = 'testrun2_regularization'
load_model.load_state_dict(torch.load(os.path.join(MODELS_DIR,model_name,'model_state.pt'), map_location=torch.device('cpu')))

load_metrics = compute_eval_metrics(test_dataloader, load_model, log=False)
for key in load_metrics.keys():
    print(key, load_metrics[key])

for (x, y) in random_dataloader:
    (x, y) = (x.to(device), y.to(device))
    pred = load_model(x)
    print(pred.item())

# %%
feat_df['vol'].hist()
