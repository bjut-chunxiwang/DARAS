# %% [markdown]
# # Model Prototyping
#
# Building the basis for our model experimentation

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import numpy as np
import pandas as pd
import torch
import os
import json

from torch.utils import data
from torch.nn import Conv2d, AvgPool2d, ReLU, Dropout, Flatten, Linear, Sequential, Module
from torch.optim import Adam
from time import time

from tqdm import tqdm

device = torch.device("cuda:0")
torch.set_default_dtype(torch.float64)

MODELS_DIR  = '/home/cxw/sonos_rirs/models/'

# %%
model_dict = {}
model_dict['name'] = "testrun2_regularization"
model_dict['notes'] = "same as test run but with regularization"
model_dict['data_path'] = '/home/cxw/sonos_rirs/features/080122_5k_phase/feature_df_bp.csv'
model_dict['model_path'] = os.path.join(MODELS_DIR, model_dict['name'])

# %%
try:
    # 尝试导入IPython
    from IPython import get_ipython
    # 检查是否在IPython环境下
    if get_ipython() is not None:
        # 加载autoreload扩展
        # %load_ext autoreload
        # 设置autoreload为2
        # %autoreload 2
except ImportError:
    # 如果IPython没有被安装，则不作任何操作
    pass

# %%
# %autoreload 2
# import volume_estimation.modeling as model_funcs
# model_funcs.train_model(model_funcs.Baseline_Model, model_dict,\
#                         overwrite=True, epochs=1,log=False) #######################################################

# %%
feat_df = pd.read_csv(model_dict['data_path'])
model_path = os.path.join(MODELS_DIR, model_dict['name'])

dataset = []

import pandas as pd
import numpy as np
import torch
from tqdm import tqdm
import os

# 假设 csv_file_path 是你的 .csv 文件路径
csv_file_path = '/home/cxw/sonos_rirs/features/080122_5k_phase/feature_df_bp.csv'

# 读取 .csv 文件
csv_df = pd.read_csv(csv_file_path)

def create_dataloader(feature_df, batch_size=1, log=False):
    dataset = []
    for row in tqdm(feature_df.iterrows()):
        feat_file = row[1]['file_feature']
        loaded = np.load(feat_file)
        
        # 获取 log_rt60
        vol = loaded['log_rt60']
        
        # 在 csv_df 中查找对应的 log_bp 值
        csv_row = csv_df[csv_df['file_feature'] == feat_file]
        if not csv_row.empty:
            log_bp_value = csv_row['log_bp'].values[0]
            vol = log_bp_value  # 用 log_bp 替换 log_rt60
        
        feature = loaded['feat']
        feature = feature.reshape((feature.shape[0], feature.shape[1]))
        feature = np.real(feature)
        
        if log:
            vol = np.log10(vol)
        
        dataset.append((feature, vol))
    
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
    return dataloader

# 假设 feat_df 是你的特征数据框
dataloader = create_dataloader(feat_df, log=False)
# Out:
# 32000it [00:39, 816.70it/s]

# %%
savename = './testmodeldict.json'
with open(savename, 'w') as f:
    json.dump(model_dict, f)
    
with open(savename) as f:
    load_dict = json.load(f)
    
for key in load_dict.keys():
    print(key, load_dict[key])
# Out:
# name testrun2_regularization
# notes same as test run but with regularization
# data_path /home/cxw/sonos_rirs/features/080122_5k_phase/feature_df_bp.csv
# model_path /home/cxw/sonos_rirs/models/testrun2_regularization

# %%
train_df = feat_df[feat_df['split'].isin(['train','test'])]
val_df = feat_df[feat_df['split']=='test']
test_df = feat_df[feat_df['split']=='test']

print("Creating training dataloader")
train_dataloader = create_dataloader(train_df, batch_size=128)        ##################################batch_size

print("Creating validation dataloader")
val_dataloader = create_dataloader(val_df)

print("Creating test dataloader")
test_dataloader = create_dataloader(test_df)
# Out:
# Creating training dataloader
# 25580it [00:31, 805.49it/s]
# Creating validation dataloader
# 6380it [00:07, 803.98it/s]
# Creating test dataloader
# 6380it [00:08, 785.74it/s]

# %%
features, labels = next(iter(train_dataloader))
# features = features.squeeze(1)
# features = features.transpose(1,2)
print(f"Feature batch shape: {features.size()}")
print(f"Labels batch shape: {labels.size()}")
# Out:
# Feature batch shape: torch.Size([128, 30, 1997])
# Labels batch shape: torch.Size([128])

# %%
# class Baseline_Model(Module):
#     def __init__(self, input_shape):
#         #accepts a tuple with the height/width of the feature
#         #matrix to set the FC layer dimensions
#         super(Baseline_Model, self).__init__()
        
#         #block1
#         Conv1 = Conv2d(1, 30, kernel_size=(1,10), stride=(1,1))
#         Avgpool1 = AvgPool2d((1,2), stride=(1,2))

#         #block2
#         Conv2 = Conv2d(30, 20, kernel_size=(1,10), stride=(1,1))
#         Avgpool2 = AvgPool2d((1,2), stride=(1,2))

#         #block3
#         Conv3 = Conv2d(20, 10, kernel_size=(1,10), stride=(1,1))
#         Avgpool3 = AvgPool2d((1,2), stride=(1,2))

#         #block4
#         Conv4 = Conv2d(10, 10, kernel_size=(1,10), stride=(1,1))
#         Avgpool4 = AvgPool2d((1,2), stride=(1,2))

#         #block5
#         Conv5 = Conv2d(10, 5, kernel_size=(3,9), stride=(1,1))
#         Avgpool5 = AvgPool2d((1,2), stride=(1,2))

#         #block6
#         Conv6 = Conv2d(5, 5, kernel_size=(3,9), stride=(1,1))
#         Avgpool6 = AvgPool2d((2,2), stride=(2,2))

#         #dropout
#         dropout_layer = Dropout(p=0.5)
#         height5 = input_shape[0] - 2
#         height6 = (height5 - 2) // 2

#         time1 = (input_shape[1] - 9) // 2
#         time2 = (time1 - 9) // 2
#         time3 = (time2 - 9) // 2
#         time4 = (time3 - 9) // 2
#         time5 = (time4 - 7) // 2
#         time6 = (time5 - 7) // 2

#         flat_dims = 5 * height6 * time6
#         fc_layer = Linear(flat_dims, 1)
        
#         self.net = Sequential(
#                     Conv1, ReLU(), Avgpool1,
#                     Conv2, ReLU(), Avgpool2,
#                     Conv3, ReLU(), Avgpool3,
#                     Conv4, ReLU(), Avgpool4,
#                     Conv5, ReLU(), Avgpool5,
#                     Conv6, ReLU(), Avgpool6,
#                     dropout_layer, Flatten(),
#                     fc_layer, Flatten()
#                 )
#     def forward(self, x):
#         for layer in self.net:
#             x = layer(x)
#         return x

# %%
"""
Author: Siavash Shams
Date: 4/10/2024

This script contains the implementation of the AMBAModel and ASTModel for audio processing tasks.
The ASTModel is adapted from Yuan Gong's code.

"""
import os
os.environ["HF_ENDPOINT"]='https://hf-mirror.com'
import torch.nn as nn
import torch
import sys

from timm.models.layers import trunc_normal_
import timm
import numpy as np
from timm.models.layers import to_2tuple
from random import randrange
from matplotlib import pyplot as plt
import random

# from src.models.mamba.benchmarks.benchmark_generation_mamba_simple import device
device = "cuda"
sys.path.append('/home/cxw/Vim')
sys.path.append('/home/cxw/Vim/vim')
sys.path.append('/home/cxw/Vim/vim/mamba-1p1p1')



from models_mamba import VisionMamba
from mamba_ssm.ops.triton.layernorm import RMSNorm, layer_norm_fn, rms_norm_fn
    

    
    
class PatchEmbed(nn.Module):
    """ Image to Patch Embedding
    """
    def __init__(self, img_size=224, patch_size=16, in_chans=3, embed_dim=768):
        super().__init__()
        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        num_patches = (img_size[1] // patch_size[1]) * (img_size[0] // patch_size[0])
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = num_patches

        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=patch_size, stride=patch_size)

    def forward(self, x):
        x = self.proj(x).flatten(2).transpose(1, 2)
        return x

def get_sinusoid_encoding(n_position, d_hid):
    ''' Sinusoid position encoding table '''

    def get_position_angle_vec(position):
        return [position / np.power(10000, 2 * (hid_j // 2) / d_hid) for hid_j in range(d_hid)]

    sinusoid_table = np.array([get_position_angle_vec(pos_i) for pos_i in range(n_position)])
    sinusoid_table[:, 0::2] = np.sin(sinusoid_table[:, 0::2])  # dim 2i
    sinusoid_table[:, 1::2] = np.cos(sinusoid_table[:, 1::2])  # dim 2i+1

    return torch.FloatTensor(sinusoid_table).unsqueeze(0)

class AMBAModel(nn.Module):
    def __init__(self, label_dim=527,
                 fshape=128, tshape=2, fstride=128, tstride=2,
                 input_fdim=128, input_tdim=1024, model_size='base',
                 pretrain_stage=True, load_pretrained_mdl_path=None, vision_mamba_config=None):
        
        print("Vision Mamba Config:", vision_mamba_config)
        super(AMBAModel, self).__init__()
        #assert timm.__version__ == '0.4.5', 'Please use timm == 0.4.5, the code might not be compatible with newer versions.'

        # override timm input shape restriction
        timm.models.vision_transformer.PatchEmbed = PatchEmbed

        # pretrain the AMBA models
        if pretrain_stage == True:
            if load_pretrained_mdl_path != None:
                raise ValueError('Setting load_pretrained_mdl_path at pretraining stage is useless, pretraining is always from scratch, please change it to None.')
            if fstride != fshape or tstride != tshape:
                raise ValueError('fstride != fshape or tstride != tshape, they must be same at the pretraining stage, patch split overlapping is not supported.')

            
            default_vision_mamba_config = {
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 24,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': True,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': False,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        }
            
            
            combined_vision_mamba_config = {**default_vision_mamba_config, **vision_mamba_config}
            # Replace self.v with MambaBlocksSequential
            print("combined_vision_mamba_config",combined_vision_mamba_config)
            self.v = VisionMamba(**combined_vision_mamba_config)

            self.cls_token_num = 1
            self.original_num_patches = self.v.patch_embed.num_patches
            self.oringal_hw = int(self.original_num_patches ** 0.5)
            self.original_embedding_dim = self.v.pos_embed.shape[2]

            # SSL Pretraining Code
            self.softmax = nn.Softmax(dim=-1)
            self.lsoftmax = nn.LogSoftmax(dim=-1)
            self.fshape, self.tshape = fshape, tshape
            self.fstride, self.tstride = fstride, tstride
            self.input_fdim, self.input_tdim = input_fdim, input_tdim
            # this is a trick to make state_dict to track pretraining input_fdim and input_tdim and save them by using torch.save
            self.p_input_fdim, self.p_input_tdim = nn.Parameter(torch.tensor(input_fdim), requires_grad=False), nn.Parameter(torch.tensor(input_tdim), requires_grad=False)

            self.cpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            # masked patch reconstruction (generative objective) layer
            self.gpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            self.unfold = torch.nn.Unfold(kernel_size=(fshape, tshape), stride=(fstride, tstride))

            # we use learnable mask embedding (follow the BEIT paper), but using a fixed mask embedding (e.g., 0) leads to same performance.
            self.mask_embed = nn.Parameter(torch.zeros([1, 1, self.original_embedding_dim]))
            self.mask_embed = torch.nn.init.xavier_normal_(self.mask_embed)

            # get the intermediate shape
            self.p_f_dim, self.p_t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            num_patches = self.p_f_dim * self.p_t_dim
            self.num_patches = num_patches
            self.v.patch_embed.num_patches = num_patches
            print('pretraining patch split stride: frequency={:d}, time={:d}'.format(fstride, tstride))
            print('pretraining patch shape: frequency={:d}, time={:d}'.format(fshape, tshape))
            print('pretraining patch array dimension: frequency={:d}, time={:d}'.format(self.p_f_dim, self.p_t_dim))
            print('pretraining number of patches={:d}'.format(num_patches))

            # the linear patch projection layer, use 1 channel for spectrogram rather than the original 3 channels for RGB images.
            new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
            self.v.patch_embed.proj = new_proj

            # use trainable positional embedding
            new_pos_embed = nn.Parameter(torch.zeros(1, self.v.patch_embed.num_patches + self.cls_token_num, self.original_embedding_dim))
            self.v.pos_embed = new_pos_embed
            trunc_normal_(self.v.pos_embed, std=.02)

        # use a pretrained models for finetuning
        elif pretrain_stage == False:
            device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
            if load_pretrained_mdl_path == None:
                raise ValueError('Please set load_pretrained_mdl_path to load a pretrained models.')
            sd = torch.load(load_pretrained_mdl_path, map_location=device)
            # get the fshape and tshape, input_fdim and input_tdim in the pretraining stage
            try:
                p_fshape, p_tshape = sd['module.v.patch_embed.proj.weight'].shape[2], sd['module.v.patch_embed.proj.weight'].shape[3]
                p_input_fdim, p_input_tdim = sd['module.p_input_fdim'].item(), sd['module.p_input_tdim'].item()
            except:
                raise  ValueError('The model loaded is not from a torch.nn.Dataparallel object. Wrap it with torch.nn.Dataparallel and try again.')

            print('now load a SSL pretrained models from ' + load_pretrained_mdl_path)
            # during pretraining, fstride=fshape and tstride=tshape because no patch overlapping is used
            # here, input_fdim and input_tdim should be that used in pretraining, not that in the fine-tuning.
            # we need to know input_fdim and input_tdim to do positional embedding cut/interpolation.
            # generally it should be better to use same input_fdim during pretraining and finetuning, but input_tdim can be safely different
            default_vision_mamba_config = {
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 24,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': True,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': False,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        }
            
            
            combined_vision_mamba_config = {**default_vision_mamba_config, **vision_mamba_config}
            # Replace self.v with MambaBlocksSequential
            print("combined_vision_mamba_config",combined_vision_mamba_config)

            audio_model = AMBAModel(fstride=p_fshape, tstride=p_tshape, fshape=p_fshape, tshape=p_tshape,
                                   input_fdim=p_input_fdim, input_tdim=p_input_tdim, pretrain_stage=True, model_size=model_size, vision_mamba_config=combined_vision_mamba_config)
            
            audio_model = torch.nn.DataParallel(audio_model)
            audio_model.load_state_dict(sd, strict=False)
            device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            self.v = audio_model.module.v
            self.original_embedding_dim = self.v.pos_embed.shape[2]
            self.cls_token_num = audio_model.module.cls_token_num

            # mlp head for fine-tuning
            self.mlp_head = nn.Sequential(nn.LayerNorm(self.original_embedding_dim),
                                          nn.Linear(self.original_embedding_dim, label_dim))

            f_dim, t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            # patch array dimension during pretraining
            p_f_dim, p_t_dim = audio_model.module.p_f_dim, audio_model.module.p_t_dim
            num_patches = f_dim * t_dim
            p_num_patches = p_f_dim * p_t_dim
            self.v.patch_embed.num_patches = num_patches
            print('fine-tuning patch split stride: frequncey={:d}, time={:d}'.format(fstride, tstride))
            print('fine-tuning number of patches={:d}'.format(num_patches))

            # patch shape should be same for pretraining and fine-tuning
            # if fshape != p_fshape or tshape != p_tshape:
            #     raise ValueError('The patch shape of pretraining and fine-tuning is not consistant, pretraining: f={:d}, t={:d}, finetuning: f={:d}, t={:d}'.format(p_fshape, p_tshape, fshape, tshape))

            # patch split stride generally should be different for pretraining and fine-tuning, as patch split overlapping is only used in finetuning
            # during pretraining, p_fshape = p_fstride and p_tshape = p_tstride
            if fstride != p_fshape or tstride != p_tshape:
                # initialize a new patch embedding layer with desired new stride.
                new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
                # but the weights of patch embedding layer is still got from the pretrained models
                new_proj.weight = torch.nn.Parameter(torch.sum(self.v.patch_embed.proj.weight, dim=1).unsqueeze(1))
                new_proj.bias = self.v.patch_embed.proj.bias
                self.v.patch_embed.proj = new_proj

            new_pos_embed = self.v.pos_embed[:, self.cls_token_num:, :].detach().reshape(1, p_num_patches, self.original_embedding_dim).transpose(1, 2).reshape(1, self.original_embedding_dim, p_f_dim, p_t_dim)
            # cut or interpolate the positional embedding
            if t_dim < p_t_dim:
                new_pos_embed = new_pos_embed[:, :, :, int(p_t_dim/2) - int(t_dim / 2): int(p_t_dim/2) - int(t_dim / 2) + t_dim]
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(8, t_dim), mode='bilinear')
            if f_dim < p_f_dim:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')

            new_pos_embed = new_pos_embed.reshape(1, self.original_embedding_dim, num_patches).transpose(1, 2)
            self.v.pos_embed = nn.Parameter(torch.cat([self.v.pos_embed[:, :self.cls_token_num, :].detach(), new_pos_embed], dim=1))

    # get the shape of intermediate representation.
    def get_shape(self, fstride, tstride, input_fdim, input_tdim, fshape, tshape):
        test_input = torch.randn(1, 1, input_fdim, input_tdim)
        test_proj = nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
        test_out = test_proj(test_input)
        f_dim = test_out.shape[2]
        t_dim = test_out.shape[3]
        return f_dim, t_dim

    # generate mask for 16*16 patch
    def gen_maskid_patch(self, sequence_len=512, mask_size=100, cluster=3):
        mask_id = []

        # randomize clutering factor in [3,6)
        cur_clus = randrange(cluster) + 3

        while len(list(set(mask_id))) <= mask_size:
            start_id = randrange(sequence_len)

            # this improves the efficiency, but might change the pretrained model
            # while start_id in mask_id:
            #     start_id = randrange(sequence_len)

            cur_mask = []
            for i in range(0, cur_clus):
                for j in range(0, cur_clus):
                    mask_cand = start_id + self.p_t_dim * i + j
                    if mask_cand > 0 and mask_cand < sequence_len:
                        cur_mask.append(mask_cand)
            mask_id = mask_id + cur_mask
        mask_id = list(set(mask_id))[:mask_size]
        return torch.tensor(mask_id)

    # using cluster for frame masking hurts the performance, so just use the naive random sampling
    def gen_maskid_frame(self, sequence_len=512, mask_size=100):
        mask_id = random.sample(range(0, sequence_len), mask_size)
        return torch.tensor(mask_id)
    
    def finetuningavgtok_1sec(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                hidden_states, residual = layer(hidden_states, residual)
        else:
            for i in range(len(self.v.layers) // 2):
                hidden_states_f, residual_f = self.v.layers[i * 2](hidden_states, residual)
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](hidden_states.flip([1]), None if residual is None else residual.flip([1]))
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        x = self.v.norm_f(hidden_states)

        # Average output of tokens within each 1-second segment
        tokens_per_second = x.shape[1] // 60  
        x_averaged = torch.stack([torch.mean(x[:, i * tokens_per_second:(i + 1) * tokens_per_second, :], dim=1) for i in range(60)], dim=1)
        x_averaged = self.mlp_head(x_averaged)
        return x_averaged

    def finetuningavgtok(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x
        x = self.v.pos_drop(x)
        
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        x = self.v.norm_f(hidden_states)

        # average output of all tokens except cls token(s)
        x = torch.mean(x[:, self.cls_token_num:, :], dim=1)
        x = self.mlp_head(x)
        return x

    def finetuningcls(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

       
        x = self.v.norm_f(hidden_states)


        # if models has two cls tokens (DEIT), average as the clip-level representation
        if self.cls_token_num == 2:
            x = (x[:, 0] + x[:, 1]) / 2
        else:
            x = x[:, 0]
        x = self.mlp_head(x)
        return x

    # masked patch pretraining with discriminative objective
    def mpc(self, x, mask_patch, cluster, show_mask=False):
        input = self.unfold(x).transpose(1, 2)
        B = x.shape[0]
        # x in shape (batch_size, sequence_len, embedding dim)
        x = self.v.patch_embed(x)

        # encode the patch
        # size 12(batch_size) * 100(#mask_patch) * 768(hidden_dim), prepare to save the true values of masked samples
        encode_samples = torch.empty((B, mask_patch, 256), device=x.device, requires_grad=False).float()
        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)

        # for each audio clip in the batch
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            # copy the masked embeddings, note gradients are stopped in this path
            encode_samples[i] = input[i, mask_index[i], :].clone().detach()
            # mask the encode samples with 0
            mask_dense[i, mask_index[i], :] = 0

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # mask the patch
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # pass through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        #dist_token = self.v.dist_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
    
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        # return only cls token if it exists
        
        x = self.v.norm_f(hidden_states)
        
        
   
        pred = torch.empty((B, mask_patch, 256), device='cpu').float()  # e.g. size 12*100*768
        for i in range(B):
            #  +2 for indexes because skipping the cls and dis token
            # we map the output of transformer (768-dim for base models) to 256-dim patch input space, and then dot product with flattened patch input (also 256-dim) to calculate loss.
            # alternatively, you can map the output of transformer to 768-dim patch embedding space, and dot product with patch embedding. Performance-wise they are similar, but map to 256 space is more efficient.
            pred[i] = self.cpredlayer(x[i, mask_index[i] + self.cls_token_num, :])

        # calculate the NCE loss
        nce = torch.tensor(0.0).to(x.device)
        correct = torch.tensor(0.0).to(x.device)
        for i in np.arange(0, B):
            # negative samples are from the same batch
            # 8/12/2022: has a difference with equation (1) in the ssast paper but (likely) performance-wise similar, see https://github.com/YuanGongND/ssast/issues/13
            total = torch.mm(encode_samples[i], torch.transpose(pred[i], 0, 1))  # e.g. size 100*100
            correct += torch.sum(torch.eq(torch.argmax(self.softmax(total), dim=0), torch.arange(0, mask_patch, device=x.device)))  # correct is a tensor
            nce += torch.sum(torch.diag(self.lsoftmax(total)))  # nce is a tensor
        acc = 1. * correct / (B * mask_patch)
        nce = nce / (-1. * B * mask_patch)

        # visualize the masked area, for probing test only, set show_mask = False for any training/inference.
        if show_mask == False:
            return acc, nce
        else:
            if B > 1:
                raise Exception('Currently only support single spectrogram probing test.')

            self.mask_correct = torch.nn.Parameter(torch.arange(0, mask_patch), requires_grad=False)

            pred = input.clone()  # [B, 512, 256]
            masked = input.clone()

            for i in range(B):
                result = [float(t) * 99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)]
                pred[i, mask_index[i], :] = torch.tensor(result).reshape(mask_patch, 1).expand(mask_patch, 256)
                masked[i, mask_index[i], :] = 99.0

            # print(total)
            # print(self.softmax(total))
            # print(torch.argmax(self.softmax(total), dim=0))
            # print(self.mask_correct)
            # print(torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct))
            # print([float(t)*99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)])

            fold = torch.nn.Fold(output_size=([self.input_fdim, self.input_tdim]), kernel_size=(self.fshape, self.tshape), stride=(self.fstride, self.tstride))
            pred = fold(pred.transpose(1, 2))
            masked = fold(masked.transpose(1, 2))

            return pred, masked

        
    # # masked patch pretraining with generative objective
    def mpg(self, input, mask_patch, cluster):
        
        B = input.shape[0]
        x = self.v.patch_embed(input)
        input = self.unfold(input).transpose(1, 2)

        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            mask_dense[i, mask_index[i], :] = 0

        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # go through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        #dist_token = self.v.dist_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        
        x = self.v.norm_f(hidden_states)
        
        pred = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float()  # e.g. size 12*100*256
        target = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float() # e.g. size 12*100*256

        for i in range(B):
            #  +2 for indexes because cls and dis token
            pred[i] = self.gpredlayer(x[i, mask_index[i] + self.cls_token_num, :])
            target[i] = input[i, mask_index[i], :]

        # calculate the MSE loss
        mse = torch.mean((pred - target) ** 2)

        return mse
        
     
    def forward(self, x, task, cluster=True, mask_patch=400):
        # expect input x = (batch_size, time_frame_num, frequency_bins), e.g., (12, 1024, 128)
        x = x.unsqueeze(1)
        x = x.transpose(2, 3)
        # finetuning (ft), use the mean of all token (patch) output as clip-level representation.
        # this is default for SSAMBA fine-tuning as during pretraining, supervision signal is given to each token, not the [cls] token
        if task == 'ft_avgtok':
            return self.finetuningavgtok(x)
        elif task == 'ft_avgtok_1sec':
            return self.finetuningavgtok_1sec(x)
        # alternatively, use the [cls] token output as clip-level representation.
        elif task == 'ft_cls':
            return self.finetuningcls(x)
        # pretraining, masked patch classification (discriminative objective)
        elif task == 'pretrain_mpc':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster)
        # pretraining, masked patch reconstruction (generative objective)
        elif task == 'pretrain_mpg':
            return self.mpg(x, mask_patch=mask_patch, cluster=cluster)
        elif task == 'visualize_mask':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster, show_mask=True)
        else:
            raise Exception('Task unrecognized.')

            
class ASTModel(nn.Module):
    def __init__(self, label_dim=527,
                 fshape=128, tshape=2, fstride=128, tstride=2,
                 input_fdim=128, input_tdim=1024, model_size='base_nokd',
                 pretrain_stage=True, load_pretrained_mdl_path=None):

        super(ASTModel, self).__init__()
        assert timm.__version__ == '0.4.5', 'Please use timm == 0.4.5, the code might not be compatible with newer versions.'

        # override timm input shape restriction
        timm.models.vision_transformer.PatchEmbed = PatchEmbed

        # pretrain the AST models
        if pretrain_stage == True:
            if load_pretrained_mdl_path != None:
                raise ValueError('Setting load_pretrained_mdl_path at pretraining stage is useless, pretraining is always from scratch, please change it to None.')
            if fstride != fshape or tstride != tshape:
                raise ValueError('fstride != fshape or tstride != tshape, they must be same at the pretraining stage, patch split overlapping is not supported.')

            # if AudioSet pretraining is not used (but ImageNet pretraining may still apply)
            if model_size == 'tiny':
                self.v = timm.create_model('vit_deit_tiny_distilled_patch16_224', pretrained=False)
                self.heads, self.depth = 3, 12
                self.cls_token_num = 2
            elif model_size == 'small':
                self.v = timm.create_model('vit_deit_small_distilled_patch16_224', pretrained=False)
                self.heads, self.depth = 6, 12
                self.cls_token_num = 2
            elif model_size == 'base':
                self.v = timm.create_model('vit_deit_base_distilled_patch16_384', pretrained=False)
                self.heads, self.depth = 12, 12
                self.cls_token_num = 2
            elif model_size == 'base_nokd':
                self.v = timm.create_model('vit_deit_base_patch16_384', pretrained=False)
                self.heads, self.depth = 12, 12
                self.cls_token_num = 1
            else:
                raise Exception('Model size must be one of tiny, small, base, base_nokd')

            self.original_num_patches = self.v.patch_embed.num_patches
            self.oringal_hw = int(self.original_num_patches ** 0.5)
            self.original_embedding_dim = self.v.pos_embed.shape[2]

            # SSL Pretraining Code
            self.softmax = nn.Softmax(dim=-1)
            self.lsoftmax = nn.LogSoftmax(dim=-1)
            self.fshape, self.tshape = fshape, tshape
            self.fstride, self.tstride = fstride, tstride
            self.input_fdim, self.input_tdim = input_fdim, input_tdim
            # this is a trick to make state_dict to track pretraining input_fdim and input_tdim and save them by using torch.save
            self.p_input_fdim, self.p_input_tdim = nn.Parameter(torch.tensor(input_fdim), requires_grad=False), nn.Parameter(torch.tensor(input_tdim), requires_grad=False)

            # masked patch classification (discriminative objective) layer
            # we use two layers for pretext task, but using a single layer has similar performance.
            # we map the output of transformer (768-dim for base models) to 256-dim patch input space, and then dot product with flattened patch input (also 256-dim) to calculate loss.
            # alternatively, you can map the output of transformer to 768-dim patch embedding space, and dot product with patch embedding. Performance-wise they are similar, but map to 256 space is more efficient.
            self.cpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            # masked patch reconstruction (generative objective) layer
            self.gpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            self.unfold = torch.nn.Unfold(kernel_size=(fshape, tshape), stride=(fstride, tstride))

            # we use learnable mask embedding (follow the BEIT paper), but using a fixed mask embedding (e.g., 0) leads to same performance.
            self.mask_embed = nn.Parameter(torch.zeros([1, 1, self.original_embedding_dim]))
            self.mask_embed = torch.nn.init.xavier_normal_(self.mask_embed)

            # get the intermediate shape
            self.p_f_dim, self.p_t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            num_patches = self.p_f_dim * self.p_t_dim
            self.num_patches = num_patches
            self.v.patch_embed.num_patches = num_patches
            print('pretraining patch split stride: frequency={:d}, time={:d}'.format(fstride, tstride))
            print('pretraining patch shape: frequency={:d}, time={:d}'.format(fshape, tshape))
            print('pretraining patch array dimension: frequency={:d}, time={:d}'.format(self.p_f_dim, self.p_t_dim))
            print('pretraining number of patches={:d}'.format(num_patches))

            # the linear patch projection layer, use 1 channel for spectrogram rather than the original 3 channels for RGB images.
            new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
            self.v.patch_embed.proj = new_proj

            # use trainable positional embedding
            new_pos_embed = nn.Parameter(torch.zeros(1, self.v.patch_embed.num_patches + self.cls_token_num, self.original_embedding_dim))
            self.v.pos_embed = new_pos_embed
            trunc_normal_(self.v.pos_embed, std=.02)

        # use a pretrained models for finetuning
        elif pretrain_stage == False:
            device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            if load_pretrained_mdl_path == None:
                raise ValueError('Please set load_pretrained_mdl_path to load a pretrained models.')
            sd = torch.load(load_pretrained_mdl_path, map_location=device)
            # get the fshape and tshape, input_fdim and input_tdim in the pretraining stage
            try:
                p_fshape, p_tshape = sd['module.v.patch_embed.proj.weight'].shape[2], sd['module.v.patch_embed.proj.weight'].shape[3]
                p_input_fdim, p_input_tdim = sd['module.p_input_fdim'].item(), sd['module.p_input_tdim'].item()
            except:
                raise  ValueError('The model loaded is not from a torch.nn.Dataparallel object. Wrap it with torch.nn.Dataparallel and try again.')

            print('now load a SSL pretrained models from ' + load_pretrained_mdl_path)
            # during pretraining, fstride=fshape and tstride=tshape because no patch overlapping is used
            # here, input_fdim and input_tdim should be that used in pretraining, not that in the fine-tuning.
            # we need to know input_fdim and input_tdim to do positional embedding cut/interpolation.
            # generally it should be better to use same input_fdim during pretraining and finetuning, but input_tdim can be safely different
            audio_model = ASTModel(fstride=p_fshape, tstride=p_tshape, fshape=p_fshape, tshape=p_tshape,
                                   input_fdim=p_input_fdim, input_tdim=p_input_tdim, pretrain_stage=True, model_size=model_size)
            audio_model = torch.nn.DataParallel(audio_model)
            audio_model.load_state_dict(sd, strict=False)

            self.v = audio_model.module.v
            self.original_embedding_dim = self.v.pos_embed.shape[2]
            self.cls_token_num = audio_model.module.cls_token_num

            # mlp head for fine-tuning
            self.mlp_head = nn.Sequential(nn.LayerNorm(self.original_embedding_dim),
                                          nn.Linear(self.original_embedding_dim, label_dim))

            f_dim, t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            # patch array dimension during pretraining
            p_f_dim, p_t_dim = audio_model.module.p_f_dim, audio_model.module.p_t_dim
            num_patches = f_dim * t_dim
            p_num_patches = p_f_dim * p_t_dim
            self.v.patch_embed.num_patches = num_patches
            print('fine-tuning patch split stride: frequncey={:d}, time={:d}'.format(fstride, tstride))
            print('fine-tuning number of patches={:d}'.format(num_patches))

            # patch shape should be same for pretraining and fine-tuning
            if fshape != p_fshape or tshape != p_tshape:
                raise ValueError('The patch shape of pretraining and fine-tuning is not consistant, pretraining: f={:d}, t={:d}, finetuning: f={:d}, t={:d}'.format(p_fshape, p_tshape, fshape, tshape))

            # patch split stride generally should be different for pretraining and fine-tuning, as patch split overlapping is only used in finetuning
            # during pretraining, p_fshape = p_fstride and p_tshape = p_tstride
            if fstride != p_fshape or tstride != p_tshape:
                # initialize a new patch embedding layer with desired new stride.
                new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
                # but the weights of patch embedding layer is still got from the pretrained models
                new_proj.weight = torch.nn.Parameter(torch.sum(self.v.patch_embed.proj.weight, dim=1).unsqueeze(1))
                new_proj.bias = self.v.patch_embed.proj.bias
                self.v.patch_embed.proj = new_proj

            new_pos_embed = self.v.pos_embed[:, self.cls_token_num:, :].detach().reshape(1, p_num_patches, self.original_embedding_dim).transpose(1, 2).reshape(1, self.original_embedding_dim, p_f_dim, p_t_dim)
            # cut or interpolate the positional embedding
            if t_dim < p_t_dim:
                new_pos_embed = new_pos_embed[:, :, :, int(p_t_dim/2) - int(t_dim / 2): int(p_t_dim/2) - int(t_dim / 2) + t_dim]
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(8, t_dim), mode='bilinear')
            if f_dim < p_f_dim:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')

            new_pos_embed = new_pos_embed.reshape(1, self.original_embedding_dim, num_patches).transpose(1, 2)
            self.v.pos_embed = nn.Parameter(torch.cat([self.v.pos_embed[:, :self.cls_token_num, :].detach(), new_pos_embed], dim=1))

    # get the shape of intermediate representation.
    def get_shape(self, fstride, tstride, input_fdim, input_tdim, fshape, tshape):
        test_input = torch.randn(1, 1, input_fdim, input_tdim)
        test_proj = nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
        test_out = test_proj(test_input)
        f_dim = test_out.shape[2]
        t_dim = test_out.shape[3]
        return f_dim, t_dim

    # generate mask for 16*16 patch
    def gen_maskid_patch(self, sequence_len=512, mask_size=100, cluster=3):
        mask_id = []

        # randomize clutering factor in [3,6)
        cur_clus = randrange(cluster) + 3

        while len(list(set(mask_id))) <= mask_size:
            start_id = randrange(sequence_len)

            # this improves the efficiency, but might change the pretrained model
            # while start_id in mask_id:
            #     start_id = randrange(sequence_len)

            cur_mask = []
            for i in range(0, cur_clus):
                for j in range(0, cur_clus):
                    mask_cand = start_id + self.p_t_dim * i + j
                    if mask_cand > 0 and mask_cand < sequence_len:
                        cur_mask.append(mask_cand)
            mask_id = mask_id + cur_mask
        mask_id = list(set(mask_id))[:mask_size]
        return torch.tensor(mask_id)

    # using cluster for frame masking hurts the performance, so just use the naive random sampling
    def gen_maskid_frame(self, sequence_len=512, mask_size=100):
        mask_id = random.sample(range(0, sequence_len), mask_size)
        return torch.tensor(mask_id)
    
    def finetuningavgtok_1sec(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        for blk_id, blk in enumerate(self.v.blocks):
            x = blk(x)
        x = self.v.norm(x)

        # Average output of tokens within each 1-second segment
        tokens_per_second = x.shape[1] // 60  
        x_averaged = torch.stack([torch.mean(x[:, i * tokens_per_second:(i + 1) * tokens_per_second, :], dim=1) for i in range(60)], dim=1)
        x_averaged = self.mlp_head(x_averaged)
        return x_averaged
        

    def finetuningavgtok(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)

        for blk_id, blk in enumerate(self.v.blocks):
            x = blk(x)
        x = self.v.norm(x)

        # average output of all tokens except cls token(s)
        x = torch.mean(x[:, self.cls_token_num:, :], dim=1)
        x = self.mlp_head(x)
        return x

    def finetuningcls(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)

        for blk_id, blk in enumerate(self.v.blocks):
            x = blk(x)
        x = self.v.norm(x)

        # if models has two cls tokens (DEIT), average as the clip-level representation
        if self.cls_token_num == 2:
            x = (x[:, 0] + x[:, 1]) / 2
        else:
            x = x[:, 0]
        x = self.mlp_head(x)
        return x

    # masked patch pretraining with discriminative objective
    def mpc(self, x, mask_patch, cluster, show_mask=False):
        input = self.unfold(x).transpose(1, 2)
        B = x.shape[0]
        # x in shape (batch_size, sequence_len, embedding dim)
        x = self.v.patch_embed(x)

        # encode the patch
        # size 12(batch_size) * 100(#mask_patch) * 768(hidden_dim), prepare to save the true values of masked samples
        encode_samples = torch.empty((B, mask_patch, 256), device=x.device, requires_grad=False).float()
        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)

        # for each audio clip in the batch
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            # copy the masked embeddings, note gradients are stopped in this path
            encode_samples[i] = input[i, mask_index[i], :].clone().detach()
            # mask the encode samples with 0
            mask_dense[i, mask_index[i], :] = 0

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # mask the patch
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # pass through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        if self.cls_token_num == 2: 
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        #print("x before blk.shape",x.shape)
        for blk in self.v.blocks:
            x = blk(x)
            #print("blk(x).shape",x.shape)
        x = self.v.norm(x)

        # prediction of the masked patch
        pred = torch.empty((B, mask_patch, 256), device=x.device).float()  # e.g. size 12*100*768
        for i in range(B):
            #  +2 for indexes because skipping the cls and dis token
            # we map the output of transformer (768-dim for base models) to 256-dim patch input space, and then dot product with flattened patch input (also 256-dim) to calculate loss.
            # alternatively, you can map the output of transformer to 768-dim patch embedding space, and dot product with patch embedding. Performance-wise they are similar, but map to 256 space is more efficient.
            pred[i] = self.cpredlayer(x[i, mask_index[i] + self.cls_token_num, :])

        # calculate the NCE loss
        nce = torch.tensor(0.0).to(x.device)
        correct = torch.tensor(0.0).to(x.device)
        for i in np.arange(0, B):
            # negative samples are from the same batch
            # 8/12/2022: has a difference with equation (1) in the ssast paper but (likely) performance-wise similar, see https://github.com/YuanGongND/ssast/issues/13
            total = torch.mm(encode_samples[i], torch.transpose(pred[i], 0, 1))  # e.g. size 100*100
            correct += torch.sum(torch.eq(torch.argmax(self.softmax(total), dim=0), torch.arange(0, mask_patch, device=x.device)))  # correct is a tensor
            nce += torch.sum(torch.diag(self.lsoftmax(total)))  # nce is a tensor
        acc = 1. * correct / (B * mask_patch)
        nce = nce / (-1. * B * mask_patch)

        # visualize the masked area, for probing test only, set show_mask = False for any training/inference.
        if show_mask == False:
            return acc, nce
        else:
            if B > 1:
                raise Exception('Currently only support single spectrogram probing test.')

            self.mask_correct = torch.nn.Parameter(torch.arange(0, mask_patch), requires_grad=False)

            pred = input.clone()  # [B, 512, 256]
            masked = input.clone()

            for i in range(B):
                result = [float(t) * 99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)]
                pred[i, mask_index[i], :] = torch.tensor(result).reshape(mask_patch, 1).expand(mask_patch, 256)
                masked[i, mask_index[i], :] = 99.0

            # print(total)
            # print(self.softmax(total))
            # print(torch.argmax(self.softmax(total), dim=0))
            # print(self.mask_correct)
            # print(torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct))
            # print([float(t)*99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)])

            fold = torch.nn.Fold(output_size=([self.input_fdim, self.input_tdim]), kernel_size=(self.fshape, self.tshape), stride=(self.fstride, self.tstride))
            pred = fold(pred.transpose(1, 2))
            masked = fold(masked.transpose(1, 2))

            return pred, masked

    # # masked patch pretraining with generative objective
    def mpg(self, input, mask_patch, cluster):
        B = input.shape[0]
        x = self.v.patch_embed(input)
        input = self.unfold(input).transpose(1, 2)

        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            mask_dense[i, mask_index[i], :] = 0

        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # go through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        if self.cls_token_num == 2: 
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        for blk in self.v.blocks:
            x = blk(x)
        x = self.v.norm(x)

        pred = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float()  # e.g. size 12*100*256
        target = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float() # e.g. size 12*100*256

        for i in range(B):
            #  +2 for indexes because cls and dis token
            pred[i] = self.gpredlayer(x[i, mask_index[i] + self.cls_token_num, :])
            target[i] = input[i, mask_index[i], :]

        # calculate the MSE loss
        mse = torch.mean((pred - target) ** 2)

        return mse

    def forward(self, x, task, cluster=True, mask_patch=400):
        # expect input x = (batch_size, time_frame_num, frequency_bins), e.g., (12, 1024, 128)
        x = x.unsqueeze(1)
        x = x.transpose(2, 3)

        # finetuning (ft), use the mean of all token (patch) output as clip-level representation.
        # this is default for SSAST fine-tuning as during pretraining, supervision signal is given to each token, not the [cls] token
        if task == 'ft_avgtok':
            return self.finetuningavgtok(x)
        elif task == 'ft_avgtok_1sec':
            return self.finetuningavgtok_1sec(x)
        # alternatively, use the [cls] token output as clip-level representation.
        elif task == 'ft_cls':
            return self.finetuningcls(x)
        # pretraining, masked patch classification (discriminative objective)
        elif task == 'pretrain_mpc':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster)
        # pretraining, masked patch reconstruction (generative objective)
        elif task == 'pretrain_mpg':
            return self.mpg(x, mask_patch=mask_patch, cluster=cluster)
        elif task == 'visualize_mask':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster, show_mask=True)
        else:
            raise Exception('Task unrecognized.')


if __name__ == '__main__':
    # fine-tuning stage
    # now you have a labeled dataset you want to finetune AST on
    # suppose the avg length is 100 frames (1s) and there are 35 classes
    # the fshape and tshape must be same in pretraining and finetuning
    # but fstride and tstride can be different in pretraining and finetuning
    # using smaller strides improves the performance but also increase the computational overhead
    # set pretrain_stage as False since now is in the finetuning stage
    # provide the path of the pretrained model you want to load
    input_tdim = 1997  # fine-tuning data length can be different with pretraining data length
    ast_mdl = AMBAModel(label_dim=1,
                 fshape=16, tshape=16, fstride=10, tstride=10,
                 input_fdim=30, input_tdim=1997, model_size='base',
                 pretrain_stage=False, load_pretrained_mdl_path='./ssamba_base_400.pth', vision_mamba_config={
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 48,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': True,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': False,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        })
    # # alternatively, use a frame based AST model
    # ast_mdl = ASTModel(label_dim=35,
    #              fshape=128, tshape=2, fstride=128, tstride=1,
    #              input_fdim=128, input_tdim=input_tdim, model_size='base',
    #              pretrain_stage=False, load_pretrained_mdl_path='./test_mdl.pth')

    # do finetuning, see src/traintest.py for our finetuning code
    test_input = torch.zeros([128, 1997, 30]).to(device)
    ast_mdl = ast_mdl.to(device)
    ast_mdl = ast_mdl.cuda()
    # print('test_input.shape',test_input.shape)
    prediction = ast_mdl(test_input, task='ft_avgtok')
    # output should in shape [batch_size, label_dim]
    print(prediction.shape)
    # calculate the loss, do back propagate, etc

    # # (optional) do some probe test
    # test_input = torch.zeros([1, input_tdim, 128]).to(device)
    # acc, nce = ast_mdl(test_input, task='pretrain_mpc', mask_patch=100)
    # # you can visualize the mask
    # pred, masked = ast_mdl(test_input, task='visualize_mask', mask_patch=100)
    # plt.imshow(masked[0,0])
    # plt.show()
# Out:
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# now load a SSL pretrained models from ./ssamba_base_400.pth
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# pretraining patch split stride: frequency=16, time=16
# pretraining patch shape: frequency=16, time=16
# pretraining patch array dimension: frequency=8, time=64
# pretraining number of patches=512
# fine-tuning patch split stride: frequncey=10, time=10
# fine-tuning number of patches=398
# torch.Size([128, 1])

# %%
input_height = features.size()[1]
input_width = features.size()[2]
model = AMBAModel(label_dim=1,
                 fshape=16, tshape=16, fstride=10, tstride=10,
                 input_fdim=30, input_tdim=1997, model_size='base',
                 pretrain_stage=False, load_pretrained_mdl_path='./ssamba_base_400.pth', vision_mamba_config={
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 36,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': False,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': True,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        }).to(device)
# model = Baseline_Model((input_height, input_width)).to(device)
# Out:
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# now load a SSL pretrained models from ./ssamba_base_400.pth
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# pretraining patch split stride: frequency=16, time=16
# pretraining patch shape: frequency=16, time=16
# pretraining patch array dimension: frequency=8, time=64
# pretraining number of patches=512
# fine-tuning patch split stride: frequncey=10, time=10
# fine-tuning number of patches=398

# %%
def MSE(output, target):
    loss = torch.mean((output - target)**2)
    return loss

def Bias(output, target):
    loss = torch.mean(output - target)
    return loss

def CovStep(output, target, output_mean, target_mean):
    loss = torch.mean(((output - output_mean) * (target - target_mean)))
    return loss

def MeanAbsLogStep(output, target, log=True):
    #convert out of log
    if log:
        vol_pred = 10**output
        vol_target = 10**target
    else:
        vol_pred = output
        vol_target = target
    loss = torch.mean(torch.abs(torch.log(vol_pred/vol_target)))
    return loss

def compute_eval_metrics(dataloader, model, log=True):
    target_sum = 0
    pred_sum = 0
    n_steps = 0
    
    for (x,y) in dataloader:        
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        target_sum += y.sum()
        pred_sum += pred.sum()
        n_steps += 1
    
    target_mean = target_sum/n_steps
    pred_mean = pred_sum/n_steps
    
    mse = 0
    mean_error = 0
    cov = 0
    abs_log_ratio = 0
    
    var_pred = 0 #technically var * N but gets cancelled out in Pearson calculation
    var_target = 0 
    
    for (x,y) in dataloader:        
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        mse += MSE(pred, y)
        mean_error += Bias(pred, y)
        cov += CovStep(pred, y, pred_mean, target_mean)
        abs_log_ratio += MeanAbsLogStep(pred, y, log=log)
        
        var_pred += MSE(pred, pred_mean)
        var_target += MSE(y, target_mean)
        
        pears = CovStep(pred, y, pred_mean, target_mean)/(torch.sqrt(MSE(pred, pred_mean))*torch.sqrt(MSE(y, target_mean)))
    
    out_dict = {}
    out_dict['mse'] = (mse / n_steps).item()
    out_dict['bias'] = (mean_error / n_steps).item()
    out_dict['pearson_cor'] = (cov/(torch.sqrt(var_pred) * torch.sqrt(var_target))).item()
    out_dict['mean_mult'] = (torch.exp(abs_log_ratio/n_steps)).item()
    
    return out_dict
    
# eval_dict = compute_eval_metrics(val_dataloader, model)
# print(eval_dict)

# %%
import os
import torch
from torch.optim import Adam
from torch.optim.lr_scheduler import StepLR
from time import time

def save_checkpoint(epoch, model, opt, filename='checkpoint.pth.tar'):
    state = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': opt.state_dict()
    }
    torch.save(state, filename)

def load_checkpoint(filename='checkpoint.pth.tar'):
    checkpoint = torch.load(filename)
    return checkpoint['epoch'], checkpoint['model_state_dict'], checkpoint['optimizer_state_dict']

# 设置保存模型的文件夹和文件名
save_dir = 'model_checkpoints'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
checkpoint_path = os.path.join(save_dir, 'checkpoint.pth.tar')
torch.set_default_dtype(torch.float32)
opt = Adam(model.parameters(),lr=0.0002, weight_decay=1e-5)

# 初始化学习率调度器
scheduler = StepLR(opt, step_size=2000, gamma=0.5)

start_epoch = 0
if os.path.isfile(checkpoint_path):
    print(f"Loading checkpoint from '{checkpoint_path}'")
    start_epoch, model_state_dict, optimizer_state_dict = load_checkpoint(checkpoint_path)
    model.load_state_dict(model_state_dict)
    opt.load_state_dict(optimizer_state_dict)
    print(f"Resuming from epoch {start_epoch}")

hist = {
	"train_loss": [],
	"val_loss": [],
    "val_bias": [],
    "val_pearson_cor": [],
    "val_mean_mult": []
}

for ep in range(1200000):     #########################################################################                   
    t_start = time()
    model.train()
    
    train_loss = 0
    val_loss = 0
    train_steps = 0
    val_steps = 0
    
    for (x, y) in train_dataloader:
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        loss = MSE(pred, y.reshape((y.shape[0], 1))).to(device)
        
        opt.zero_grad()
        loss.backward()
        opt.step()
        
        train_loss += loss
        train_steps += 1
    
    with torch.no_grad():
        model.eval()
        
        val_metrics = compute_eval_metrics(val_dataloader, model)
    
    
    hist['train_loss'].append(train_loss/train_steps)
    hist['val_loss'].append(val_metrics['mse'])
    hist['val_bias'].append(val_metrics['bias'])
    hist['val_pearson_cor'].append(val_metrics['pearson_cor'])
    hist['val_mean_mult'].append(val_metrics['mean_mult'])
    
    t_end = time()
    
    t_elapsed = t_end - t_start
    print("Epoch: {}\tDuration: {:.2f}s\tTrain loss: {:.4f}\tVal loss: {:.4f}\tVal bias:{:.4f}\tVal Pearson correlation: {:.4e}\tVal MeanMult: {:.4f}"\
          .format(ep, t_elapsed, train_loss/train_steps, val_metrics['mse'],\
                  val_metrics['bias'], val_metrics['pearson_cor'],val_metrics['mean_mult']))

# 更新学习率调度器
    scheduler.step()
    current_lr = opt.param_groups[0]['lr']
    print(f"Current learning rate: {current_lr}")
    
    if (ep + 1) % 20 == 0:
        save_checkpoint(ep + 1, model, opt, checkpoint_path)
        print(f"Checkpoint saved at epoch {ep + 1}")
# Out:
# Loading checkpoint from 'model_checkpoints/checkpoint.pth.tar'
# Resuming from epoch 600
# Epoch: 0	Duration: 85.19s	Train loss: 0.0382	Val loss: 0.0414	Val bias:0.0235	Val Pearson correlation: 9.1677e-01	Val MeanMult: 1.4404
# Current learning rate: 0.0002
# Epoch: 1	Duration: 88.59s	Train loss: 0.0380	Val loss: 0.0424	Val bias:0.0278	Val Pearson correlation: 9.1537e-01	Val MeanMult: 1.4455
# Current learning rate: 0.0002
# Epoch: 2	Duration: 84.42s	Train loss: 0.0379	Val loss: 0.0412	Val bias:0.0146	Val Pearson correlation: 9.1658e-01	Val MeanMult: 1.4397
# Current learning rate: 0.0002
# Epoch: 3	Duration: 85.31s	Train loss: 0.0379	Val loss: 0.0412	Val bias:0.0159	Val Pearson correlation: 9.1672e-01	Val MeanMult: 1.4392
# Current learning rate: 0.0002
# Epoch: 4	Duration: 85.28s	Train loss: 0.0378	Val loss: 0.0410	Val bias:0.0115	Val Pearson correlation: 9.1656e-01	Val MeanMult: 1.4389
# Current learning rate: 0.0002
# Epoch: 5	Duration: 84.41s	Train loss: 0.0379	Val loss: 0.0412	Val bias:0.0184	Val Pearson correlation: 9.1682e-01	Val MeanMult: 1.4394
# Current learning rate: 0.0002
# Epoch: 6	Duration: 95.91s	Train loss: 0.0379	Val loss: 0.0407	Val bias:0.0100	Val Pearson correlation: 9.1674e-01	Val MeanMult: 1.4370
# Current learning rate: 0.0002
# Epoch: 7	Duration: 84.51s	Train loss: 0.0378	Val loss: 0.0418	Val bias:0.0250	Val Pearson correlation: 9.1616e-01	Val MeanMult: 1.4423
# Current learning rate: 0.0002
# Epoch: 8	Duration: 84.66s	Train loss: 0.0377	Val loss: 0.0421	Val bias:0.0342	Val Pearson correlation: 9.1656e-01	Val MeanMult: 1.4431
# Current learning rate: 0.0002
# Epoch: 9	Duration: 87.40s	Train loss: 0.0376	Val loss: 0.0415	Val bias:0.0204	Val Pearson correlation: 9.1632e-01	Val MeanMult: 1.4404
# Current learning rate: 0.0002
# Epoch: 10	Duration: 84.55s	Train loss: 0.0375	Val loss: 0.0419	Val bias:0.0305	Val Pearson correlation: 9.1646e-01	Val MeanMult: 1.4422
# Current learning rate: 0.0002
# Epoch: 11	Duration: 84.73s	Train loss: 0.0376	Val loss: 0.0423	Val bias:0.0340	Val Pearson correlation: 9.1586e-01	Val MeanMult: 1.4437
# Current learning rate: 0.0002
# Epoch: 12	Duration: 85.47s	Train loss: 0.0377	Val loss: 0.0413	Val bias:0.0242	Val Pearson correlation: 9.1709e-01	Val MeanMult: 1.4398
# Current learning rate: 0.0002
# Epoch: 13	Duration: 90.64s	Train loss: 0.0375	Val loss: 0.0426	Val bias:0.0347	Val Pearson correlation: 9.1558e-01	Val MeanMult: 1.4458
# Current learning rate: 0.0002
# Epoch: 14	Duration: 84.75s	Train loss: 0.0375	Val loss: 0.0416	Val bias:0.0247	Val Pearson correlation: 9.1645e-01	Val MeanMult: 1.4410
# Current learning rate: 0.0002
# Epoch: 15	Duration: 84.79s	Train loss: 0.0376	Val loss: 0.0434	Val bias:0.0463	Val Pearson correlation: 9.1600e-01	Val MeanMult: 1.4504
# Current learning rate: 0.0002
# Epoch: 16	Duration: 84.67s	Train loss: 0.0376	Val loss: 0.0422	Val bias:0.0292	Val Pearson correlation: 9.1610e-01	Val MeanMult: 1.4441
# Current learning rate: 0.0002
# Epoch: 17	Duration: 117.64s	Train loss: 0.0379	Val loss: 0.0420	Val bias:0.0310	Val Pearson correlation: 9.1650e-01	Val MeanMult: 1.4434
# Current learning rate: 0.0002
# Epoch: 18	Duration: 84.57s	Train loss: 0.0375	Val loss: 0.0417	Val bias:0.0281	Val Pearson correlation: 9.1693e-01	Val MeanMult: 1.4419
# Current learning rate: 0.0002
# Epoch: 19	Duration: 84.56s	Train loss: 0.0375	Val loss: 0.0413	Val bias:0.0229	Val Pearson correlation: 9.1703e-01	Val MeanMult: 1.4387
# Current learning rate: 0.0002
# Checkpoint saved at epoch 20
# Epoch: 20	Duration: 84.75s	Train loss: 0.0373	Val loss: 0.0417	Val bias:0.0305	Val Pearson correlation: 9.1687e-01	Val MeanMult: 1.4406
# Current learning rate: 0.0002
# Epoch: 21	Duration: 84.46s	Train loss: 0.0372	Val loss: 0.0435	Val bias:0.0450	Val Pearson correlation: 9.1624e-01	Val MeanMult: 1.4519
# Current learning rate: 0.0002
# Epoch: 22	Duration: 97.00s	Train loss: 0.0378	Val loss: 0.0425	Val bias:0.0313	Val Pearson correlation: 9.1615e-01	Val MeanMult: 1.4457
# Current learning rate: 0.0002
# Epoch: 23	Duration: 84.72s	Train loss: 0.0374	Val loss: 0.0409	Val bias:0.0184	Val Pearson correlation: 9.1734e-01	Val MeanMult: 1.4375
# Current learning rate: 0.0002
# Epoch: 24	Duration: 84.78s	Train loss: 0.0377	Val loss: 0.0416	Val bias:0.0267	Val Pearson correlation: 9.1694e-01	Val MeanMult: 1.4404
# Current learning rate: 0.0002
# Epoch: 25	Duration: 88.14s	Train loss: 0.0376	Val loss: 0.0411	Val bias:0.0170	Val Pearson correlation: 9.1700e-01	Val MeanMult: 1.4381
# Current learning rate: 0.0002
# Epoch: 26	Duration: 84.83s	Train loss: 0.0372	Val loss: 0.0411	Val bias:0.0172	Val Pearson correlation: 9.1768e-01	Val MeanMult: 1.4390
# Current learning rate: 0.0002
# Epoch: 27	Duration: 85.67s	Train loss: 0.0374	Val loss: 0.0414	Val bias:0.0270	Val Pearson correlation: 9.1727e-01	Val MeanMult: 1.4398
# Current learning rate: 0.0002
# Epoch: 28	Duration: 84.56s	Train loss: 0.0374	Val loss: 0.0409	Val bias:0.0202	Val Pearson correlation: 9.1754e-01	Val MeanMult: 1.4370
# Current learning rate: 0.0002
# Epoch: 29	Duration: 85.09s	Train loss: 0.0376	Val loss: 0.0403	Val bias:0.0115	Val Pearson correlation: 9.1816e-01	Val MeanMult: 1.4341
# Current learning rate: 0.0002
# Epoch: 30	Duration: 90.49s	Train loss: 0.0374	Val loss: 0.0408	Val bias:0.0256	Val Pearson correlation: 9.1827e-01	Val MeanMult: 1.4358
# Current learning rate: 0.0002
# Epoch: 31	Duration: 84.75s	Train loss: 0.0372	Val loss: 0.0410	Val bias:0.0225	Val Pearson correlation: 9.1745e-01	Val MeanMult: 1.4372
# Current learning rate: 0.0002
# Epoch: 32	Duration: 95.49s	Train loss: 0.0373	Val loss: 0.0415	Val bias:0.0312	Val Pearson correlation: 9.1761e-01	Val MeanMult: 1.4396
# Current learning rate: 0.0002
# Epoch: 33	Duration: 85.58s	Train loss: 0.0371	Val loss: 0.0420	Val bias:0.0373	Val Pearson correlation: 9.1705e-01	Val MeanMult: 1.4419
# Current learning rate: 0.0002
# Epoch: 34	Duration: 84.74s	Train loss: 0.0373	Val loss: 0.0412	Val bias:0.0264	Val Pearson correlation: 9.1750e-01	Val MeanMult: 1.4379
# Current learning rate: 0.0002
# Epoch: 35	Duration: 85.66s	Train loss: 0.0372	Val loss: 0.0416	Val bias:0.0307	Val Pearson correlation: 9.1700e-01	Val MeanMult: 1.4398
# Current learning rate: 0.0002
# Epoch: 36	Duration: 94.87s	Train loss: 0.0371	Val loss: 0.0427	Val bias:0.0443	Val Pearson correlation: 9.1722e-01	Val MeanMult: 1.4457
# Current learning rate: 0.0002
# Epoch: 37	Duration: 84.71s	Train loss: 0.0372	Val loss: 0.0417	Val bias:0.0290	Val Pearson correlation: 9.1706e-01	Val MeanMult: 1.4408
# Current learning rate: 0.0002
# Epoch: 38	Duration: 86.52s	Train loss: 0.0370	Val loss: 0.0415	Val bias:0.0309	Val Pearson correlation: 9.1730e-01	Val MeanMult: 1.4389
# Current learning rate: 0.0002
# Epoch: 39	Duration: 85.31s	Train loss: 0.0369	Val loss: 0.0425	Val bias:0.0370	Val Pearson correlation: 9.1654e-01	Val MeanMult: 1.4447
# Current learning rate: 0.0002
# Checkpoint saved at epoch 40
# Epoch: 40	Duration: 84.61s	Train loss: 0.0373	Val loss: 0.0414	Val bias:0.0324	Val Pearson correlation: 9.1803e-01	Val MeanMult: 1.4392
# Current learning rate: 0.0002
# Epoch: 41	Duration: 84.33s	Train loss: 0.0370	Val loss: 0.0410	Val bias:0.0286	Val Pearson correlation: 9.1833e-01	Val MeanMult: 1.4368
# Current learning rate: 0.0002
# Epoch: 42	Duration: 84.51s	Train loss: 0.0369	Val loss: 0.0409	Val bias:0.0233	Val Pearson correlation: 9.1782e-01	Val MeanMult: 1.4368
# Current learning rate: 0.0002
# Epoch: 43	Duration: 84.49s	Train loss: 0.0372	Val loss: 0.0413	Val bias:0.0261	Val Pearson correlation: 9.1792e-01	Val MeanMult: 1.4400
# Current learning rate: 0.0002
# Epoch: 44	Duration: 84.57s	Train loss: 0.0371	Val loss: 0.0412	Val bias:0.0248	Val Pearson correlation: 9.1734e-01	Val MeanMult: 1.4381
# Current learning rate: 0.0002
# Epoch: 45	Duration: 84.55s	Train loss: 0.0369	Val loss: 0.0415	Val bias:0.0302	Val Pearson correlation: 9.1780e-01	Val MeanMult: 1.4400
# Current learning rate: 0.0002
# Epoch: 46	Duration: 85.47s	Train loss: 0.0367	Val loss: 0.0409	Val bias:0.0310	Val Pearson correlation: 9.1862e-01	Val MeanMult: 1.4360
# Current learning rate: 0.0002
# Epoch: 47	Duration: 84.45s	Train loss: 0.0366	Val loss: 0.0413	Val bias:0.0306	Val Pearson correlation: 9.1780e-01	Val MeanMult: 1.4383
# Current learning rate: 0.0002
# Epoch: 48	Duration: 86.10s	Train loss: 0.0369	Val loss: 0.0410	Val bias:0.0255	Val Pearson correlation: 9.1798e-01	Val MeanMult: 1.4365
# Current learning rate: 0.0002
# Epoch: 49	Duration: 84.42s	Train loss: 0.0368	Val loss: 0.0408	Val bias:0.0229	Val Pearson correlation: 9.1804e-01	Val MeanMult: 1.4369
# Current learning rate: 0.0002
# Epoch: 50	Duration: 95.67s	Train loss: 0.0370	Val loss: 0.0403	Val bias:0.0243	Val Pearson correlation: 9.1904e-01	Val MeanMult: 1.4327
# Current learning rate: 0.0002
# Epoch: 51	Duration: 85.39s	Train loss: 0.0367	Val loss: 0.0405	Val bias:0.0247	Val Pearson correlation: 9.1880e-01	Val MeanMult: 1.4345
# Current learning rate: 0.0002
# Epoch: 52	Duration: 85.29s	Train loss: 0.0366	Val loss: 0.0417	Val bias:0.0354	Val Pearson correlation: 9.1779e-01	Val MeanMult: 1.4413
# Current learning rate: 0.0002
# Epoch: 53	Duration: 84.61s	Train loss: 0.0370	Val loss: 0.0403	Val bias:0.0179	Val Pearson correlation: 9.1908e-01	Val MeanMult: 1.4339
# Current learning rate: 0.0002
# Epoch: 54	Duration: 85.44s	Train loss: 0.0366	Val loss: 0.0407	Val bias:0.0290	Val Pearson correlation: 9.1935e-01	Val MeanMult: 1.4356
# Current learning rate: 0.0002
# Epoch: 55	Duration: 84.43s	Train loss: 0.0370	Val loss: 0.0400	Val bias:0.0170	Val Pearson correlation: 9.1934e-01	Val MeanMult: 1.4322
# Current learning rate: 0.0002
# Epoch: 56	Duration: 84.41s	Train loss: 0.0366	Val loss: 0.0416	Val bias:0.0356	Val Pearson correlation: 9.1834e-01	Val MeanMult: 1.4408
# Current learning rate: 0.0002
# Epoch: 57	Duration: 84.45s	Train loss: 0.0364	Val loss: 0.0402	Val bias:0.0268	Val Pearson correlation: 9.1930e-01	Val MeanMult: 1.4314
# Current learning rate: 0.0002
# Epoch: 58	Duration: 85.40s	Train loss: 0.0367	Val loss: 0.0405	Val bias:0.0233	Val Pearson correlation: 9.1873e-01	Val MeanMult: 1.4339
# Current learning rate: 0.0002
# Epoch: 59	Duration: 84.49s	Train loss: 0.0368	Val loss: 0.0418	Val bias:0.0441	Val Pearson correlation: 9.1859e-01	Val MeanMult: 1.4399
# Current learning rate: 0.0002
# Checkpoint saved at epoch 60
# Epoch: 60	Duration: 103.75s	Train loss: 0.0367	Val loss: 0.0404	Val bias:0.0238	Val Pearson correlation: 9.1894e-01	Val MeanMult: 1.4331
# Current learning rate: 0.0002
# Epoch: 61	Duration: 96.73s	Train loss: 0.0366	Val loss: 0.0404	Val bias:0.0248	Val Pearson correlation: 9.1916e-01	Val MeanMult: 1.4344
# Current learning rate: 0.0002
# Epoch: 62	Duration: 89.14s	Train loss: 0.0367	Val loss: 0.0416	Val bias:0.0364	Val Pearson correlation: 9.1849e-01	Val MeanMult: 1.4403
# Current learning rate: 0.0002
# Epoch: 63	Duration: 85.54s	Train loss: 0.0365	Val loss: 0.0411	Val bias:0.0275	Val Pearson correlation: 9.1892e-01	Val MeanMult: 1.4383
# Current learning rate: 0.0002
# Epoch: 64	Duration: 85.52s	Train loss: 0.0365	Val loss: 0.0400	Val bias:0.0096	Val Pearson correlation: 9.1943e-01	Val MeanMult: 1.4330
# Current learning rate: 0.0002
# Epoch: 65	Duration: 85.38s	Train loss: 0.0365	Val loss: 0.0399	Val bias:0.0109	Val Pearson correlation: 9.1907e-01	Val MeanMult: 1.4314
# Current learning rate: 0.0002
# Epoch: 66	Duration: 84.63s	Train loss: 0.0368	Val loss: 0.0399	Val bias:0.0118	Val Pearson correlation: 9.1987e-01	Val MeanMult: 1.4320
# Current learning rate: 0.0002
# Epoch: 67	Duration: 95.48s	Train loss: 0.0366	Val loss: 0.0405	Val bias:0.0183	Val Pearson correlation: 9.1888e-01	Val MeanMult: 1.4350
# Current learning rate: 0.0002
# Epoch: 68	Duration: 85.49s	Train loss: 0.0365	Val loss: 0.0397	Val bias:0.0133	Val Pearson correlation: 9.1984e-01	Val MeanMult: 1.4302
# Current learning rate: 0.0002
# Epoch: 69	Duration: 85.41s	Train loss: 0.0364	Val loss: 0.0399	Val bias:0.0176	Val Pearson correlation: 9.1994e-01	Val MeanMult: 1.4308
# Current learning rate: 0.0002
# Epoch: 70	Duration: 84.49s	Train loss: 0.0365	Val loss: 0.0392	Val bias:0.0117	Val Pearson correlation: 9.2063e-01	Val MeanMult: 1.4276
# Current learning rate: 0.0002
# Epoch: 71	Duration: 84.42s	Train loss: 0.0362	Val loss: 0.0403	Val bias:0.0262	Val Pearson correlation: 9.1979e-01	Val MeanMult: 1.4326
# Current learning rate: 0.0002
# Epoch: 72	Duration: 84.51s	Train loss: 0.0362	Val loss: 0.0399	Val bias:0.0187	Val Pearson correlation: 9.2004e-01	Val MeanMult: 1.4314
# Current learning rate: 0.0002
# Epoch: 73	Duration: 84.53s	Train loss: 0.0362	Val loss: 0.0399	Val bias:0.0177	Val Pearson correlation: 9.2003e-01	Val MeanMult: 1.4313
# Current learning rate: 0.0002
# Epoch: 74	Duration: 85.32s	Train loss: 0.0363	Val loss: 0.0407	Val bias:0.0326	Val Pearson correlation: 9.1930e-01	Val MeanMult: 1.4342
# Current learning rate: 0.0002
# Epoch: 75	Duration: 84.47s	Train loss: 0.0364	Val loss: 0.0406	Val bias:0.0310	Val Pearson correlation: 9.1991e-01	Val MeanMult: 1.4344
# Current learning rate: 0.0002
# Epoch: 76	Duration: 84.38s	Train loss: 0.0363	Val loss: 0.0400	Val bias:0.0211	Val Pearson correlation: 9.1991e-01	Val MeanMult: 1.4315
# Current learning rate: 0.0002
# Epoch: 77	Duration: 84.47s	Train loss: 0.0364	Val loss: 0.0394	Val bias:0.0156	Val Pearson correlation: 9.2005e-01	Val MeanMult: 1.4276
# Current learning rate: 0.0002
# Epoch: 78	Duration: 87.72s	Train loss: 0.0361	Val loss: 0.0407	Val bias:0.0279	Val Pearson correlation: 9.1889e-01	Val MeanMult: 1.4346
# Current learning rate: 0.0002
# Epoch: 79	Duration: 84.50s	Train loss: 0.0363	Val loss: 0.0399	Val bias:0.0213	Val Pearson correlation: 9.1988e-01	Val MeanMult: 1.4299
# Current learning rate: 0.0002
# Checkpoint saved at epoch 80
# Epoch: 80	Duration: 89.99s	Train loss: 0.0362	Val loss: 0.0404	Val bias:0.0325	Val Pearson correlation: 9.1995e-01	Val MeanMult: 1.4326
# Current learning rate: 0.0002
# Epoch: 81	Duration: 84.71s	Train loss: 0.0363	Val loss: 0.0394	Val bias:0.0240	Val Pearson correlation: 9.2126e-01	Val MeanMult: 1.4280
# Current learning rate: 0.0002
# Epoch: 82	Duration: 84.49s	Train loss: 0.0362	Val loss: 0.0402	Val bias:0.0278	Val Pearson correlation: 9.2027e-01	Val MeanMult: 1.4320
# Current learning rate: 0.0002
# Epoch: 83	Duration: 100.25s	Train loss: 0.0361	Val loss: 0.0393	Val bias:0.0089	Val Pearson correlation: 9.2074e-01	Val MeanMult: 1.4285
# Current learning rate: 0.0002
# Epoch: 84	Duration: 90.14s	Train loss: 0.0362	Val loss: 0.0407	Val bias:0.0337	Val Pearson correlation: 9.1967e-01	Val MeanMult: 1.4346
# Current learning rate: 0.0002
# Epoch: 85	Duration: 84.66s	Train loss: 0.0363	Val loss: 0.0397	Val bias:0.0167	Val Pearson correlation: 9.2050e-01	Val MeanMult: 1.4300
# Current learning rate: 0.0002
# Epoch: 86	Duration: 88.21s	Train loss: 0.0362	Val loss: 0.0392	Val bias:0.0119	Val Pearson correlation: 9.2112e-01	Val MeanMult: 1.4280
# Current learning rate: 0.0002
# Epoch: 87	Duration: 85.92s	Train loss: 0.0360	Val loss: 0.0395	Val bias:0.0175	Val Pearson correlation: 9.2078e-01	Val MeanMult: 1.4294
# Current learning rate: 0.0002
# Epoch: 88	Duration: 84.71s	Train loss: 0.0362	Val loss: 0.0400	Val bias:0.0250	Val Pearson correlation: 9.2001e-01	Val MeanMult: 1.4309
# Current learning rate: 0.0002
# Epoch: 89	Duration: 85.42s	Train loss: 0.0362	Val loss: 0.0412	Val bias:0.0378	Val Pearson correlation: 9.1939e-01	Val MeanMult: 1.4374
# Current learning rate: 0.0002
# Epoch: 90	Duration: 84.72s	Train loss: 0.0361	Val loss: 0.0398	Val bias:0.0284	Val Pearson correlation: 9.2121e-01	Val MeanMult: 1.4305
# Current learning rate: 0.0002
# Epoch: 91	Duration: 84.68s	Train loss: 0.0362	Val loss: 0.0396	Val bias:0.0132	Val Pearson correlation: 9.2050e-01	Val MeanMult: 1.4297
# Current learning rate: 0.0002
# Epoch: 92	Duration: 84.72s	Train loss: 0.0361	Val loss: 0.0391	Val bias:0.0133	Val Pearson correlation: 9.2140e-01	Val MeanMult: 1.4272
# Current learning rate: 0.0002
# Epoch: 93	Duration: 91.99s	Train loss: 0.0361	Val loss: 0.0384	Val bias:-0.0064	Val Pearson correlation: 9.2228e-01	Val MeanMult: 1.4244
# Current learning rate: 0.0002
# Epoch: 94	Duration: 86.11s	Train loss: 0.0358	Val loss: 0.0391	Val bias:0.0166	Val Pearson correlation: 9.2172e-01	Val MeanMult: 1.4269
# Current learning rate: 0.0002
# Epoch: 95	Duration: 84.65s	Train loss: 0.0358	Val loss: 0.0389	Val bias:0.0125	Val Pearson correlation: 9.2137e-01	Val MeanMult: 1.4254
# Current learning rate: 0.0002
# Epoch: 96	Duration: 85.47s	Train loss: 0.0358	Val loss: 0.0397	Val bias:0.0280	Val Pearson correlation: 9.2106e-01	Val MeanMult: 1.4292
# Current learning rate: 0.0002
# Epoch: 97	Duration: 87.88s	Train loss: 0.0358	Val loss: 0.0398	Val bias:0.0312	Val Pearson correlation: 9.2147e-01	Val MeanMult: 1.4301
# Current learning rate: 0.0002
# Epoch: 98	Duration: 84.67s	Train loss: 0.0360	Val loss: 0.0389	Val bias:0.0153	Val Pearson correlation: 9.2166e-01	Val MeanMult: 1.4250
# Current learning rate: 0.0002
# Epoch: 99	Duration: 85.58s	Train loss: 0.0359	Val loss: 0.0395	Val bias:0.0234	Val Pearson correlation: 9.2097e-01	Val MeanMult: 1.4287
# Current learning rate: 0.0002
# Checkpoint saved at epoch 100
# Epoch: 100	Duration: 85.62s	Train loss: 0.0362	Val loss: 0.0391	Val bias:0.0194	Val Pearson correlation: 9.2146e-01	Val MeanMult: 1.4259
# Current learning rate: 0.0002
# Epoch: 101	Duration: 84.75s	Train loss: 0.0359	Val loss: 0.0389	Val bias:0.0211	Val Pearson correlation: 9.2214e-01	Val MeanMult: 1.4252
# Current learning rate: 0.0002
# Epoch: 102	Duration: 84.58s	Train loss: 0.0358	Val loss: 0.0386	Val bias:0.0170	Val Pearson correlation: 9.2262e-01	Val MeanMult: 1.4236
# Current learning rate: 0.0002
# Epoch: 103	Duration: 84.63s	Train loss: 0.0356	Val loss: 0.0387	Val bias:0.0144	Val Pearson correlation: 9.2201e-01	Val MeanMult: 1.4239
# Current learning rate: 0.0002
# Epoch: 104	Duration: 84.88s	Train loss: 0.0358	Val loss: 0.0386	Val bias:0.0151	Val Pearson correlation: 9.2189e-01	Val MeanMult: 1.4236
# Current learning rate: 0.0002
# Epoch: 105	Duration: 85.51s	Train loss: 0.0357	Val loss: 0.0394	Val bias:0.0246	Val Pearson correlation: 9.2122e-01	Val MeanMult: 1.4272
# Current learning rate: 0.0002
# Epoch: 106	Duration: 87.43s	Train loss: 0.0356	Val loss: 0.0389	Val bias:0.0207	Val Pearson correlation: 9.2183e-01	Val MeanMult: 1.4241
# Current learning rate: 0.0002
# Epoch: 107	Duration: 84.67s	Train loss: 0.0354	Val loss: 0.0396	Val bias:0.0286	Val Pearson correlation: 9.2134e-01	Val MeanMult: 1.4278
# Current learning rate: 0.0002
# Epoch: 108	Duration: 84.60s	Train loss: 0.0354	Val loss: 0.0392	Val bias:0.0225	Val Pearson correlation: 9.2119e-01	Val MeanMult: 1.4262
# Current learning rate: 0.0002
# Epoch: 109	Duration: 84.61s	Train loss: 0.0360	Val loss: 0.0401	Val bias:0.0316	Val Pearson correlation: 9.2078e-01	Val MeanMult: 1.4313
# Current learning rate: 0.0002
# Epoch: 110	Duration: 84.53s	Train loss: 0.0355	Val loss: 0.0404	Val bias:0.0399	Val Pearson correlation: 9.2110e-01	Val MeanMult: 1.4320
# Current learning rate: 0.0002
# Epoch: 111	Duration: 84.67s	Train loss: 0.0358	Val loss: 0.0390	Val bias:0.0290	Val Pearson correlation: 9.2192e-01	Val MeanMult: 1.4235
# Current learning rate: 0.0002
# Epoch: 112	Duration: 84.66s	Train loss: 0.0357	Val loss: 0.0392	Val bias:0.0276	Val Pearson correlation: 9.2150e-01	Val MeanMult: 1.4247
# Current learning rate: 0.0002
# Epoch: 113	Duration: 85.54s	Train loss: 0.0358	Val loss: 0.0402	Val bias:0.0361	Val Pearson correlation: 9.2098e-01	Val MeanMult: 1.4310
# Current learning rate: 0.0002
# Epoch: 114	Duration: 84.54s	Train loss: 0.0354	Val loss: 0.0408	Val bias:0.0409	Val Pearson correlation: 9.2056e-01	Val MeanMult: 1.4346
# Current learning rate: 0.0002
# Epoch: 115	Duration: 105.45s	Train loss: 0.0355	Val loss: 0.0392	Val bias:0.0285	Val Pearson correlation: 9.2192e-01	Val MeanMult: 1.4255
# Current learning rate: 0.0002
# Epoch: 116	Duration: 85.56s	Train loss: 0.0355	Val loss: 0.0402	Val bias:0.0356	Val Pearson correlation: 9.2085e-01	Val MeanMult: 1.4312
# Current learning rate: 0.0002
# Epoch: 117	Duration: 84.54s	Train loss: 0.0356	Val loss: 0.0389	Val bias:0.0244	Val Pearson correlation: 9.2272e-01	Val MeanMult: 1.4251
# Current learning rate: 0.0002
# Epoch: 118	Duration: 84.64s	Train loss: 0.0356	Val loss: 0.0389	Val bias:0.0197	Val Pearson correlation: 9.2203e-01	Val MeanMult: 1.4243
# Current learning rate: 0.0002
# Epoch: 119	Duration: 84.81s	Train loss: 0.0356	Val loss: 0.0400	Val bias:0.0343	Val Pearson correlation: 9.2153e-01	Val MeanMult: 1.4309
# Current learning rate: 0.0002
# Checkpoint saved at epoch 120
# Epoch: 120	Duration: 87.77s	Train loss: 0.0358	Val loss: 0.0399	Val bias:0.0328	Val Pearson correlation: 9.2181e-01	Val MeanMult: 1.4300
# Current learning rate: 0.0002
# Epoch: 121	Duration: 84.41s	Train loss: 0.0358	Val loss: 0.0387	Val bias:0.0160	Val Pearson correlation: 9.2226e-01	Val MeanMult: 1.4240
# Current learning rate: 0.0002
# Epoch: 122	Duration: 85.54s	Train loss: 0.0356	Val loss: 0.0392	Val bias:0.0305	Val Pearson correlation: 9.2265e-01	Val MeanMult: 1.4267
# Current learning rate: 0.0002
# Epoch: 123	Duration: 84.52s	Train loss: 0.0355	Val loss: 0.0386	Val bias:0.0124	Val Pearson correlation: 9.2205e-01	Val MeanMult: 1.4235
# Current learning rate: 0.0002
# Epoch: 124	Duration: 84.59s	Train loss: 0.0356	Val loss: 0.0381	Val bias:0.0076	Val Pearson correlation: 9.2311e-01	Val MeanMult: 1.4210
# Current learning rate: 0.0002
# Epoch: 125	Duration: 84.63s	Train loss: 0.0356	Val loss: 0.0379	Val bias:0.0050	Val Pearson correlation: 9.2331e-01	Val MeanMult: 1.4205
# Current learning rate: 0.0002
# Epoch: 126	Duration: 84.40s	Train loss: 0.0355	Val loss: 0.0380	Val bias:0.0147	Val Pearson correlation: 9.2330e-01	Val MeanMult: 1.4193
# Current learning rate: 0.0002
# Epoch: 127	Duration: 84.51s	Train loss: 0.0356	Val loss: 0.0393	Val bias:0.0287	Val Pearson correlation: 9.2231e-01	Val MeanMult: 1.4272
# Current learning rate: 0.0002
# Epoch: 128	Duration: 84.47s	Train loss: 0.0354	Val loss: 0.0387	Val bias:0.0151	Val Pearson correlation: 9.2190e-01	Val MeanMult: 1.4245
# Current learning rate: 0.0002
# Epoch: 129	Duration: 92.77s	Train loss: 0.0354	Val loss: 0.0383	Val bias:0.0121	Val Pearson correlation: 9.2248e-01	Val MeanMult: 1.4214
# Current learning rate: 0.0002
# Epoch: 130	Duration: 84.40s	Train loss: 0.0351	Val loss: 0.0388	Val bias:0.0217	Val Pearson correlation: 9.2193e-01	Val MeanMult: 1.4230
# Current learning rate: 0.0002
# Epoch: 131	Duration: 84.38s	Train loss: 0.0353	Val loss: 0.0393	Val bias:0.0260	Val Pearson correlation: 9.2155e-01	Val MeanMult: 1.4259
# Current learning rate: 0.0002
# Epoch: 132	Duration: 85.42s	Train loss: 0.0353	Val loss: 0.0392	Val bias:0.0341	Val Pearson correlation: 9.2257e-01	Val MeanMult: 1.4246
# Current learning rate: 0.0002
# Epoch: 133	Duration: 87.37s	Train loss: 0.0355	Val loss: 0.0390	Val bias:0.0298	Val Pearson correlation: 9.2276e-01	Val MeanMult: 1.4246
# Current learning rate: 0.0002
# Epoch: 134	Duration: 84.62s	Train loss: 0.0353	Val loss: 0.0413	Val bias:0.0458	Val Pearson correlation: 9.2093e-01	Val MeanMult: 1.4383
# Current learning rate: 0.0002
# Epoch: 135	Duration: 84.52s	Train loss: 0.0353	Val loss: 0.0392	Val bias:0.0251	Val Pearson correlation: 9.2185e-01	Val MeanMult: 1.4255
# Current learning rate: 0.0002
# Epoch: 136	Duration: 85.49s	Train loss: 0.0353	Val loss: 0.0403	Val bias:0.0384	Val Pearson correlation: 9.2128e-01	Val MeanMult: 1.4319
# Current learning rate: 0.0002
# Epoch: 137	Duration: 84.70s	Train loss: 0.0354	Val loss: 0.0392	Val bias:0.0243	Val Pearson correlation: 9.2172e-01	Val MeanMult: 1.4255
# Current learning rate: 0.0002
# Epoch: 138	Duration: 92.26s	Train loss: 0.0353	Val loss: 0.0395	Val bias:0.0296	Val Pearson correlation: 9.2145e-01	Val MeanMult: 1.4275
# Current learning rate: 0.0002
# Epoch: 139	Duration: 84.78s	Train loss: 0.0351	Val loss: 0.0384	Val bias:0.0200	Val Pearson correlation: 9.2336e-01	Val MeanMult: 1.4218
# Current learning rate: 0.0002
# Checkpoint saved at epoch 140
# Epoch: 140	Duration: 85.62s	Train loss: 0.0350	Val loss: 0.0398	Val bias:0.0365	Val Pearson correlation: 9.2194e-01	Val MeanMult: 1.4290
# Current learning rate: 0.0002
# Epoch: 141	Duration: 84.73s	Train loss: 0.0351	Val loss: 0.0392	Val bias:0.0311	Val Pearson correlation: 9.2251e-01	Val MeanMult: 1.4260
# Current learning rate: 0.0002
# Epoch: 142	Duration: 92.17s	Train loss: 0.0350	Val loss: 0.0388	Val bias:0.0276	Val Pearson correlation: 9.2291e-01	Val MeanMult: 1.4240
# Current learning rate: 0.0002
# Epoch: 143	Duration: 85.45s	Train loss: 0.0350	Val loss: 0.0394	Val bias:0.0311	Val Pearson correlation: 9.2223e-01	Val MeanMult: 1.4267
# Current learning rate: 0.0002
# Epoch: 144	Duration: 101.10s	Train loss: 0.0351	Val loss: 0.0389	Val bias:0.0289	Val Pearson correlation: 9.2294e-01	Val MeanMult: 1.4240
# Current learning rate: 0.0002
# Epoch: 145	Duration: 88.04s	Train loss: 0.0351	Val loss: 0.0396	Val bias:0.0263	Val Pearson correlation: 9.2137e-01	Val MeanMult: 1.4286
# Current learning rate: 0.0002
# Epoch: 146	Duration: 84.67s	Train loss: 0.0351	Val loss: 0.0383	Val bias:0.0159	Val Pearson correlation: 9.2274e-01	Val MeanMult: 1.4214
# Current learning rate: 0.0002
# Epoch: 147	Duration: 94.25s	Train loss: 0.0350	Val loss: 0.0403	Val bias:0.0437	Val Pearson correlation: 9.2222e-01	Val MeanMult: 1.4317
# Current learning rate: 0.0002
# Epoch: 148	Duration: 84.80s	Train loss: 0.0349	Val loss: 0.0393	Val bias:0.0310	Val Pearson correlation: 9.2257e-01	Val MeanMult: 1.4266
# Current learning rate: 0.0002
# Epoch: 149	Duration: 84.80s	Train loss: 0.0350	Val loss: 0.0388	Val bias:0.0305	Val Pearson correlation: 9.2314e-01	Val MeanMult: 1.4227
# Current learning rate: 0.0002
# Epoch: 150	Duration: 87.16s	Train loss: 0.0349	Val loss: 0.0394	Val bias:0.0334	Val Pearson correlation: 9.2275e-01	Val MeanMult: 1.4270
# Current learning rate: 0.0002
# Epoch: 151	Duration: 84.72s	Train loss: 0.0351	Val loss: 0.0398	Val bias:0.0335	Val Pearson correlation: 9.2221e-01	Val MeanMult: 1.4293
# Current learning rate: 0.0002
# Epoch: 152	Duration: 90.01s	Train loss: 0.0352	Val loss: 0.0383	Val bias:0.0182	Val Pearson correlation: 9.2290e-01	Val MeanMult: 1.4203
# Current learning rate: 0.0002
# Epoch: 153	Duration: 102.93s	Train loss: 0.0350	Val loss: 0.0384	Val bias:0.0152	Val Pearson correlation: 9.2322e-01	Val MeanMult: 1.4223
# Current learning rate: 0.0002
# Epoch: 154	Duration: 84.71s	Train loss: 0.0350	Val loss: 0.0389	Val bias:0.0270	Val Pearson correlation: 9.2319e-01	Val MeanMult: 1.4239
# Current learning rate: 0.0002
# Epoch: 155	Duration: 84.69s	Train loss: 0.0345	Val loss: 0.0385	Val bias:0.0236	Val Pearson correlation: 9.2360e-01	Val MeanMult: 1.4222
# Current learning rate: 0.0002
# Epoch: 156	Duration: 86.44s	Train loss: 0.0351	Val loss: 0.0402	Val bias:0.0366	Val Pearson correlation: 9.2137e-01	Val MeanMult: 1.4309
# Current learning rate: 0.0002
# Epoch: 157	Duration: 86.02s	Train loss: 0.0347	Val loss: 0.0390	Val bias:0.0274	Val Pearson correlation: 9.2310e-01	Val MeanMult: 1.4253
# Current learning rate: 0.0002
# Epoch: 158	Duration: 84.74s	Train loss: 0.0347	Val loss: 0.0393	Val bias:0.0301	Val Pearson correlation: 9.2249e-01	Val MeanMult: 1.4259
# Current learning rate: 0.0002
# Epoch: 159	Duration: 90.65s	Train loss: 0.0347	Val loss: 0.0385	Val bias:0.0204	Val Pearson correlation: 9.2296e-01	Val MeanMult: 1.4222
# Current learning rate: 0.0002
# Checkpoint saved at epoch 160
# Epoch: 160	Duration: 84.64s	Train loss: 0.0348	Val loss: 0.0400	Val bias:0.0366	Val Pearson correlation: 9.2256e-01	Val MeanMult: 1.4312
# Current learning rate: 0.0002
# Epoch: 161	Duration: 84.59s	Train loss: 0.0347	Val loss: 0.0389	Val bias:0.0315	Val Pearson correlation: 9.2370e-01	Val MeanMult: 1.4245
# Current learning rate: 0.0002
# Epoch: 162	Duration: 84.65s	Train loss: 0.0351	Val loss: 0.0380	Val bias:0.0135	Val Pearson correlation: 9.2373e-01	Val MeanMult: 1.4195
# Current learning rate: 0.0002
# Epoch: 163	Duration: 84.56s	Train loss: 0.0350	Val loss: 0.0377	Val bias:0.0084	Val Pearson correlation: 9.2449e-01	Val MeanMult: 1.4184
# Current learning rate: 0.0002
# Epoch: 164	Duration: 98.30s	Train loss: 0.0349	Val loss: 0.0381	Val bias:0.0185	Val Pearson correlation: 9.2386e-01	Val MeanMult: 1.4203
# Current learning rate: 0.0002
# Epoch: 165	Duration: 84.70s	Train loss: 0.0351	Val loss: 0.0380	Val bias:0.0059	Val Pearson correlation: 9.2371e-01	Val MeanMult: 1.4207
# Current learning rate: 0.0002
# Epoch: 166	Duration: 84.61s	Train loss: 0.0349	Val loss: 0.0382	Val bias:0.0228	Val Pearson correlation: 9.2423e-01	Val MeanMult: 1.4212
# Current learning rate: 0.0002
# Epoch: 167	Duration: 85.55s	Train loss: 0.0351	Val loss: 0.0388	Val bias:0.0286	Val Pearson correlation: 9.2404e-01	Val MeanMult: 1.4244
# Current learning rate: 0.0002
# Epoch: 168	Duration: 85.27s	Train loss: 0.0348	Val loss: 0.0375	Val bias:0.0214	Val Pearson correlation: 9.2517e-01	Val MeanMult: 1.4160
# Current learning rate: 0.0002
# Epoch: 169	Duration: 85.55s	Train loss: 0.0348	Val loss: 0.0387	Val bias:0.0313	Val Pearson correlation: 9.2333e-01	Val MeanMult: 1.4229
# Current learning rate: 0.0002
# Epoch: 170	Duration: 84.82s	Train loss: 0.0353	Val loss: 0.0396	Val bias:0.0374	Val Pearson correlation: 9.2253e-01	Val MeanMult: 1.4279
# Current learning rate: 0.0002
# Epoch: 171	Duration: 94.00s	Train loss: 0.0348	Val loss: 0.0390	Val bias:0.0293	Val Pearson correlation: 9.2316e-01	Val MeanMult: 1.4248
# Current learning rate: 0.0002
# Epoch: 172	Duration: 84.57s	Train loss: 0.0349	Val loss: 0.0397	Val bias:0.0423	Val Pearson correlation: 9.2352e-01	Val MeanMult: 1.4279
# Current learning rate: 0.0002
# Epoch: 173	Duration: 85.49s	Train loss: 0.0349	Val loss: 0.0417	Val bias:0.0537	Val Pearson correlation: 9.2105e-01	Val MeanMult: 1.4388
# Current learning rate: 0.0002
# Epoch: 174	Duration: 85.36s	Train loss: 0.0351	Val loss: 0.0401	Val bias:0.0408	Val Pearson correlation: 9.2229e-01	Val MeanMult: 1.4304
# Current learning rate: 0.0002
# Epoch: 175	Duration: 84.76s	Train loss: 0.0347	Val loss: 0.0401	Val bias:0.0460	Val Pearson correlation: 9.2288e-01	Val MeanMult: 1.4294
# Current learning rate: 0.0002
# Epoch: 176	Duration: 98.52s	Train loss: 0.0347	Val loss: 0.0400	Val bias:0.0449	Val Pearson correlation: 9.2293e-01	Val MeanMult: 1.4288
# Current learning rate: 0.0002
# Epoch: 177	Duration: 84.40s	Train loss: 0.0349	Val loss: 0.0420	Val bias:0.0602	Val Pearson correlation: 9.2233e-01	Val MeanMult: 1.4419
# Current learning rate: 0.0002
# Epoch: 178	Duration: 84.50s	Train loss: 0.0352	Val loss: 0.0408	Val bias:0.0483	Val Pearson correlation: 9.2203e-01	Val MeanMult: 1.4334
# Current learning rate: 0.0002
# Epoch: 179	Duration: 84.43s	Train loss: 0.0350	Val loss: 0.0411	Val bias:0.0514	Val Pearson correlation: 9.2203e-01	Val MeanMult: 1.4358
# Current learning rate: 0.0002
# Checkpoint saved at epoch 180
# Epoch: 180	Duration: 86.15s	Train loss: 0.0352	Val loss: 0.0406	Val bias:0.0452	Val Pearson correlation: 9.2189e-01	Val MeanMult: 1.4323
# Current learning rate: 0.0002
# Epoch: 181	Duration: 85.35s	Train loss: 0.0351	Val loss: 0.0388	Val bias:0.0283	Val Pearson correlation: 9.2322e-01	Val MeanMult: 1.4233
# Current learning rate: 0.0002
# Epoch: 182	Duration: 84.42s	Train loss: 0.0353	Val loss: 0.0411	Val bias:0.0529	Val Pearson correlation: 9.2226e-01	Val MeanMult: 1.4362
# Current learning rate: 0.0002
# Epoch: 183	Duration: 85.52s	Train loss: 0.0357	Val loss: 0.0417	Val bias:0.0521	Val Pearson correlation: 9.2058e-01	Val MeanMult: 1.4393
# Current learning rate: 0.0002
# Epoch: 184	Duration: 85.38s	Train loss: 0.0357	Val loss: 0.0401	Val bias:0.0437	Val Pearson correlation: 9.2293e-01	Val MeanMult: 1.4305
# Current learning rate: 0.0002
# Epoch: 185	Duration: 111.36s	Train loss: 0.0362	Val loss: 0.0398	Val bias:0.0414	Val Pearson correlation: 9.2258e-01	Val MeanMult: 1.4275
# Current learning rate: 0.0002
# Epoch: 186	Duration: 85.68s	Train loss: 0.0370	Val loss: 0.0386	Val bias:0.0300	Val Pearson correlation: 9.2360e-01	Val MeanMult: 1.4218
# Current learning rate: 0.0002
# Epoch: 187	Duration: 84.67s	Train loss: 0.0382	Val loss: 0.0375	Val bias:0.0012	Val Pearson correlation: 9.2418e-01	Val MeanMult: 1.4179
# Current learning rate: 0.0002
# Epoch: 188	Duration: 84.82s	Train loss: 0.0397	Val loss: 0.0374	Val bias:-0.0174	Val Pearson correlation: 9.2480e-01	Val MeanMult: 1.4191
# Current learning rate: 0.0002
# Epoch: 189	Duration: 84.60s	Train loss: 0.0404	Val loss: 0.0485	Val bias:-0.1071	Val Pearson correlation: 9.2477e-01	Val MeanMult: 1.5020
# Current learning rate: 0.0002
# Epoch: 190	Duration: 84.53s	Train loss: 0.0414	Val loss: 0.0534	Val bias:-0.1279	Val Pearson correlation: 9.2454e-01	Val MeanMult: 1.5345
# Current learning rate: 0.0002
# Epoch: 191	Duration: 85.70s	Train loss: 0.0426	Val loss: 0.0462	Val bias:-0.0971	Val Pearson correlation: 9.2533e-01	Val MeanMult: 1.4838
# Current learning rate: 0.0002
# Epoch: 192	Duration: 84.73s	Train loss: 0.0417	Val loss: 0.0415	Val bias:-0.0708	Val Pearson correlation: 9.2570e-01	Val MeanMult: 1.4510
# Current learning rate: 0.0002
# Epoch: 193	Duration: 85.57s	Train loss: 0.0413	Val loss: 0.0414	Val bias:-0.0677	Val Pearson correlation: 9.2552e-01	Val MeanMult: 1.4491
# Current learning rate: 0.0002
# Epoch: 194	Duration: 84.87s	Train loss: 0.0411	Val loss: 0.0412	Val bias:-0.0670	Val Pearson correlation: 9.2585e-01	Val MeanMult: 1.4479
# Current learning rate: 0.0002
# Epoch: 195	Duration: 89.68s	Train loss: 0.0413	Val loss: 0.0406	Val bias:-0.0622	Val Pearson correlation: 9.2553e-01	Val MeanMult: 1.4436
# Current learning rate: 0.0002
# Epoch: 196	Duration: 85.58s	Train loss: 0.0412	Val loss: 0.0395	Val bias:-0.0492	Val Pearson correlation: 9.2504e-01	Val MeanMult: 1.4359
# Current learning rate: 0.0002
# Epoch: 197	Duration: 84.60s	Train loss: 0.0412	Val loss: 0.0396	Val bias:-0.0493	Val Pearson correlation: 9.2488e-01	Val MeanMult: 1.4368
# Current learning rate: 0.0002
# Epoch: 198	Duration: 84.72s	Train loss: 0.0418	Val loss: 0.0397	Val bias:-0.0483	Val Pearson correlation: 9.2457e-01	Val MeanMult: 1.4369
# Current learning rate: 0.0002
# Epoch: 199	Duration: 84.72s	Train loss: 0.0420	Val loss: 0.0397	Val bias:-0.0489	Val Pearson correlation: 9.2423e-01	Val MeanMult: 1.4376
# Current learning rate: 0.0002
# Checkpoint saved at epoch 200
# Epoch: 200	Duration: 84.69s	Train loss: 0.0432	Val loss: 0.0409	Val bias:-0.0584	Val Pearson correlation: 9.2380e-01	Val MeanMult: 1.4467
# Current learning rate: 0.0002
# Epoch: 201	Duration: 85.15s	Train loss: 0.0443	Val loss: 0.0417	Val bias:-0.0629	Val Pearson correlation: 9.2327e-01	Val MeanMult: 1.4524
# Current learning rate: 0.0002
# Epoch: 202	Duration: 87.66s	Train loss: 0.0462	Val loss: 0.0404	Val bias:-0.0506	Val Pearson correlation: 9.2279e-01	Val MeanMult: 1.4426
# Current learning rate: 0.0002
# Epoch: 203	Duration: 92.41s	Train loss: 0.0474	Val loss: 0.0393	Val bias:-0.0344	Val Pearson correlation: 9.2230e-01	Val MeanMult: 1.4327
# Current learning rate: 0.0002
# Epoch: 204	Duration: 84.55s	Train loss: 0.0468	Val loss: 0.0396	Val bias:-0.0364	Val Pearson correlation: 9.2214e-01	Val MeanMult: 1.4349
# Current learning rate: 0.0002
# Epoch: 205	Duration: 84.53s	Train loss: 0.0461	Val loss: 0.0395	Val bias:-0.0373	Val Pearson correlation: 9.2237e-01	Val MeanMult: 1.4341
# Current learning rate: 0.0002
# Epoch: 206	Duration: 85.45s	Train loss: 0.0453	Val loss: 0.0408	Val bias:-0.0476	Val Pearson correlation: 9.2175e-01	Val MeanMult: 1.4431
# Current learning rate: 0.0002
# Epoch: 207	Duration: 84.54s	Train loss: 0.0447	Val loss: 0.0406	Val bias:-0.0412	Val Pearson correlation: 9.2136e-01	Val MeanMult: 1.4409
# Current learning rate: 0.0002
# Epoch: 208	Duration: 85.61s	Train loss: 0.0444	Val loss: 0.0411	Val bias:-0.0463	Val Pearson correlation: 9.2137e-01	Val MeanMult: 1.4445
# Current learning rate: 0.0002
# Epoch: 209	Duration: 85.82s	Train loss: 0.0439	Val loss: 0.0403	Val bias:-0.0364	Val Pearson correlation: 9.2149e-01	Val MeanMult: 1.4387
# Current learning rate: 0.0002
# Epoch: 210	Duration: 85.65s	Train loss: 0.0434	Val loss: 0.0410	Val bias:-0.0483	Val Pearson correlation: 9.2158e-01	Val MeanMult: 1.4449
# Current learning rate: 0.0002
# Epoch: 211	Duration: 88.21s	Train loss: 0.0429	Val loss: 0.0410	Val bias:-0.0485	Val Pearson correlation: 9.2199e-01	Val MeanMult: 1.4444
# Current learning rate: 0.0002
# Epoch: 212	Duration: 84.67s	Train loss: 0.0428	Val loss: 0.0406	Val bias:-0.0416	Val Pearson correlation: 9.2159e-01	Val MeanMult: 1.4415
# Current learning rate: 0.0002
# Epoch: 213	Duration: 103.17s	Train loss: 0.0425	Val loss: 0.0415	Val bias:-0.0503	Val Pearson correlation: 9.2147e-01	Val MeanMult: 1.4475
# Current learning rate: 0.0002
# Epoch: 214	Duration: 85.74s	Train loss: 0.0419	Val loss: 0.0419	Val bias:-0.0553	Val Pearson correlation: 9.2197e-01	Val MeanMult: 1.4505
# Current learning rate: 0.0002
# Epoch: 215	Duration: 85.24s	Train loss: 0.0417	Val loss: 0.0424	Val bias:-0.0560	Val Pearson correlation: 9.2169e-01	Val MeanMult: 1.4539
# Current learning rate: 0.0002
# Epoch: 216	Duration: 96.43s	Train loss: 0.0411	Val loss: 0.0423	Val bias:-0.0593	Val Pearson correlation: 9.2215e-01	Val MeanMult: 1.4540
# Current learning rate: 0.0002
# Epoch: 217	Duration: 84.32s	Train loss: 0.0405	Val loss: 0.0419	Val bias:-0.0540	Val Pearson correlation: 9.2198e-01	Val MeanMult: 1.4509
# Current learning rate: 0.0002
# Epoch: 218	Duration: 85.71s	Train loss: 0.0400	Val loss: 0.0430	Val bias:-0.0650	Val Pearson correlation: 9.2227e-01	Val MeanMult: 1.4590
# Current learning rate: 0.0002
# Epoch: 219	Duration: 84.67s	Train loss: 0.0396	Val loss: 0.0425	Val bias:-0.0626	Val Pearson correlation: 9.2258e-01	Val MeanMult: 1.4558
# Current learning rate: 0.0002
# Checkpoint saved at epoch 220
# Epoch: 220	Duration: 84.72s	Train loss: 0.0387	Val loss: 0.0408	Val bias:-0.0503	Val Pearson correlation: 9.2342e-01	Val MeanMult: 1.4437
# Current learning rate: 0.0002
# Epoch: 221	Duration: 84.62s	Train loss: 0.0381	Val loss: 0.0430	Val bias:-0.0699	Val Pearson correlation: 9.2375e-01	Val MeanMult: 1.4599
# Current learning rate: 0.0002
# Epoch: 222	Duration: 84.62s	Train loss: 0.0374	Val loss: 0.0428	Val bias:-0.0686	Val Pearson correlation: 9.2389e-01	Val MeanMult: 1.4590
# Current learning rate: 0.0002
# Epoch: 223	Duration: 87.67s	Train loss: 0.0371	Val loss: 0.0416	Val bias:-0.0627	Val Pearson correlation: 9.2461e-01	Val MeanMult: 1.4505
# Current learning rate: 0.0002
# Epoch: 224	Duration: 87.45s	Train loss: 0.0364	Val loss: 0.0404	Val bias:-0.0511	Val Pearson correlation: 9.2471e-01	Val MeanMult: 1.4420
# Current learning rate: 0.0002
# Epoch: 225	Duration: 84.80s	Train loss: 0.0360	Val loss: 0.0398	Val bias:-0.0504	Val Pearson correlation: 9.2540e-01	Val MeanMult: 1.4378
# Current learning rate: 0.0002
# Epoch: 226	Duration: 106.94s	Train loss: 0.0356	Val loss: 0.0394	Val bias:-0.0413	Val Pearson correlation: 9.2501e-01	Val MeanMult: 1.4343
# Current learning rate: 0.0002
# Epoch: 227	Duration: 86.48s	Train loss: 0.0353	Val loss: 0.0383	Val bias:-0.0249	Val Pearson correlation: 9.2528e-01	Val MeanMult: 1.4265
# Current learning rate: 0.0002
# Epoch: 228	Duration: 90.00s	Train loss: 0.0349	Val loss: 0.0381	Val bias:-0.0260	Val Pearson correlation: 9.2531e-01	Val MeanMult: 1.4247
# Current learning rate: 0.0002
# Epoch: 229	Duration: 84.72s	Train loss: 0.0349	Val loss: 0.0382	Val bias:-0.0259	Val Pearson correlation: 9.2570e-01	Val MeanMult: 1.4262
# Current learning rate: 0.0002
# Epoch: 230	Duration: 91.01s	Train loss: 0.0345	Val loss: 0.0372	Val bias:-0.0167	Val Pearson correlation: 9.2641e-01	Val MeanMult: 1.4186
# Current learning rate: 0.0002
# Epoch: 231	Duration: 84.69s	Train loss: 0.0343	Val loss: 0.0371	Val bias:-0.0119	Val Pearson correlation: 9.2626e-01	Val MeanMult: 1.4170
# Current learning rate: 0.0002
# Epoch: 232	Duration: 84.76s	Train loss: 0.0346	Val loss: 0.0373	Val bias:0.0004	Val Pearson correlation: 9.2569e-01	Val MeanMult: 1.4171
# Current learning rate: 0.0002
# Epoch: 233	Duration: 90.34s	Train loss: 0.0345	Val loss: 0.0371	Val bias:-0.0117	Val Pearson correlation: 9.2646e-01	Val MeanMult: 1.4170
# Current learning rate: 0.0002
# Epoch: 234	Duration: 84.68s	Train loss: 0.0342	Val loss: 0.0372	Val bias:0.0086	Val Pearson correlation: 9.2608e-01	Val MeanMult: 1.4159
# Current learning rate: 0.0002
# Epoch: 235	Duration: 84.69s	Train loss: 0.0342	Val loss: 0.0374	Val bias:0.0109	Val Pearson correlation: 9.2513e-01	Val MeanMult: 1.4167
# Current learning rate: 0.0002
# Epoch: 236	Duration: 85.95s	Train loss: 0.0341	Val loss: 0.0370	Val bias:-0.0015	Val Pearson correlation: 9.2629e-01	Val MeanMult: 1.4151
# Current learning rate: 0.0002
# Epoch: 237	Duration: 85.94s	Train loss: 0.0339	Val loss: 0.0375	Val bias:0.0075	Val Pearson correlation: 9.2572e-01	Val MeanMult: 1.4175
# Current learning rate: 0.0002
# Epoch: 238	Duration: 85.60s	Train loss: 0.0339	Val loss: 0.0366	Val bias:-0.0067	Val Pearson correlation: 9.2645e-01	Val MeanMult: 1.4128
# Current learning rate: 0.0002
# Epoch: 239	Duration: 84.86s	Train loss: 0.0338	Val loss: 0.0367	Val bias:0.0054	Val Pearson correlation: 9.2751e-01	Val MeanMult: 1.4133
# Current learning rate: 0.0002
# Checkpoint saved at epoch 240
# Epoch: 240	Duration: 85.54s	Train loss: 0.0339	Val loss: 0.0370	Val bias:0.0071	Val Pearson correlation: 9.2635e-01	Val MeanMult: 1.4141
# Current learning rate: 0.0002
# Epoch: 241	Duration: 85.58s	Train loss: 0.0339	Val loss: 0.0368	Val bias:0.0047	Val Pearson correlation: 9.2644e-01	Val MeanMult: 1.4133
# Current learning rate: 0.0002
# Epoch: 242	Duration: 92.42s	Train loss: 0.0337	Val loss: 0.0374	Val bias:0.0140	Val Pearson correlation: 9.2649e-01	Val MeanMult: 1.4165
# Current learning rate: 0.0002
# Epoch: 243	Duration: 85.65s	Train loss: 0.0342	Val loss: 0.0375	Val bias:0.0125	Val Pearson correlation: 9.2581e-01	Val MeanMult: 1.4171
# Current learning rate: 0.0002
# Epoch: 244	Duration: 84.75s	Train loss: 0.0336	Val loss: 0.0369	Val bias:0.0113	Val Pearson correlation: 9.2631e-01	Val MeanMult: 1.4127
# Current learning rate: 0.0002
# Epoch: 245	Duration: 85.80s	Train loss: 0.0336	Val loss: 0.0377	Val bias:0.0279	Val Pearson correlation: 9.2620e-01	Val MeanMult: 1.4162
# Current learning rate: 0.0002
# Epoch: 246	Duration: 84.52s	Train loss: 0.0335	Val loss: 0.0371	Val bias:0.0143	Val Pearson correlation: 9.2623e-01	Val MeanMult: 1.4135
# Current learning rate: 0.0002
# Epoch: 247	Duration: 88.90s	Train loss: 0.0334	Val loss: 0.0372	Val bias:0.0193	Val Pearson correlation: 9.2640e-01	Val MeanMult: 1.4139
# Current learning rate: 0.0002
# Epoch: 248	Duration: 85.98s	Train loss: 0.0341	Val loss: 0.0374	Val bias:0.0084	Val Pearson correlation: 9.2642e-01	Val MeanMult: 1.4166
# Current learning rate: 0.0002
# Epoch: 249	Duration: 84.77s	Train loss: 0.0334	Val loss: 0.0380	Val bias:0.0276	Val Pearson correlation: 9.2638e-01	Val MeanMult: 1.4190
# Current learning rate: 0.0002
# Epoch: 250	Duration: 92.57s	Train loss: 0.0334	Val loss: 0.0370	Val bias:0.0147	Val Pearson correlation: 9.2651e-01	Val MeanMult: 1.4125
# Current learning rate: 0.0002
# Epoch: 251	Duration: 114.86s	Train loss: 0.0335	Val loss: 0.0370	Val bias:0.0011	Val Pearson correlation: 9.2623e-01	Val MeanMult: 1.4139
# Current learning rate: 0.0002
# Epoch: 252	Duration: 85.04s	Train loss: 0.0336	Val loss: 0.0377	Val bias:0.0241	Val Pearson correlation: 9.2575e-01	Val MeanMult: 1.4168
# Current learning rate: 0.0002
# Epoch: 253	Duration: 84.73s	Train loss: 0.0334	Val loss: 0.0385	Val bias:0.0305	Val Pearson correlation: 9.2554e-01	Val MeanMult: 1.4221
# Current learning rate: 0.0002
# Epoch: 254	Duration: 84.68s	Train loss: 0.0334	Val loss: 0.0376	Val bias:0.0270	Val Pearson correlation: 9.2634e-01	Val MeanMult: 1.4160
# Current learning rate: 0.0002
# Epoch: 255	Duration: 84.84s	Train loss: 0.0337	Val loss: 0.0376	Val bias:0.0196	Val Pearson correlation: 9.2664e-01	Val MeanMult: 1.4175
# Current learning rate: 0.0002
# Epoch: 256	Duration: 84.69s	Train loss: 0.0333	Val loss: 0.0368	Val bias:0.0062	Val Pearson correlation: 9.2731e-01	Val MeanMult: 1.4128
# Current learning rate: 0.0002
# Epoch: 257	Duration: 85.83s	Train loss: 0.0334	Val loss: 0.0366	Val bias:0.0005	Val Pearson correlation: 9.2739e-01	Val MeanMult: 1.4123
# Current learning rate: 0.0002
# Epoch: 258	Duration: 92.04s	Train loss: 0.0336	Val loss: 0.0357	Val bias:0.0018	Val Pearson correlation: 9.2847e-01	Val MeanMult: 1.4059
# Current learning rate: 0.0002
# Epoch: 259	Duration: 87.83s	Train loss: 0.0331	Val loss: 0.0362	Val bias:0.0089	Val Pearson correlation: 9.2770e-01	Val MeanMult: 1.4090
# Current learning rate: 0.0002
# Checkpoint saved at epoch 260
# Epoch: 260	Duration: 84.79s	Train loss: 0.0335	Val loss: 0.0369	Val bias:0.0161	Val Pearson correlation: 9.2695e-01	Val MeanMult: 1.4125
# Current learning rate: 0.0002
# Epoch: 261	Duration: 84.65s	Train loss: 0.0330	Val loss: 0.0360	Val bias:0.0112	Val Pearson correlation: 9.2801e-01	Val MeanMult: 1.4065
# Current learning rate: 0.0002
# Epoch: 262	Duration: 110.30s	Train loss: 0.0331	Val loss: 0.0369	Val bias:0.0191	Val Pearson correlation: 9.2743e-01	Val MeanMult: 1.4123
# Current learning rate: 0.0002
# Epoch: 263	Duration: 90.08s	Train loss: 0.0332	Val loss: 0.0370	Val bias:0.0115	Val Pearson correlation: 9.2609e-01	Val MeanMult: 1.4132
# Current learning rate: 0.0002
# Epoch: 264	Duration: 84.77s	Train loss: 0.0334	Val loss: 0.0364	Val bias:0.0060	Val Pearson correlation: 9.2709e-01	Val MeanMult: 1.4101
# Current learning rate: 0.0002
# Epoch: 265	Duration: 84.66s	Train loss: 0.0330	Val loss: 0.0362	Val bias:-0.0042	Val Pearson correlation: 9.2771e-01	Val MeanMult: 1.4096
# Current learning rate: 0.0002
# Epoch: 266	Duration: 84.66s	Train loss: 0.0330	Val loss: 0.0360	Val bias:0.0135	Val Pearson correlation: 9.2788e-01	Val MeanMult: 1.4068
# Current learning rate: 0.0002
# Epoch: 267	Duration: 84.54s	Train loss: 0.0333	Val loss: 0.0356	Val bias:0.0061	Val Pearson correlation: 9.2945e-01	Val MeanMult: 1.4055
# Current learning rate: 0.0002
# Epoch: 268	Duration: 88.46s	Train loss: 0.0331	Val loss: 0.0365	Val bias:0.0121	Val Pearson correlation: 9.2738e-01	Val MeanMult: 1.4097
# Current learning rate: 0.0002
# Epoch: 269	Duration: 84.77s	Train loss: 0.0329	Val loss: 0.0355	Val bias:0.0095	Val Pearson correlation: 9.2855e-01	Val MeanMult: 1.4035
# Current learning rate: 0.0002
# Epoch: 270	Duration: 89.68s	Train loss: 0.0331	Val loss: 0.0366	Val bias:0.0173	Val Pearson correlation: 9.2707e-01	Val MeanMult: 1.4096
# Current learning rate: 0.0002
# Epoch: 271	Duration: 86.04s	Train loss: 0.0330	Val loss: 0.0375	Val bias:0.0246	Val Pearson correlation: 9.2659e-01	Val MeanMult: 1.4156
# Current learning rate: 0.0002
# Epoch: 272	Duration: 84.62s	Train loss: 0.0327	Val loss: 0.0365	Val bias:0.0234	Val Pearson correlation: 9.2820e-01	Val MeanMult: 1.4094
# Current learning rate: 0.0002
# Epoch: 273	Duration: 85.55s	Train loss: 0.0330	Val loss: 0.0364	Val bias:0.0181	Val Pearson correlation: 9.2751e-01	Val MeanMult: 1.4084
# Current learning rate: 0.0002
# Epoch: 274	Duration: 85.63s	Train loss: 0.0328	Val loss: 0.0369	Val bias:0.0290	Val Pearson correlation: 9.2803e-01	Val MeanMult: 1.4111
# Current learning rate: 0.0002
# Epoch: 275	Duration: 95.50s	Train loss: 0.0331	Val loss: 0.0367	Val bias:0.0224	Val Pearson correlation: 9.2745e-01	Val MeanMult: 1.4100
# Current learning rate: 0.0002
# Epoch: 276	Duration: 84.79s	Train loss: 0.0327	Val loss: 0.0363	Val bias:0.0148	Val Pearson correlation: 9.2704e-01	Val MeanMult: 1.4075
# Current learning rate: 0.0002
# Epoch: 277	Duration: 85.64s	Train loss: 0.0331	Val loss: 0.0367	Val bias:0.0297	Val Pearson correlation: 9.2767e-01	Val MeanMult: 1.4089
# Current learning rate: 0.0002
# Epoch: 278	Duration: 84.53s	Train loss: 0.0331	Val loss: 0.0386	Val bias:0.0449	Val Pearson correlation: 9.2611e-01	Val MeanMult: 1.4200
# Current learning rate: 0.0002
# Epoch: 279	Duration: 85.48s	Train loss: 0.0330	Val loss: 0.0394	Val bias:0.0523	Val Pearson correlation: 9.2578e-01	Val MeanMult: 1.4240
# Current learning rate: 0.0002
# Checkpoint saved at epoch 280
# Epoch: 280	Duration: 84.50s	Train loss: 0.0330	Val loss: 0.0385	Val bias:0.0397	Val Pearson correlation: 9.2633e-01	Val MeanMult: 1.4207
# Current learning rate: 0.0002
# Epoch: 281	Duration: 84.31s	Train loss: 0.0331	Val loss: 0.0387	Val bias:0.0434	Val Pearson correlation: 9.2681e-01	Val MeanMult: 1.4212
# Current learning rate: 0.0002
# Epoch: 282	Duration: 84.49s	Train loss: 0.0328	Val loss: 0.0377	Val bias:0.0302	Val Pearson correlation: 9.2682e-01	Val MeanMult: 1.4156
# Current learning rate: 0.0002
# Epoch: 283	Duration: 84.40s	Train loss: 0.0329	Val loss: 0.0379	Val bias:0.0366	Val Pearson correlation: 9.2641e-01	Val MeanMult: 1.4166
# Current learning rate: 0.0002
# ...
# Current learning rate: 0.0002
# Epoch: 984	Duration: 84.76s	Train loss: 0.0250	Val loss: 0.0266	Val bias:0.0201	Val Pearson correlation: 9.4707e-01	Val MeanMult: 1.3410
# Current learning rate: 0.0002
# Epoch: 985	Duration: 84.77s	Train loss: 0.0254	Val loss: 0.0265	Val bias:-0.0144	Val Pearson correlation: 9.4680e-01	Val MeanMult: 1.3432
# Current learning rate: 0.0002
# Epoch: 986	Duration: 94.93s	Train loss: 0.0260	Val loss: 0.0322	Val bias:-0.0770	Val Pearson correlation: 9.4690e-01	Val MeanMult: 1.3916
# Current learning rate: 0.0002
# Epoch: 987	Duration: 84.67s	Train loss: 0.0276	Val loss: 0.0647	Val bias:-0.1907	Val Pearson correlation: 9.4364e-01	Val MeanMult: 1.6358
# Current learning rate: 0.0002
# Epoch: 988	Duration: 92.39s	Train loss: 0.0298	Val loss: 0.0481	Val bias:-0.1435	Val Pearson correlation: 9.4508e-01	Val MeanMult: 1.5121
# Current learning rate: 0.0002
# Epoch: 989	Duration: 85.72s	Train loss: 0.0310	Val loss: 0.0399	Val bias:-0.1107	Val Pearson correlation: 9.4428e-01	Val MeanMult: 1.4466
# Current learning rate: 0.0002
# Epoch: 990	Duration: 84.42s	Train loss: 0.0309	Val loss: 0.0288	Val bias:-0.0458	Val Pearson correlation: 9.4593e-01	Val MeanMult: 1.3621
# Current learning rate: 0.0002
# Epoch: 991	Duration: 85.57s	Train loss: 0.0305	Val loss: 0.0283	Val bias:-0.0381	Val Pearson correlation: 9.4583e-01	Val MeanMult: 1.3580
# Current learning rate: 0.0002
# Epoch: 992	Duration: 84.46s	Train loss: 0.0296	Val loss: 0.0314	Val bias:-0.0649	Val Pearson correlation: 9.4509e-01	Val MeanMult: 1.3821
# Current learning rate: 0.0002
# Epoch: 993	Duration: 84.48s	Train loss: 0.0298	Val loss: 0.0321	Val bias:-0.0692	Val Pearson correlation: 9.4489e-01	Val MeanMult: 1.3877
# Current learning rate: 0.0002
# Epoch: 994	Duration: 84.48s	Train loss: 0.0299	Val loss: 0.0320	Val bias:-0.0701	Val Pearson correlation: 9.4538e-01	Val MeanMult: 1.3866
# Current learning rate: 0.0002
# Epoch: 995	Duration: 84.44s	Train loss: 0.0293	Val loss: 0.0323	Val bias:-0.0730	Val Pearson correlation: 9.4542e-01	Val MeanMult: 1.3899
# Current learning rate: 0.0002
# Epoch: 996	Duration: 84.46s	Train loss: 0.0293	Val loss: 0.0324	Val bias:-0.0712	Val Pearson correlation: 9.4459e-01	Val MeanMult: 1.3897
# Current learning rate: 0.0002
# Epoch: 997	Duration: 89.13s	Train loss: 0.0290	Val loss: 0.0330	Val bias:-0.0768	Val Pearson correlation: 9.4510e-01	Val MeanMult: 1.3948
# Current learning rate: 0.0002
# Epoch: 998	Duration: 84.57s	Train loss: 0.0291	Val loss: 0.0333	Val bias:-0.0782	Val Pearson correlation: 9.4502e-01	Val MeanMult: 1.3966
# Current learning rate: 0.0002
# Epoch: 999	Duration: 84.65s	Train loss: 0.0285	Val loss: 0.0336	Val bias:-0.0785	Val Pearson correlation: 9.4452e-01	Val MeanMult: 1.3985
# Current learning rate: 0.0002
# Checkpoint saved at epoch 1000
# Epoch: 1000	Duration: 84.66s	Train loss: 0.0288	Val loss: 0.0325	Val bias:-0.0727	Val Pearson correlation: 9.4505e-01	Val MeanMult: 1.3911
# Current learning rate: 0.0002
# Epoch: 1001	Duration: 97.60s	Train loss: 0.0288	Val loss: 0.0326	Val bias:-0.0714	Val Pearson correlation: 9.4462e-01	Val MeanMult: 1.3912
# Current learning rate: 0.0002
# Epoch: 1002	Duration: 85.98s	Train loss: 0.0288	Val loss: 0.0329	Val bias:-0.0734	Val Pearson correlation: 9.4446e-01	Val MeanMult: 1.3934
# Current learning rate: 0.0002
# Epoch: 1003	Duration: 84.60s	Train loss: 0.0284	Val loss: 0.0319	Val bias:-0.0654	Val Pearson correlation: 9.4455e-01	Val MeanMult: 1.3850
# Current learning rate: 0.0002
# Epoch: 1004	Duration: 84.66s	Train loss: 0.0285	Val loss: 0.0318	Val bias:-0.0658	Val Pearson correlation: 9.4445e-01	Val MeanMult: 1.3847
# Current learning rate: 0.0002
# Epoch: 1005	Duration: 89.20s	Train loss: 0.0283	Val loss: 0.0332	Val bias:-0.0750	Val Pearson correlation: 9.4448e-01	Val MeanMult: 1.3958
# Current learning rate: 0.0002
# Epoch: 1006	Duration: 84.36s	Train loss: 0.0277	Val loss: 0.0333	Val bias:-0.0772	Val Pearson correlation: 9.4484e-01	Val MeanMult: 1.3965
# Current learning rate: 0.0002
# Epoch: 1007	Duration: 86.39s	Train loss: 0.0273	Val loss: 0.0326	Val bias:-0.0741	Val Pearson correlation: 9.4531e-01	Val MeanMult: 1.3919
# Current learning rate: 0.0002
# Epoch: 1008	Duration: 84.62s	Train loss: 0.0271	Val loss: 0.0339	Val bias:-0.0802	Val Pearson correlation: 9.4461e-01	Val MeanMult: 1.4009
# Current learning rate: 0.0002
# Epoch: 1009	Duration: 84.60s	Train loss: 0.0270	Val loss: 0.0349	Val bias:-0.0884	Val Pearson correlation: 9.4542e-01	Val MeanMult: 1.4093
# Current learning rate: 0.0002
# Epoch: 1010	Duration: 84.62s	Train loss: 0.0262	Val loss: 0.0340	Val bias:-0.0833	Val Pearson correlation: 9.4543e-01	Val MeanMult: 1.4018
# Current learning rate: 0.0002
# Epoch: 1011	Duration: 84.70s	Train loss: 0.0258	Val loss: 0.0364	Val bias:-0.0975	Val Pearson correlation: 9.4570e-01	Val MeanMult: 1.4211
# Current learning rate: 0.0002
# Epoch: 1012	Duration: 84.62s	Train loss: 0.0257	Val loss: 0.0332	Val bias:-0.0809	Val Pearson correlation: 9.4635e-01	Val MeanMult: 1.3967
# Current learning rate: 0.0002
# Epoch: 1013	Duration: 84.61s	Train loss: 0.0258	Val loss: 0.0334	Val bias:-0.0813	Val Pearson correlation: 9.4601e-01	Val MeanMult: 1.3985
# Current learning rate: 0.0002
# Epoch: 1014	Duration: 84.73s	Train loss: 0.0250	Val loss: 0.0331	Val bias:-0.0796	Val Pearson correlation: 9.4635e-01	Val MeanMult: 1.3953
# Current learning rate: 0.0002
# Epoch: 1015	Duration: 84.54s	Train loss: 0.0251	Val loss: 0.0330	Val bias:-0.0782	Val Pearson correlation: 9.4613e-01	Val MeanMult: 1.3952
# Current learning rate: 0.0002
# Epoch: 1016	Duration: 88.78s	Train loss: 0.0249	Val loss: 0.0311	Val bias:-0.0632	Val Pearson correlation: 9.4588e-01	Val MeanMult: 1.3791
# Current learning rate: 0.0002
# Epoch: 1017	Duration: 84.65s	Train loss: 0.0243	Val loss: 0.0304	Val bias:-0.0609	Val Pearson correlation: 9.4642e-01	Val MeanMult: 1.3747
# Current learning rate: 0.0002
# Epoch: 1018	Duration: 84.76s	Train loss: 0.0243	Val loss: 0.0284	Val bias:-0.0405	Val Pearson correlation: 9.4664e-01	Val MeanMult: 1.3591
# Current learning rate: 0.0002
# Epoch: 1019	Duration: 84.65s	Train loss: 0.0243	Val loss: 0.0283	Val bias:-0.0433	Val Pearson correlation: 9.4696e-01	Val MeanMult: 1.3586
# Current learning rate: 0.0002
# Checkpoint saved at epoch 1020
# Epoch: 1020	Duration: 84.70s	Train loss: 0.0241	Val loss: 0.0285	Val bias:-0.0399	Val Pearson correlation: 9.4633e-01	Val MeanMult: 1.3602
# Current learning rate: 0.0002
# Epoch: 1021	Duration: 84.99s	Train loss: 0.0243	Val loss: 0.0275	Val bias:-0.0238	Val Pearson correlation: 9.4644e-01	Val MeanMult: 1.3517
# Current learning rate: 0.0002
# Epoch: 1022	Duration: 84.66s	Train loss: 0.0240	Val loss: 0.0270	Val bias:-0.0221	Val Pearson correlation: 9.4667e-01	Val MeanMult: 1.3475
# Current learning rate: 0.0002
# Epoch: 1023	Duration: 84.61s	Train loss: 0.0242	Val loss: 0.0273	Val bias:-0.0165	Val Pearson correlation: 9.4562e-01	Val MeanMult: 1.3496
# Current learning rate: 0.0002
# Epoch: 1024	Duration: 90.76s	Train loss: 0.0241	Val loss: 0.0273	Val bias:-0.0274	Val Pearson correlation: 9.4698e-01	Val MeanMult: 1.3501
# Current learning rate: 0.0002
# Epoch: 1025	Duration: 88.25s	Train loss: 0.0242	Val loss: 0.0277	Val bias:-0.0239	Val Pearson correlation: 9.4637e-01	Val MeanMult: 1.3530
# Current learning rate: 0.0002
# Epoch: 1026	Duration: 89.37s	Train loss: 0.0241	Val loss: 0.0263	Val bias:-0.0186	Val Pearson correlation: 9.4796e-01	Val MeanMult: 1.3416
# Current learning rate: 0.0002
# Epoch: 1027	Duration: 84.69s	Train loss: 0.0240	Val loss: 0.0273	Val bias:-0.0248	Val Pearson correlation: 9.4689e-01	Val MeanMult: 1.3499
# Current learning rate: 0.0002
# Epoch: 1028	Duration: 84.91s	Train loss: 0.0238	Val loss: 0.0264	Val bias:-0.0028	Val Pearson correlation: 9.4707e-01	Val MeanMult: 1.3424
# Current learning rate: 0.0002
# Epoch: 1029	Duration: 85.62s	Train loss: 0.0240	Val loss: 0.0267	Val bias:0.0013	Val Pearson correlation: 9.4683e-01	Val MeanMult: 1.3434
# Current learning rate: 0.0002
# Epoch: 1030	Duration: 86.57s	Train loss: 0.0241	Val loss: 0.0268	Val bias:-0.0148	Val Pearson correlation: 9.4670e-01	Val MeanMult: 1.3457
# Current learning rate: 0.0002
# Epoch: 1031	Duration: 85.63s	Train loss: 0.0240	Val loss: 0.0267	Val bias:0.0061	Val Pearson correlation: 9.4637e-01	Val MeanMult: 1.3431
# Current learning rate: 0.0002
# Epoch: 1032	Duration: 85.77s	Train loss: 0.0239	Val loss: 0.0266	Val bias:-0.0024	Val Pearson correlation: 9.4644e-01	Val MeanMult: 1.3430
# Current learning rate: 0.0002
# Epoch: 1033	Duration: 84.57s	Train loss: 0.0239	Val loss: 0.0265	Val bias:-0.0143	Val Pearson correlation: 9.4719e-01	Val MeanMult: 1.3437
# Current learning rate: 0.0002
# Epoch: 1034	Duration: 86.24s	Train loss: 0.0238	Val loss: 0.0267	Val bias:-0.0221	Val Pearson correlation: 9.4728e-01	Val MeanMult: 1.3451
# Current learning rate: 0.0002
# Epoch: 1035	Duration: 93.53s	Train loss: 0.0236	Val loss: 0.0264	Val bias:-0.0188	Val Pearson correlation: 9.4788e-01	Val MeanMult: 1.3421
# Current learning rate: 0.0002
# Epoch: 1036	Duration: 84.45s	Train loss: 0.0236	Val loss: 0.0269	Val bias:-0.0115	Val Pearson correlation: 9.4671e-01	Val MeanMult: 1.3453
# Current learning rate: 0.0002
# Epoch: 1037	Duration: 88.45s	Train loss: 0.0238	Val loss: 0.0270	Val bias:-0.0205	Val Pearson correlation: 9.4676e-01	Val MeanMult: 1.3469
# Current learning rate: 0.0002
# Epoch: 1038	Duration: 86.73s	Train loss: 0.0236	Val loss: 0.0261	Val bias:0.0001	Val Pearson correlation: 9.4747e-01	Val MeanMult: 1.3389
# Current learning rate: 0.0002
# Epoch: 1039	Duration: 84.66s	Train loss: 0.0237	Val loss: 0.0270	Val bias:0.0019	Val Pearson correlation: 9.4595e-01	Val MeanMult: 1.3452
# Current learning rate: 0.0002
# Checkpoint saved at epoch 1040
# Epoch: 1040	Duration: 84.48s	Train loss: 0.0238	Val loss: 0.0268	Val bias:-0.0047	Val Pearson correlation: 9.4622e-01	Val MeanMult: 1.3451
# Current learning rate: 0.0002
# Epoch: 1041	Duration: 84.49s	Train loss: 0.0236	Val loss: 0.0264	Val bias:-0.0045	Val Pearson correlation: 9.4695e-01	Val MeanMult: 1.3413
# Current learning rate: 0.0002
# Epoch: 1042	Duration: 85.77s	Train loss: 0.0238	Val loss: 0.0268	Val bias:-0.0242	Val Pearson correlation: 9.4752e-01	Val MeanMult: 1.3455
# Current learning rate: 0.0002
# Epoch: 1043	Duration: 84.58s	Train loss: 0.0239	Val loss: 0.0268	Val bias:-0.0161	Val Pearson correlation: 9.4654e-01	Val MeanMult: 1.3450
# Current learning rate: 0.0002
# Epoch: 1044	Duration: 84.46s	Train loss: 0.0236	Val loss: 0.0270	Val bias:-0.0229	Val Pearson correlation: 9.4706e-01	Val MeanMult: 1.3463
# Current learning rate: 0.0002
# Epoch: 1045	Duration: 85.45s	Train loss: 0.0236	Val loss: 0.0264	Val bias:-0.0188	Val Pearson correlation: 9.4754e-01	Val MeanMult: 1.3430
# Current learning rate: 0.0002
# Epoch: 1046	Duration: 84.41s	Train loss: 0.0236	Val loss: 0.0266	Val bias:-0.0181	Val Pearson correlation: 9.4729e-01	Val MeanMult: 1.3439
# Current learning rate: 0.0002
# Epoch: 1047	Duration: 84.50s	Train loss: 0.0237	Val loss: 0.0266	Val bias:0.0006	Val Pearson correlation: 9.4684e-01	Val MeanMult: 1.3425
# Current learning rate: 0.0002
# Epoch: 1048	Duration: 84.40s	Train loss: 0.0240	Val loss: 0.0262	Val bias:-0.0076	Val Pearson correlation: 9.4765e-01	Val MeanMult: 1.3405
# Current learning rate: 0.0002
# Epoch: 1049	Duration: 90.15s	Train loss: 0.0243	Val loss: 0.0260	Val bias:-0.0054	Val Pearson correlation: 9.4770e-01	Val MeanMult: 1.3388
# Current learning rate: 0.0002
# Epoch: 1050	Duration: 84.52s	Train loss: 0.0242	Val loss: 0.0262	Val bias:0.0026	Val Pearson correlation: 9.4743e-01	Val MeanMult: 1.3393
# Current learning rate: 0.0002
# Epoch: 1051	Duration: 84.46s	Train loss: 0.0246	Val loss: 0.0270	Val bias:-0.0285	Val Pearson correlation: 9.4710e-01	Val MeanMult: 1.3477
# Current learning rate: 0.0002
# Epoch: 1052	Duration: 84.48s	Train loss: 0.0250	Val loss: 0.0339	Val bias:-0.0891	Val Pearson correlation: 9.4755e-01	Val MeanMult: 1.4047
# Current learning rate: 0.0002
# Epoch: 1053	Duration: 84.45s	Train loss: 0.0265	Val loss: 0.0584	Val bias:-0.1766	Val Pearson correlation: 9.4594e-01	Val MeanMult: 1.5922
# Current learning rate: 0.0002
# Epoch: 1054	Duration: 85.46s	Train loss: 0.0281	Val loss: 0.0535	Val bias:-0.1602	Val Pearson correlation: 9.4529e-01	Val MeanMult: 1.5528
# Current learning rate: 0.0002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 70
#      67 with torch.no_grad():
#      68     model.eval()
# ---> 70     val_metrics = compute_eval_metrics(val_dataloader, model)
#      73 hist['train_loss'].append(train_loss/train_steps)
#      74 hist['val_loss'].append(val_metrics['mse'])
#
# Cell In[12], line 31, in compute_eval_metrics(dataloader, model, log)
#      29 for (x,y) in dataloader:
#      30     (x, y) = (x.to(device), y.to(device))
# ---> 31     pred = model(x,task='ft_avgtok')
#      32     target_sum += y.sum()
#      33     pred_sum += pred.sum()
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[10], line 710, in AMBAModel.forward(self, x, task, cluster, mask_patch)
#     707 # finetuning (ft), use the mean of all token (patch) output as clip-level representation.
#     708 # this is default for SSAMBA fine-tuning as during pretraining, supervision signal is given to each token, not the [cls] token
#     709 if task == 'ft_avgtok':
# --> 710     return self.finetuningavgtok(x)
#     711 elif task == 'ft_avgtok_1sec':
#     712     return self.finetuningavgtok_1sec(x)
#
# Cell In[10], line 360, in AMBAModel.finetuningavgtok(self, x)
#     357 if not self.v.if_bidirectional:
#     358     for layer in self.v.layers:
# --> 360         hidden_states, residual = layer(
#     361             hidden_states, residual
#     362         )
#     363 else:
#     364     # get two layers in a single for-loop
#     365     for i in range(len(self.v.layers) // 2):
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/volest/volume-estimation/TTTT/models_mamba.py:112, in Block.forward(self, hidden_states, residual, inference_params)
#     110     hidden_states = self.norm(residual.to(dtype=self.norm.weight.dtype))
#     111     if self.residual_in_fp32:
# --> 112         residual = residual.to(torch.float32)
#     113 else:
#     114     fused_add_norm_fn = rms_norm_fn if isinstance(self.norm, RMSNorm) else layer_norm_fn
#
# KeyboardInterrupt:

# %%
torch.cuda.empty_cache()

# %%
import csv
torch.cuda.empty_cache()


# 创建一个空列表来存储pred和y的值
data_to_save = []

test1_df = test_df.sample(5)

mae = 0.0 
total_samples = 0

test_dataloader1 = create_dataloader(test1_df) 
test_random = compute_eval_metrics(test_dataloader1,model) 
print(test_random)

for(x,y) in test_dataloader: 
    (x,y) = (x.to(device),y.to(device)) 
    pred = model(x,task='ft_avgtok') 
    for i in range(len(pred)):
        data_to_save.append([pred[i].item(), y[i].item()])

# 指定要保存的CSV文件名
csv_filename = 'predictions.csv'

# 打开CSV文件并将数据写入
with open(csv_filename, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # 写入列名（如果需要）
    csv_writer.writerow(['Prediction', 'Actual'])
    
    # 写入数据
    csv_writer.writerows(data_to_save)

print(f'Data saved to {csv_filename}')
#     print(pred,'///',y)

#     # 计算绝对误差
#     absolute_error = torch.abs(pred-y)

#     # 累加绝对误差和样本数
#     mae += absolute_error.sum().item()
    

# #     计算平均绝对误差


# mae /= 5 
# print("MAE:", mae)
# Out:
# 5it [00:00, 696.43it/s]
# {'mse': 0.013952666987486165, 'bias': -0.06646099251625044, 'pearson_cor': 0.9693664692502876, 'mean_mult': 1.2414894812916284}
# Data saved to predictions.csv

# %%
with torch.no_grad():
    eval_test = compute_eval_metrics(test_dataloader, model)
    print(eval_test)
# Out:
# {'mse': 0.04112523694364636, 'bias': -0.12083855395474014, 'pearson_cor': 0.9465716273462855, 'mean_mult': 1.4580013167092452}

# %%
torch.cuda.empty_cache()

# %%
hist.keys()
np.std(hist['val_loss'][15:])
np.arange(100)[-10:]

# %%
random_df = feat_df.sample(20)

random_dataloader = create_dataloader(random_df)
eval_random = compute_eval_metrics(random_dataloader, model)
print(eval_random)

for (x, y) in random_dataloader:
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        print(pred.item())

# %%
class print_Model(Module):
    def __init__(self, seq):
        super(print_Model, self).__init__()
        self.net = seq

    def forward(self, x):
        print("Start\n{}".format(x.size()))
        for layer in self.net:
            x = layer(x)
            print(layer)
            print(x.size())
        return x

# %%
# %load_ext autoreload

# %%
random_df = feat_df.sample(20)

random_dataloader = create_dataloader(random_df, log=False)


load_model = Baseline_Model((input_height, input_width)).to(device)
model_name = 'testrun2_regularization'
load_model.load_state_dict(torch.load(os.path.join(MODELS_DIR,model_name,'model_state.pt'), map_location=torch.device('cpu')))

load_metrics = compute_eval_metrics(test_dataloader, load_model, log=False)
for key in load_metrics.keys():
    print(key, load_metrics[key])

for (x, y) in random_dataloader:
    (x, y) = (x.to(device), y.to(device))
    pred = load_model(x)
    print(pred.item())

# %%
feat_df['vol'].hist()
